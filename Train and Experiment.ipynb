# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import RobustScaler, PowerTransformer, StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.decomposition import PCA
from sklearn.ensemble import (RandomForestRegressor, GradientBoostingRegressor, 
                             VotingRegressor, StackingRegressor)
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
import xgboost as xgb
import lightgbm as lgb

import matplotlib.pyplot as plt
import joblib
import seaborn as sns
import warnings
from scipy import stats
from scipy.stats import skew
import os
import pickle
warnings.filterwarnings('ignore')

class ComprehensiveKFoldNoisePredictor:
    def __init__(self):
        self.models = {}
        self.best_models = {}  # 存储最佳模型
        self.scalers = {}
        self.target_transformers = {}
        self.feature_selectors = {}
        self.pca_transformers = {}
        self.feature_names = {}
        self.noise_types = ['Mean Noise', 'Low Freq', 'Mid Freq', 'High Freq']
        self.feature_types = ['street', 'remote', 'fusion']
        self.feature_names_display = {
            'street': 'Street View', 
            'remote': 'Remote Sensing', 
            'fusion': 'Fusion'
        }
        
        # 8个模型配置
        self.model_configs = self._get_all_model_configs()
        
    def _get_all_model_configs(self):
        """获取所有8个模型的配置"""
        configs = {
            'XGBoost': {
                'class': xgb.XGBRegressor,
                'params': {
                    'objective': 'reg:squarederror',
                    'max_depth': 8,
                    'learning_rate': 0.03,
                    'n_estimators': 1000,
                    'subsample': 0.85,
                    'colsample_bytree': 0.85,
                    'reg_alpha': 0.1,
                    'reg_lambda': 1.2,
                    'random_state': 42,
                    'n_jobs': -1,
                    'verbosity': 0
                },
                'param_grid': {
                    'max_depth': [6, 8, 10],
                    'learning_rate': [0.01, 0.03, 0.05],
                    'n_estimators': [800, 1000, 1200],
                    'subsample': [0.8, 0.85, 0.9],
                    'colsample_bytree': [0.8, 0.85, 0.9]
                }
            },
            'LightGBM': {
                'class': lgb.LGBMRegressor,
                'params': {
                    'objective': 'regression',
                    'max_depth': 8,
                    'learning_rate': 0.03,
                    'n_estimators': 1000,
                    'subsample': 0.85,
                    'colsample_bytree': 0.85,
                    'reg_alpha': 0.1,
                    'reg_lambda': 1.2,
                    'random_state': 42,
                    'n_jobs': -1,
                    'verbose': -1
                },
                'param_grid': {
                    'max_depth': [6, 8, 10],
                    'learning_rate': [0.01, 0.03, 0.05],
                    'n_estimators': [800, 1000, 1200],
                    'subsample': [0.8, 0.85, 0.9]
                }
            },
            'Random Forest': {
                'class': RandomForestRegressor,
                'params': {
                    'n_estimators': 300,
                    'max_depth': 20,
                    'min_samples_split': 3,
                    'min_samples_leaf': 1,
                    'max_features': 'sqrt',
                    'random_state': 42,
                    'n_jobs': -1
                },
                'param_grid': {
                    'n_estimators': [200, 300, 400],
                    'max_depth': [15, 20, 25],
                    'min_samples_split': [2, 3, 5],
                    'max_features': ['sqrt', 'log2']
                }
            },
            'Gradient Boosting': {
                'class': GradientBoostingRegressor,
                'params': {
                    'n_estimators': 300,
                    'max_depth': 8,
                    'learning_rate': 0.05,
                    'subsample': 0.85,
                    'min_samples_split': 3,
                    'random_state': 42
                },
                'param_grid': {
                    'n_estimators': [200, 300, 400],
                    'max_depth': [6, 8, 10],
                    'learning_rate': [0.03, 0.05, 0.1],
                    'subsample': [0.8, 0.85, 0.9]
                }
            },
            'SVR': {
                'class': SVR,
                'params': {
                    'kernel': 'rbf',
                    'C': 100,
                    'gamma': 'scale',
                    'epsilon': 0.05
                },
                'param_grid': {
                    'kernel': ['rbf', 'poly'],
                    'C': [50, 100, 200],
                    'gamma': ['scale', 'auto'],
                    'epsilon': [0.01, 0.05, 0.1]
                }
            },
            'KNN': {
                'class': KNeighborsRegressor,
                'params': {
                    'n_neighbors': 5,
                    'weights': 'distance',
                    'algorithm': 'auto',
                    'leaf_size': 30,
                    'p': 2,
                    'n_jobs': -1
                },
                'param_grid': {
                    'n_neighbors': [3, 5, 7, 9],
                    'weights': ['uniform', 'distance'],
                    'leaf_size': [20, 30, 40],
                    'p': [1, 2]
                }
            },
            'Lasso': {
                'class': Lasso,
                'params': {
                    'alpha': 0.1,
                    'random_state': 42,
                    'max_iter': 2000
                },
                'param_grid': {
                    'alpha': [0.001, 0.01, 0.1, 1.0],
                    'max_iter': [1000, 2000, 3000]
                }
            }
        }
        
        return configs

    def load_data(self, street_view_path, remote_sensing_path, noise_labels_path):
        """加载数据"""
        street_features = np.load(street_view_path)
        remote_features = np.load(remote_sensing_path)
        noise_labels = np.load(noise_labels_path)

        print(f"Street view features shape: {street_features.shape}")
        print(f"Remote sensing features shape: {remote_features.shape}")
        print(f"Noise labels shape: {noise_labels.shape}")

        if noise_labels.shape[1] != 4:
            raise ValueError(f"Noise labels should have 4 columns, but got {noise_labels.shape[1]}")

        # 生成特征名称
        self.feature_names['street'] = [f'street_feat_{i}' for i in range(street_features.shape[1])]
        self.feature_names['remote'] = [f'remote_feat_{i}' for i in range(remote_features.shape[1])]
        self.feature_names['fusion'] = self.feature_names['street'] + self.feature_names['remote']

        # 拼接特征用于融合模型
        fusion_features = np.concatenate([street_features, remote_features], axis=1)

        return street_features, remote_features, fusion_features, noise_labels

    def advanced_preprocessing(self, X_train, X_test, y_train):
        """高级数据预处理"""
        # 1. 异常值检测和处理
        try:
            z_scores = np.abs(stats.zscore(X_train, axis=0, nan_policy='omit'))
            outlier_threshold = 4
            outlier_mask = (z_scores < outlier_threshold).all(axis=1)
            
            if np.sum(~outlier_mask) > 0:
                X_train_clean = X_train[outlier_mask]
                y_train_clean = y_train[outlier_mask]
            else:
                X_train_clean = X_train
                y_train_clean = y_train
        except Exception as e:
            X_train_clean = X_train
            y_train_clean = y_train
        
        # 2. 使用RobustScaler
        scaler = RobustScaler()
        X_train_scaled = scaler.fit_transform(X_train_clean)
        X_test_scaled = scaler.transform(X_test)
        
        # 3. 目标变量变换
        target_transformer = None
        try:
            if len(y_train_clean) > 0 and skew(y_train_clean) > 1:
                target_transformer = PowerTransformer(method='yeo-johnson')
                y_train_transformed = target_transformer.fit_transform(
                    y_train_clean.reshape(-1, 1)
                ).flatten()
            else:
                y_train_transformed = y_train_clean
        except Exception as e:
            y_train_transformed = y_train_clean
        
        return X_train_scaled, X_test_scaled, y_train_transformed, scaler, target_transformer

    def advanced_feature_engineering(self, X_train, X_test, y_train):
        """高级特征工程"""
        # 1. 移除常数特征
        constant_features = []
        for i in range(X_train.shape[1]):
            if np.var(X_train[:, i]) < 1e-10:
                constant_features.append(i)
        
        if constant_features:
            X_train = np.delete(X_train, constant_features, axis=1)
            X_test = np.delete(X_test, constant_features, axis=1)
        
        # 2. 特征选择
        feature_selector = None
        n_features_to_select = min(300, X_train.shape[1])
        if X_train.shape[1] > n_features_to_select:
            feature_selector = SelectKBest(score_func=f_regression, k=n_features_to_select)
            X_train_selected = feature_selector.fit_transform(X_train, y_train)
            X_test_selected = feature_selector.transform(X_test)
        else:
            X_train_selected = X_train
            X_test_selected = X_test
        
        # 3. PCA降维
        pca_transformer = None
        if X_train_selected.shape[1] > 100:
            try:
                pca_transformer = PCA(n_components=0.95, random_state=42)
                X_train_pca = pca_transformer.fit_transform(X_train_selected)
                X_test_pca = pca_transformer.transform(X_test_selected)
            except Exception as e:
                X_train_pca = X_train_selected
                X_test_pca = X_test_selected
                pca_transformer = None
        else:
            X_train_pca = X_train_selected
            X_test_pca = X_test_selected
        
        return X_train_pca, X_test_pca, feature_selector, pca_transformer

    def k_fold_cross_validation_all_models(self, features_dict, labels, k=5, optimize_hyperparams=False, save_best_models=True):
        """对所有模型进行K折交叉验证并保存最佳模型"""
        print(f"\n{'='*120}")
        print(f"          K-FOLD CROSS-VALIDATION FOR ALL 8 MODELS + ENSEMBLES (K={k})")
        print(f"{'='*120}")
        print(f"Models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso")
        print(f"Ensembles: Voting (7 models), Stacking (7 models + Lasso)")
        
        all_results = []
        
        # 获取特征数据
        street_features = features_dict['street']
        remote_features = features_dict['remote']
        fusion_features = features_dict['fusion']
        
        for noise_idx, noise_type in enumerate(self.noise_types):
            print(f"\n{'='*100}")
            print(f"NOISE TYPE: {noise_type}")
            print(f"{'='*100}")
            
            y_full = labels[:, noise_idx]
            
            # 初始化该噪声类型的模型存储
            if noise_type not in self.best_models:
                self.best_models[noise_type] = {}
            
            for feature_type in self.feature_types:
                print(f"\n{'-'*100}")
                print(f"Feature Type: {self.feature_names_display[feature_type]}")
                print(f"{'-'*100}")
                
                # 获取对应特征
                if feature_type == 'street':
                    X_full = street_features
                elif feature_type == 'remote':
                    X_full = remote_features
                else:  # fusion
                    X_full = fusion_features
                
                # 初始化该特征类型的模型存储
                if feature_type not in self.best_models[noise_type]:
                    self.best_models[noise_type][feature_type] = {}
                
                # 为每个基础模型进行K折验证
                base_models_results = {}
                
                for model_name in self.model_configs.keys():
                    print(f"\n  Training {model_name}...")
                    
                    kf = KFold(n_splits=k, shuffle=True, random_state=42)
                    fold_scores = {
                        'R²': [], 'RMSE': [], 'MAE': [], 'MSE': []
                    }
                    
                    fold_predictions = []
                    fold_models = []
                    fold_preprocessors = []
                    
                    for fold_num, (train_index, val_index) in enumerate(kf.split(X_full), 1):
                        X_train_fold = X_full[train_index]
                        X_val_fold = X_full[val_index]
                        y_train_fold = y_full[train_index]
                        y_val_fold = y_full[val_index]
                        
                        try:
                            # 预处理
                            X_train_scaled, X_val_scaled, y_train_transformed, scaler, target_transformer = \
                                self.advanced_preprocessing(X_train_fold, X_val_fold, y_train_fold)
                            
                            # 特征工程
                            X_train_final, X_val_final, feature_selector, pca_transformer = \
                                self.advanced_feature_engineering(X_train_scaled, X_val_scaled, y_train_transformed)
                            
                            # 训练模型
                            if optimize_hyperparams and fold_num == 1:
                                model = self.optimize_hyperparameters(
                                    X_train_final, y_train_transformed, model_name, n_iter=10
                                )
                            else:
                                model = self.model_configs[model_name]['class'](
                                    **self.model_configs[model_name]['params']
                                )
                            
                            model.fit(X_train_final, y_train_transformed)
                            fold_models.append(model)
                            
                            # 保存预处理器
                            fold_preprocessors.append({
                                'scaler': scaler,
                                'target_transformer': target_transformer,
                                'feature_selector': feature_selector,
                                'pca_transformer': pca_transformer
                            })
                            
                            # 预测
                            y_pred = model.predict(X_val_final)
                            
                            # 逆变换
                            if target_transformer:
                                y_pred = target_transformer.inverse_transform(
                                    y_pred.reshape(-1, 1)
                                ).flatten()
                            
                            # 计算指标
                            r2 = r2_score(y_val_fold, y_pred)
                            rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred))
                            mae = mean_absolute_error(y_val_fold, y_pred)
                            mse = mean_squared_error(y_val_fold, y_pred)
                            
                            fold_scores['R²'].append(r2)
                            fold_scores['RMSE'].append(rmse)
                            fold_scores['MAE'].append(mae)
                            fold_scores['MSE'].append(mse)
                            
                            fold_predictions.append({
                                'y_true': y_val_fold,
                                'y_pred': y_pred
                            })
                            
                            print(f"    Fold {fold_num}/{k}: R²={r2:.4f}, RMSE={rmse:.4f}, MAE={mae:.4f}")
                            
                        except Exception as e:
                            print(f"    Fold {fold_num}/{k} failed: {e}")
                            continue
                    
                    # 计算平均指标
                    if len(fold_scores['R²']) > 0:
                        mean_r2 = np.mean(fold_scores['R²'])
                        std_r2 = np.std(fold_scores['R²'])
                        mean_rmse = np.mean(fold_scores['RMSE'])
                        std_rmse = np.std(fold_scores['RMSE'])
                        mean_mae = np.mean(fold_scores['MAE'])
                        std_mae = np.std(fold_scores['MAE'])
                        
                        print(f"\n  {model_name} {k}-Fold CV Results:")
                        print(f"    R²:   {mean_r2:.4f} ± {std_r2:.4f}")
                        print(f"    RMSE: {mean_rmse:.4f} ± {std_rmse:.4f}")
                        print(f"    MAE:  {mean_mae:.4f} ± {std_mae:.4f}")
                        
                        all_results.append({
                            'Noise Type': noise_type,
                            'Feature Type': self.feature_names_display[feature_type],
                            'Model': model_name,
                            'Model Type': 'Base',
                            'CV R² Mean': mean_r2,
                            'CV R² Std': std_r2,
                            'CV RMSE Mean': mean_rmse,
                            'CV RMSE Std': std_rmse,
                            'CV MAE Mean': mean_mae,
                            'CV MAE Std': std_mae,
                            'CV MSE Mean': np.mean(fold_scores['MSE']),
                            'CV MSE Std': np.std(fold_scores['MSE'])
                        })
                        
                        # 保存最佳fold的模型（基于R²）
                        best_fold_idx = np.argmax(fold_scores['R²'])
                        self.best_models[noise_type][feature_type][model_name] = {
                            'model': fold_models[best_fold_idx],
                            'preprocessors': fold_preprocessors[best_fold_idx],
                            'cv_scores': fold_scores,
                            'mean_r2': mean_r2,
                            'mean_rmse': mean_rmse,
                            'mean_mae': mean_mae
                        }
                        
                        base_models_results[model_name] = {
                            'models': fold_models,
                            'predictions': fold_predictions,
                            'scores': fold_scores
                        }
                
                # 创建集成模型并进行K折验证
                if len(base_models_results) >= 2:
                    print(f"\n  Creating Ensemble Models...")
                    
                    # Voting Ensemble
                    print(f"\n  Training Voting Ensemble...")
                    voting_result = self._k_fold_ensemble_voting(
                        X_full, y_full, k, noise_type, feature_type
                    )
                    
                    if voting_result:
                        all_results.append({
                            'Noise Type': noise_type,
                            'Feature Type': self.feature_names_display[feature_type],
                            'Model': 'Voting',
                            'Model Type': 'Ensemble',
                            'CV R² Mean': voting_result['scores']['mean_r2'],
                            'CV R² Std': voting_result['scores']['std_r2'],
                            'CV RMSE Mean': voting_result['scores']['mean_rmse'],
                            'CV RMSE Std': voting_result['scores']['std_rmse'],
                            'CV MAE Mean': voting_result['scores']['mean_mae'],
                            'CV MAE Std': voting_result['scores']['std_mae'],
                            'CV MSE Mean': voting_result['scores']['mean_mse'],
                            'CV MSE Std': voting_result['scores']['std_mse']
                        })
                        
                        # 保存Voting模型
                        self.best_models[noise_type][feature_type]['Voting'] = voting_result
                    
                    # Stacking Ensemble
                    print(f"\n  Training Stacking Ensemble...")
                    stacking_result = self._k_fold_ensemble_stacking(
                        X_full, y_full, k, noise_type, feature_type
                    )
                    
                    if stacking_result:
                        all_results.append({
                            'Noise Type': noise_type,
                            'Feature Type': self.feature_names_display[feature_type],
                            'Model': 'Stacking',
                            'Model Type': 'Ensemble',
                            'CV R² Mean': stacking_result['scores']['mean_r2'],
                            'CV R² Std': stacking_result['scores']['std_r2'],
                            'CV RMSE Mean': stacking_result['scores']['mean_rmse'],
                            'CV RMSE Std': stacking_result['scores']['std_rmse'],
                            'CV MAE Mean': stacking_result['scores']['mean_mae'],
                            'CV MAE Std': stacking_result['scores']['std_mae'],
                            'CV MSE Mean': stacking_result['scores']['mean_mse'],
                            'CV MSE Std': stacking_result['scores']['std_mse']
                        })
                        
                        # 保存Stacking模型
                        self.best_models[noise_type][feature_type]['Stacking'] = stacking_result
        
        # 创建结果DataFrame
        results_df = pd.DataFrame(all_results)
        
        # 显示结果
        self._display_kfold_results(results_df)
        
        # 保存结果
        results_df.to_csv('comprehensive_kfold_results.csv', index=False)
        print(f"\n{'='*120}")
        print(f"Results saved to 'comprehensive_kfold_results.csv'")
        
        # 保存所有最佳模型
        if save_best_models:
            self.save_all_models()
        
        print(f"{'='*120}")
        
        return results_df

    def _k_fold_ensemble_voting(self, X_full, y_full, k, noise_type, feature_type):
        """Voting集成的K折验证"""
        kf = KFold(n_splits=k, shuffle=True, random_state=42)
        fold_scores = {'R²': [], 'RMSE': [], 'MAE': [], 'MSE': []}
        fold_models = []
        fold_preprocessors = []
        
        for fold_num, (train_index, val_index) in enumerate(kf.split(X_full), 1):
            X_train_fold = X_full[train_index]
            X_val_fold = X_full[val_index]
            y_train_fold = y_full[train_index]
            y_val_fold = y_full[val_index]
            
            try:
                # 预处理
                X_train_scaled, X_val_scaled, y_train_transformed, scaler, target_transformer = \
                    self.advanced_preprocessing(X_train_fold, X_val_fold, y_train_fold)
                
                X_train_final, X_val_final, feature_selector, pca_transformer = \
                    self.advanced_feature_engineering(X_train_scaled, X_val_scaled, y_train_transformed)
                
                # 创建并训练Voting模型
                estimators = []
                for model_name in self.model_configs.keys():
                    model = self.model_configs[model_name]['class'](
                        **self.model_configs[model_name]['params']
                    )
                    estimators.append((model_name, model))
                
                voting_model = VotingRegressor(estimators=estimators)
                voting_model.fit(X_train_final, y_train_transformed)
                fold_models.append(voting_model)
                
                # 保存预处理器
                fold_preprocessors.append({
                    'scaler': scaler,
                    'target_transformer': target_transformer,
                    'feature_selector': feature_selector,
                    'pca_transformer': pca_transformer
                })
                
                # 预测
                y_pred = voting_model.predict(X_val_final)
                
                if target_transformer:
                    y_pred = target_transformer.inverse_transform(
                        y_pred.reshape(-1, 1)
                    ).flatten()
                
                # 计算指标
                r2 = r2_score(y_val_fold, y_pred)
                rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred))
                mae = mean_absolute_error(y_val_fold, y_pred)
                mse = mean_squared_error(y_val_fold, y_pred)
                
                fold_scores['R²'].append(r2)
                fold_scores['RMSE'].append(rmse)
                fold_scores['MAE'].append(mae)
                fold_scores['MSE'].append(mse)
                
                print(f"    Fold {fold_num}/{k}: R²={r2:.4f}, RMSE={rmse:.4f}, MAE={mae:.4f}")
                
            except Exception as e:
                print(f"    Fold {fold_num}/{k} failed: {e}")
                continue
        
        if len(fold_scores['R²']) > 0:
            mean_r2 = np.mean(fold_scores['R²'])
            std_r2 = np.std(fold_scores['R²'])
            mean_rmse = np.mean(fold_scores['RMSE'])
            std_rmse = np.std(fold_scores['RMSE'])
            mean_mae = np.mean(fold_scores['MAE'])
            std_mae = np.std(fold_scores['MAE'])
            
            print(f"\n  Voting Ensemble {k}-Fold CV Results:")
            print(f"    R²:   {mean_r2:.4f} ± {std_r2:.4f}")
            print(f"    RMSE: {mean_rmse:.4f} ± {std_rmse:.4f}")
            print(f"    MAE:  {mean_mae:.4f} ± {std_mae:.4f}")
            
            # 返回最佳fold的模型
            best_fold_idx = np.argmax(fold_scores['R²'])
            
            return {
                'model': fold_models[best_fold_idx],
                'preprocessors': fold_preprocessors[best_fold_idx],
                'cv_scores': fold_scores,
                'scores': {
                    'mean_r2': mean_r2,
                    'std_r2': std_r2,
                    'mean_rmse': mean_rmse,
                    'std_rmse': std_rmse,
                    'mean_mae': mean_mae,
                    'std_mae': std_mae,
                    'mean_mse': np.mean(fold_scores['MSE']),
                    'std_mse': np.std(fold_scores['MSE'])
                }
            }
        return None

    def _k_fold_ensemble_stacking(self, X_full, y_full, k, noise_type, feature_type):
        """Stacking集成的K折验证"""
        kf = KFold(n_splits=k, shuffle=True, random_state=42)
        fold_scores = {'R²': [], 'RMSE': [], 'MAE': [], 'MSE': []}
        fold_models = []
        fold_preprocessors = []
        
        for fold_num, (train_index, val_index) in enumerate(kf.split(X_full), 1):
            X_train_fold = X_full[train_index]
            X_val_fold = X_full[val_index]
            y_train_fold = y_full[train_index]
            y_val_fold = y_full[val_index]
            
            try:
                # 预处理
                X_train_scaled, X_val_scaled, y_train_transformed, scaler, target_transformer = \
                    self.advanced_preprocessing(X_train_fold, X_val_fold, y_train_fold)
                
                X_train_final, X_val_final, feature_selector, pca_transformer = \
                    self.advanced_feature_engineering(X_train_scaled, X_val_scaled, y_train_transformed)
                
                # 创建并训练Stacking模型
                estimators = []
                for model_name in self.model_configs.keys():
                    model = self.model_configs[model_name]['class'](
                        **self.model_configs[model_name]['params']
                    )
                    estimators.append((model_name, model))
                
                stacking_model = StackingRegressor(
                    estimators=estimators,
                    final_estimator=Lasso(alpha=1.0, random_state=42),
                    cv=5,
                    n_jobs=-1
                )
                stacking_model.fit(X_train_final, y_train_transformed)
                fold_models.append(stacking_model)
                
                # 保存预处理器
                fold_preprocessors.append({
                    'scaler': scaler,
                    'target_transformer': target_transformer,
                    'feature_selector': feature_selector,
                    'pca_transformer': pca_transformer
                })
                
                # 预测
                y_pred = stacking_model.predict(X_val_final)
                
                if target_transformer:
                    y_pred = target_transformer.inverse_transform(
                        y_pred.reshape(-1, 1)
                    ).flatten()
                
                # 计算指标
                r2 = r2_score(y_val_fold, y_pred)
                rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred))
                mae = mean_absolute_error(y_val_fold, y_pred)
                mse = mean_squared_error(y_val_fold, y_pred)
                
                fold_scores['R²'].append(r2)
                fold_scores['RMSE'].append(rmse)
                fold_scores['MAE'].append(mae)
                fold_scores['MSE'].append(mse)
                
                print(f"    Fold {fold_num}/{k}: R²={r2:.4f}, RMSE={rmse:.4f}, MAE={mae:.4f}")
                
            except Exception as e:
                print(f"    Fold {fold_num}/{k} failed: {e}")
                continue
        
        if len(fold_scores['R²']) > 0:
            mean_r2 = np.mean(fold_scores['R²'])
            std_r2 = np.std(fold_scores['R²'])
            mean_rmse = np.mean(fold_scores['RMSE'])
            std_rmse = np.std(fold_scores['RMSE'])
            mean_mae = np.mean(fold_scores['MAE'])
            std_mae = np.std(fold_scores['MAE'])
            
            print(f"\n  Stacking Ensemble {k}-Fold CV Results:")
            print(f"    R²:   {mean_r2:.4f} ± {std_r2:.4f}")
            print(f"    RMSE: {mean_rmse:.4f} ± {std_rmse:.4f}")
            print(f"    MAE:  {mean_mae:.4f} ± {std_mae:.4f}")
            
            # 返回最佳fold的模型
            best_fold_idx = np.argmax(fold_scores['R²'])
            
            return {
                'model': fold_models[best_fold_idx],
                'preprocessors': fold_preprocessors[best_fold_idx],
                'cv_scores': fold_scores,
                'scores': {
                    'mean_r2': mean_r2,
                    'std_r2': std_r2,
                    'mean_rmse': mean_rmse,
                    'std_rmse': std_rmse,
                    'mean_mae': mean_mae,
                    'std_mae': std_mae,
                    'mean_mse': np.mean(fold_scores['MSE']),
                    'std_mse': np.std(fold_scores['MSE'])
                }
            }
        return None

    def optimize_hyperparameters(self, X_train, y_train, model_name, n_iter=10):
        """超参数优化"""
        if 'param_grid' not in self.model_configs[model_name]:
            return self.model_configs[model_name]['class'](
                **self.model_configs[model_name]['params']
            )
        
        model_class = self.model_configs[model_name]['class']
        param_grid = self.model_configs[model_name]['param_grid']
        
        # 创建基础模型
        if model_name in ['XGBoost', 'LightGBM']:
            base_params = {'random_state': 42, 'n_jobs': -1}
            if model_name == 'XGBoost':
                base_params['verbosity'] = 0
            else:
                base_params['verbose'] = -1
            base_model = model_class(**base_params)
        elif model_name == 'KNN':
            base_model = model_class(n_jobs=-1)
        elif model_name == 'Lasso':
            base_model = model_class(random_state=42)
        else:
            base_model = model_class(random_state=42)
        
        random_search = RandomizedSearchCV(
            base_model,
            param_grid,
            n_iter=n_iter,
            cv=3,
            scoring='r2',
            n_jobs=-1,
            random_state=42,
            verbose=0
        )
        
        try:
            random_search.fit(X_train, y_train)
            return random_search.best_estimator_
        except Exception as e:
            return self.model_configs[model_name]['class'](
                **self.model_configs[model_name]['params']
            )

    def save_all_models(self, save_dir='saved_models'):
        """保存所有最佳模型和预处理器"""
        print(f"\n{'='*120}")
        print("SAVING ALL BEST MODELS...")
        print(f"{'='*120}")
        
        # 创建主目录
        os.makedirs(save_dir, exist_ok=True)
        
        saved_count = 0
        
        for noise_type in self.noise_types:
            if noise_type not in self.best_models:
                continue
                
            # 创建噪声类型目录
            noise_dir = os.path.join(save_dir, noise_type.replace(' ', '_'))
            os.makedirs(noise_dir, exist_ok=True)
            
            for feature_type in self.feature_types:
                if feature_type not in self.best_models[noise_type]:
                    continue
                
                # 创建特征类型目录
                feature_dir = os.path.join(noise_dir, feature_type)
                os.makedirs(feature_dir, exist_ok=True)
                
                for model_name, model_data in self.best_models[noise_type][feature_type].items():
                    try:
                        # 保存模型
                        model_path = os.path.join(feature_dir, f'{model_name}_model.pkl')
                        joblib.dump(model_data['model'], model_path)
                        
                        # 保存预处理器
                        preprocessor_path = os.path.join(feature_dir, f'{model_name}_preprocessors.pkl')
                        joblib.dump(model_data['preprocessors'], preprocessor_path)
                        
                        # 保存模型信息
                        info = {
                            'noise_type': noise_type,
                            'feature_type': feature_type,
                            'model_name': model_name,
                            'mean_r2': model_data.get('mean_r2', model_data.get('scores', {}).get('mean_r2', 0)),
                            'mean_rmse': model_data.get('mean_rmse', model_data.get('scores', {}).get('mean_rmse', 0)),
                            'mean_mae': model_data.get('mean_mae', model_data.get('scores', {}).get('mean_mae', 0))
                        }
                        info_path = os.path.join(feature_dir, f'{model_name}_info.pkl')
                        joblib.dump(info, info_path)
                        
                        saved_count += 1
                        print(f"  ✓ Saved: {noise_type} - {feature_type} - {model_name}")
                        
                    except Exception as e:
                        print(f"  ✗ Failed to save {noise_type} - {feature_type} - {model_name}: {e}")
        
        # 保存完整的predictor对象
        try:
            predictor_path = os.path.join(save_dir, 'predictor_complete.pkl')
            joblib.dump(self, predictor_path)
            print(f"\n  ✓ Saved complete predictor object")
        except Exception as e:
            print(f"\n  ✗ Failed to save complete predictor: {e}")
        
        print(f"\n{'='*120}")
        print(f"Successfully saved {saved_count} models to '{save_dir}' directory")
        print(f"{'='*120}")

    def load_saved_model(self, noise_type, feature_type, model_name, save_dir='saved_models'):
        """加载保存的模型"""
        noise_dir = os.path.join(save_dir, noise_type.replace(' ', '_'))
        feature_dir = os.path.join(noise_dir, feature_type)
        
        # 加载模型
        model_path = os.path.join(feature_dir, f'{model_name}_model.pkl')
        model = joblib.load(model_path)
        
        # 加载预处理器
        preprocessor_path = os.path.join(feature_dir, f'{model_name}_preprocessors.pkl')
        preprocessors = joblib.load(preprocessor_path)
        
        # 加载模型信息
        info_path = os.path.join(feature_dir, f'{model_name}_info.pkl')
        info = joblib.load(info_path)
        
        print(f"Loaded model: {noise_type} - {feature_type} - {model_name}")
        print(f"  R²: {info['mean_r2']:.4f}")
        print(f"  RMSE: {info['mean_rmse']:.4f}")
        print(f"  MAE: {info['mean_mae']:.4f}")
        
        return model, preprocessors, info

    def predict_with_saved_model(self, X_new, noise_type, feature_type, model_name, save_dir='saved_models'):
        """使用保存的模型进行预测"""
        # 加载模型和预处理器
        model, preprocessors, info = self.load_saved_model(
            noise_type, feature_type, model_name, save_dir
        )
        
        # 应用预处理
        X_processed = X_new
        
        if preprocessors['scaler'] is not None:
            X_processed = preprocessors['scaler'].transform(X_processed)
        
        if preprocessors['feature_selector'] is not None:
            X_processed = preprocessors['feature_selector'].transform(X_processed)
        
        if preprocessors['pca_transformer'] is not None:
            X_processed = preprocessors['pca_transformer'].transform(X_processed)
        
        # 预测
        y_pred = model.predict(X_processed)
        
        # 逆变换
        if preprocessors['target_transformer'] is not None:
            y_pred = preprocessors['target_transformer'].inverse_transform(
                y_pred.reshape(-1, 1)
            ).flatten()
        
        return y_pred

    @staticmethod
    def load_complete_predictor(save_dir='saved_models'):
        """加载完整的predictor对象"""
        predictor_path = os.path.join(save_dir, 'predictor_complete.pkl')
        predictor = joblib.load(predictor_path)
        print(f"Loaded complete predictor from '{save_dir}'")
        return predictor

    def _display_kfold_results(self, results_df):
        """显示K折验证结果"""
        print(f"\n{'='*120}")
        print("                          K-FOLD CROSS-VALIDATION RESULTS SUMMARY")
        print(f"{'='*120}")
        
        # 按噪声类型分组显示
        for noise_type in self.noise_types:
            print(f"\n{'='*100}")
            print(f"NOISE TYPE: {noise_type}")
            print(f"{'='*100}")
            
            subset = results_df[results_df['Noise Type'] == noise_type]
            
            if not subset.empty:
                # 按R²排序并显示前10名
                top_models = subset.nlargest(10, 'CV R² Mean')
                
                print(f"\nTop 10 Models (by R² Score):")
                print("-" * 100)
                for idx, row in top_models.iterrows():
                    print(f"{row['Model']:20} ({row['Model Type']:10}) + {row['Feature Type']:15}")
                    print(f"  R²:   {row['CV R² Mean']:.4f} ± {row['CV R² Std']:.4f}")
                    print(f"  RMSE: {row['CV RMSE Mean']:.4f} ± {row['CV RMSE Std']:.4f}")
                    print(f"  MAE:  {row['CV MAE Mean']:.4f} ± {row['CV MAE Std']:.4f}")
                    print("-" * 100)
        
        # 显示整体最佳模型
        print(f"\n{'='*120}")
        print("                          OVERALL TOP 10 BEST MODELS")
        print(f"{'='*120}")
        
        overall_best = results_df.nlargest(10, 'CV R² Mean')
        for idx, row in overall_best.iterrows():
            print(f"\n{row['Model']:20} ({row['Model Type']:10})")
            print(f"  Noise: {row['Noise Type']}, Features: {row['Feature Type']}")
            print(f"  R²:   {row['CV R² Mean']:.4f} ± {row['CV R² Std']:.4f}")
            print(f"  RMSE: {row['CV RMSE Mean']:.4f} ± {row['CV RMSE Std']:.4f}")
            print(f"  MAE:  {row['CV MAE Mean']:.4f} ± {row['CV MAE Std']:.4f}")
        
        print(f"\n{'='*120}")


# ============ 主程序调用 ============
if __name__ == "__main__":
    # 创建预测器
    predictor = ComprehensiveKFoldNoisePredictor()

    # 文件路径
    street_view_path = './revise_data/features_dinov3-vitb16-pretrain-lvd1689m.npy'
    remote_sensing_path = './revise_data/features_dinov3-vitl16-pretrain-sat493m.npy'
    noise_labels_path = './revise_data/noise_labels_25.npy'

    try:
        # 加载数据
        print("Loading data...")
        street_features, remote_features, fusion_features, labels = predictor.load_data(
            street_view_path, remote_sensing_path, noise_labels_path
        )
        
        # 准备特征字典
        features_dict = {
            'street': street_features,
            'remote': remote_features,
            'fusion': fusion_features
        }
        
        # 执行K折交叉验证并保存模型
        print("\nStarting comprehensive K-fold cross-validation...")
        results_df = predictor.k_fold_cross_validation_all_models(
            features_dict=features_dict,
            labels=labels,
            k=5,  # 5折交叉验证
            optimize_hyperparams=False,  # 设为True可启用超参数优化（会更慢）
            save_best_models=True  # 自动保存所有最佳模型
        )
        
        print(f"\n{'='*120}")
        print("                           EXPERIMENT COMPLETED SUCCESSFULLY")
        print(f"{'='*120}")
        print("\nSummary:")
        print("• Total models evaluated: 9 (7 base models + 2 ensemble models)")
        print("• Base models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso")
        print("• Ensemble models: Voting (7 models), Stacking (7 models + Lasso)")
        print("• Feature types: Street View, Remote Sensing, Fusion")
        print("• Noise types: Mean Noise, Low Freq, Mid Freq, High Freq")
        print("• Cross-validation: 5-fold")
        print("• Metrics: R², RMSE, MAE, MSE (all with mean ± std)")
        print("• All models saved to 'saved_models/' directory")
        print("\nResults saved to 'comprehensive_kfold_results.csv'")
        
        # ============ 演示如何使用保存的模型 ============
        print(f"\n{'='*120}")
        print("DEMONSTRATION: How to Load and Use Saved Models")
        print(f"{'='*120}")
        
        # 示例1: 加载单个模型
        print("\n1. Loading a single model:")
        try:
            model, preprocessors, info = predictor.load_saved_model(
                noise_type='Mean Noise',
                feature_type='fusion',
                model_name='XGBoost',
                save_dir='saved_models'
            )
        except:
            print("  (Model not found - will be available after training)")
        
        # 示例2: 使用保存的模型进行预测
        print("\n2. Making predictions with a saved model:")
        print("  predictions = predictor.predict_with_saved_model(")
        print("      X_new=new_data,")
        print("      noise_type='Mean Noise',")
        print("      feature_type='fusion',")
        print("      model_name='XGBoost'")
        print("  )")
        
        # 示例3: 加载完整的predictor
        print("\n3. Loading complete predictor:")
        print("  loaded_predictor = ComprehensiveKFoldNoisePredictor.load_complete_predictor('saved_models')")
        
    except FileNotFoundError as e:
        print(f"File not found: {e}")
        print("Please ensure the following files exist:")
        print(f"- {street_view_path}")
        print(f"- {remote_sensing_path}")
        print(f"- {noise_labels_path}")
    except Exception as e:
        print(f"Error occurred: {e}")
        import traceback
        traceback.print_exc()
# Out:
# Loading data...
# Street view features shape: (923, 768)
# Remote sensing features shape: (923, 1024)
# Noise labels shape: (923, 4)
#
# Starting comprehensive K-fold cross-validation...
#
# ========================================================================================================================
#           K-FOLD CROSS-VALIDATION FOR ALL 8 MODELS + ENSEMBLES (K=5)
# ========================================================================================================================
# Models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso
# Ensembles: Voting (7 models), Stacking (7 models + Lasso)
#
# ====================================================================================================
# NOISE TYPE: Mean Noise
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3822, RMSE=2.8377, MAE=2.3427
#     Fold 2/5: R²=0.2627, RMSE=3.1293, MAE=2.4382
#     Fold 3/5: R²=0.2944, RMSE=3.3126, MAE=2.4554
#     Fold 4/5: R²=0.2802, RMSE=3.1211, MAE=2.4876
#     Fold 5/5: R²=0.2302, RMSE=3.4768, MAE=2.7839
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2900 ± 0.0509
#     RMSE: 3.1755 ± 0.2139
#     MAE:  2.5016 ± 0.1492
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3537, RMSE=2.9025, MAE=2.4027
#     Fold 2/5: R²=0.2791, RMSE=3.0944, MAE=2.4586
#     Fold 3/5: R²=0.2267, RMSE=3.4679, MAE=2.6020
#     Fold 4/5: R²=0.2898, RMSE=3.1003, MAE=2.4565
#     Fold 5/5: R²=0.2404, RMSE=3.4537, MAE=2.7433
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2779 ± 0.0445
#     RMSE: 3.2037 ± 0.2217
#     MAE:  2.5326 ± 0.1244
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2304, RMSE=3.1673, MAE=2.6434
#     Fold 2/5: R²=0.1817, RMSE=3.2967, MAE=2.5645
#     Fold 3/5: R²=0.1858, RMSE=3.5585, MAE=2.6883
#     Fold 4/5: R²=0.1884, RMSE=3.3142, MAE=2.5884
#     Fold 5/5: R²=0.1771, RMSE=3.5947, MAE=2.8411
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1927 ± 0.0192
#     RMSE: 3.3863 ± 0.1639
#     MAE:  2.6652 ± 0.0980
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3462, RMSE=2.9192, MAE=2.4148
#     Fold 2/5: R²=0.2651, RMSE=3.1243, MAE=2.4478
#     Fold 3/5: R²=0.2974, RMSE=3.3055, MAE=2.4465
#     Fold 4/5: R²=0.3232, RMSE=3.0265, MAE=2.4509
#     Fold 5/5: R²=0.2245, RMSE=3.4898, MAE=2.7868
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2913 ± 0.0429
#     RMSE: 3.1731 ± 0.2030
#     MAE:  2.5093 ± 0.1393
#
#   Training SVR...
#     Fold 1/5: R²=0.4417, RMSE=2.6976, MAE=2.1369
#     Fold 2/5: R²=0.3186, RMSE=3.0084, MAE=2.2954
#     Fold 3/5: R²=0.3332, RMSE=3.2203, MAE=2.3828
#     Fold 4/5: R²=0.4242, RMSE=2.7916, MAE=2.1797
#     Fold 5/5: R²=0.3182, RMSE=3.2720, MAE=2.5937
#
#   SVR 5-Fold CV Results:
#     R²:   0.3672 ± 0.0542
#     RMSE: 2.9980 ± 0.2269
#     MAE:  2.3177 ± 0.1629
#
#   Training KNN...
#     Fold 1/5: R²=0.4494, RMSE=2.6789, MAE=2.1755
#     Fold 2/5: R²=0.3826, RMSE=2.8636, MAE=2.1812
#     Fold 3/5: R²=0.3567, RMSE=3.1630, MAE=2.3413
#     Fold 4/5: R²=0.3919, RMSE=2.8688, MAE=2.2513
#     Fold 5/5: R²=0.2687, RMSE=3.3888, MAE=2.6167
#
#   KNN 5-Fold CV Results:
#     R²:   0.3699 ± 0.0590
#     RMSE: 2.9926 ± 0.2515
#     MAE:  2.3132 ± 0.1632
#
#   Training Lasso...
#     Fold 1/5: R²=0.3597, RMSE=2.8890, MAE=2.3854
#     Fold 2/5: R²=0.2194, RMSE=3.2200, MAE=2.5240
#     Fold 3/5: R²=0.2607, RMSE=3.3908, MAE=2.4704
#     Fold 4/5: R²=0.2495, RMSE=3.1869, MAE=2.5033
#     Fold 5/5: R²=0.2844, RMSE=3.3522, MAE=2.7431
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2747 ± 0.0473
#     RMSE: 3.2078 ± 0.1770
#     MAE:  2.5252 ± 0.1187
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4285, RMSE=2.7293, MAE=2.2537
#     Fold 2/5: R²=0.3294, RMSE=2.9846, MAE=2.3122
#     Fold 3/5: R²=0.3326, RMSE=3.2216, MAE=2.3750
#     Fold 4/5: R²=0.3749, RMSE=2.9086, MAE=2.3202
#     Fold 5/5: R²=0.3009, RMSE=3.3132, MAE=2.6277
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3533 ± 0.0444
#     RMSE: 3.0315 ± 0.2117
#     MAE:  2.3778 ± 0.1308
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3580, RMSE=2.8928, MAE=2.3912
#     Fold 2/5: R²=0.2843, RMSE=3.0832, MAE=2.4069
#     Fold 3/5: R²=0.2775, RMSE=3.3521, MAE=2.4866
#     Fold 4/5: R²=0.3224, RMSE=3.0283, MAE=2.3731
#     Fold 5/5: R²=0.2683, RMSE=3.3897, MAE=2.6952
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.3021 ± 0.0335
#     RMSE: 3.1492 ± 0.1917
#     MAE:  2.4706 ± 0.1188
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2601, RMSE=3.1055, MAE=2.5348
#     Fold 2/5: R²=0.2415, RMSE=3.1741, MAE=2.3806
#     Fold 3/5: R²=0.2918, RMSE=3.3187, MAE=2.4368
#     Fold 4/5: R²=0.3037, RMSE=3.0698, MAE=2.4303
#     Fold 5/5: R²=0.1997, RMSE=3.5451, MAE=2.8041
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2594 ± 0.0371
#     RMSE: 3.2426 ± 0.1736
#     MAE:  2.5173 ± 0.1519
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2705, RMSE=3.0836, MAE=2.4953
#     Fold 2/5: R²=0.2466, RMSE=3.1634, MAE=2.4575
#     Fold 3/5: R²=0.3178, RMSE=3.2572, MAE=2.3785
#     Fold 4/5: R²=0.3349, RMSE=3.0002, MAE=2.4334
#     Fold 5/5: R²=0.2747, RMSE=3.3749, MAE=2.6361
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2889 ± 0.0325
#     RMSE: 3.1759 ± 0.1310
#     MAE:  2.4802 ± 0.0867
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1902, RMSE=3.2490, MAE=2.6767
#     Fold 2/5: R²=0.1795, RMSE=3.3012, MAE=2.5670
#     Fold 3/5: R²=0.2227, RMSE=3.4769, MAE=2.5744
#     Fold 4/5: R²=0.1888, RMSE=3.3133, MAE=2.6172
#     Fold 5/5: R²=0.1597, RMSE=3.6326, MAE=2.8540
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1882 ± 0.0204
#     RMSE: 3.3946 ± 0.1414
#     MAE:  2.6579 ± 0.1055
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2212, RMSE=3.1861, MAE=2.6085
#     Fold 2/5: R²=0.2271, RMSE=3.2040, MAE=2.4264
#     Fold 3/5: R²=0.3044, RMSE=3.2891, MAE=2.4221
#     Fold 4/5: R²=0.2739, RMSE=3.1348, MAE=2.4722
#     Fold 5/5: R²=0.1532, RMSE=3.6466, MAE=2.8634
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2359 ± 0.0515
#     RMSE: 3.2921 ± 0.1841
#     MAE:  2.5585 ± 0.1667
#
#   Training SVR...
#     Fold 1/5: R²=0.3729, RMSE=2.8590, MAE=2.2835
#     Fold 2/5: R²=0.3021, RMSE=3.0447, MAE=2.3534
#     Fold 3/5: R²=0.3687, RMSE=3.1334, MAE=2.2956
#     Fold 4/5: R²=0.4175, RMSE=2.8077, MAE=2.1708
#     Fold 5/5: R²=0.4098, RMSE=3.0444, MAE=2.3829
#
#   SVR 5-Fold CV Results:
#     R²:   0.3742 ± 0.0409
#     RMSE: 2.9778 ± 0.1234
#     MAE:  2.2972 ± 0.0730
#
#   Training KNN...
#     Fold 1/5: R²=0.3801, RMSE=2.8425, MAE=2.3035
#     Fold 2/5: R²=0.2965, RMSE=3.0567, MAE=2.3189
#     Fold 3/5: R²=0.2393, RMSE=3.4396, MAE=2.4920
#     Fold 4/5: R²=0.3795, RMSE=2.8977, MAE=2.2201
#     Fold 5/5: R²=0.2919, RMSE=3.3345, MAE=2.5480
#
#   KNN 5-Fold CV Results:
#     R²:   0.3175 ± 0.0547
#     RMSE: 3.1142 ± 0.2360
#     MAE:  2.3765 ± 0.1232
#
#   Training Lasso...
#     Fold 1/5: R²=0.3335, RMSE=2.9475, MAE=2.3615
#     Fold 2/5: R²=0.1596, RMSE=3.3411, MAE=2.6146
#     Fold 3/5: R²=0.2329, RMSE=3.4539, MAE=2.5154
#     Fold 4/5: R²=0.2759, RMSE=3.1305, MAE=2.4654
#     Fold 5/5: R²=0.2768, RMSE=3.3700, MAE=2.5577
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2557 ± 0.0577
#     RMSE: 3.2486 ± 0.1844
#     MAE:  2.5029 ± 0.0861
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3521, RMSE=2.9061, MAE=2.3841
#     Fold 2/5: R²=0.3038, RMSE=3.0409, MAE=2.3212
#     Fold 3/5: R²=0.3444, RMSE=3.1931, MAE=2.3200
#     Fold 4/5: R²=0.3756, RMSE=2.9069, MAE=2.2974
#     Fold 5/5: R²=0.3100, RMSE=3.2917, MAE=2.5632
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3372 ± 0.0269
#     RMSE: 3.0678 ± 0.1540
#     MAE:  2.3772 ± 0.0974
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2242, RMSE=3.1799, MAE=2.6320
#     Fold 2/5: R²=0.1616, RMSE=3.3370, MAE=2.6135
#     Fold 3/5: R²=0.1536, RMSE=3.6281, MAE=2.6909
#     Fold 4/5: R²=0.2510, RMSE=3.1837, MAE=2.4994
#     Fold 5/5: R²=0.1588, RMSE=3.6345, MAE=2.8536
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1899 ± 0.0400
#     RMSE: 3.3927 ± 0.2029
#     MAE:  2.6579 ± 0.1159
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4262, RMSE=2.7348, MAE=2.2233
#     Fold 2/5: R²=0.2828, RMSE=3.0864, MAE=2.3909
#     Fold 3/5: R²=0.2933, RMSE=3.3153, MAE=2.4736
#     Fold 4/5: R²=0.3451, RMSE=2.9770, MAE=2.3450
#     Fold 5/5: R²=0.3006, RMSE=3.3141, MAE=2.6032
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3296 ± 0.0528
#     RMSE: 3.0855 ± 0.2190
#     MAE:  2.4072 ± 0.1271
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3942, RMSE=2.8100, MAE=2.2375
#     Fold 2/5: R²=0.2659, RMSE=3.1226, MAE=2.4059
#     Fold 3/5: R²=0.3281, RMSE=3.2326, MAE=2.4110
#     Fold 4/5: R²=0.3473, RMSE=2.9720, MAE=2.3227
#     Fold 5/5: R²=0.3106, RMSE=3.2903, MAE=2.6230
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3292 ± 0.0422
#     RMSE: 3.0855 ± 0.1753
#     MAE:  2.4000 ± 0.1282
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2446, RMSE=3.1379, MAE=2.5851
#     Fold 2/5: R²=0.1851, RMSE=3.2899, MAE=2.5640
#     Fold 3/5: R²=0.2157, RMSE=3.4924, MAE=2.6335
#     Fold 4/5: R²=0.2149, RMSE=3.2596, MAE=2.4989
#     Fold 5/5: R²=0.1832, RMSE=3.5814, MAE=2.8096
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2087 ± 0.0227
#     RMSE: 3.3522 ± 0.1616
#     MAE:  2.6182 ± 0.1050
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.4106, RMSE=2.7719, MAE=2.2526
#     Fold 2/5: R²=0.2421, RMSE=3.1728, MAE=2.4483
#     Fold 3/5: R²=0.2962, RMSE=3.3083, MAE=2.5178
#     Fold 4/5: R²=0.3126, RMSE=3.0501, MAE=2.3890
#     Fold 5/5: R²=0.2751, RMSE=3.3740, MAE=2.6560
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3073 ± 0.0567
#     RMSE: 3.1354 ± 0.2134
#     MAE:  2.4527 ± 0.1339
#
#   Training SVR...
#     Fold 1/5: R²=0.4730, RMSE=2.6210, MAE=2.0520
#     Fold 2/5: R²=0.3475, RMSE=2.9439, MAE=2.2423
#     Fold 3/5: R²=0.3571, RMSE=3.1621, MAE=2.3172
#     Fold 4/5: R²=0.5034, RMSE=2.5924, MAE=1.9914
#     Fold 5/5: R²=0.4014, RMSE=3.0659, MAE=2.3763
#
#   SVR 5-Fold CV Results:
#     R²:   0.4165 ± 0.0621
#     RMSE: 2.8771 ± 0.2315
#     MAE:  2.1958 ± 0.1496
#
#   Training KNN...
#     Fold 1/5: R²=0.5113, RMSE=2.5240, MAE=2.0619
#     Fold 2/5: R²=0.4043, RMSE=2.8129, MAE=2.0378
#     Fold 3/5: R²=0.2830, RMSE=3.3393, MAE=2.4202
#     Fold 4/5: R²=0.5003, RMSE=2.6006, MAE=2.0276
#     Fold 5/5: R²=0.2922, RMSE=3.3338, MAE=2.5551
#
#   KNN 5-Fold CV Results:
#     R²:   0.3982 ± 0.0977
#     RMSE: 2.9221 ± 0.3514
#     MAE:  2.2205 ± 0.2225
#
#   Training Lasso...
#     Fold 1/5: R²=0.3832, RMSE=2.8355, MAE=2.2277
#     Fold 2/5: R²=0.2394, RMSE=3.1784, MAE=2.4613
#     Fold 3/5: R²=0.3161, RMSE=3.2612, MAE=2.4198
#     Fold 4/5: R²=0.3433, RMSE=2.9813, MAE=2.3889
#     Fold 5/5: R²=0.3249, RMSE=3.2559, MAE=2.5573
#
#   Lasso 5-Fold CV Results:
#     R²:   0.3214 ± 0.0470
#     RMSE: 3.1025 ± 0.1676
#     MAE:  2.4110 ± 0.1078
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4625, RMSE=2.6469, MAE=2.1557
#     Fold 2/5: R²=0.3364, RMSE=2.9687, MAE=2.2702
#     Fold 3/5: R²=0.3568, RMSE=3.1627, MAE=2.3163
#     Fold 4/5: R²=0.4252, RMSE=2.7892, MAE=2.1583
#     Fold 5/5: R²=0.3488, RMSE=3.1978, MAE=2.5077
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3859 ± 0.0491
#     RMSE: 2.9531 ± 0.2120
#     MAE:  2.2817 ± 0.1292
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3846, RMSE=2.8323, MAE=2.3428
#     Fold 2/5: R²=0.2144, RMSE=3.2302, MAE=2.5312
#     Fold 3/5: R²=0.2376, RMSE=3.4434, MAE=2.5569
#     Fold 4/5: R²=0.3781, RMSE=2.9011, MAE=2.2467
#     Fold 5/5: R²=0.2873, RMSE=3.3454, MAE=2.6022
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.3004 ± 0.0702
#     RMSE: 3.1505 ± 0.2423
#     MAE:  2.4560 ± 0.1370
#
# ====================================================================================================
# NOISE TYPE: Low Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.1992, RMSE=3.1446, MAE=2.4163
#     Fold 2/5: R²=0.2393, RMSE=3.3388, MAE=2.7594
#     Fold 3/5: R²=0.2759, RMSE=3.3096, MAE=2.4611
#     Fold 4/5: R²=0.2503, RMSE=3.1128, MAE=2.4780
#     Fold 5/5: R²=0.1701, RMSE=3.4027, MAE=2.7305
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2270 ± 0.0377
#     RMSE: 3.2617 ± 0.1131
#     MAE:  2.5690 ± 0.1453
#
#   Training LightGBM...
#     Fold 1/5: R²=0.1357, RMSE=3.2669, MAE=2.5326
#     Fold 2/5: R²=0.2978, RMSE=3.2078, MAE=2.6472
#     Fold 3/5: R²=0.2779, RMSE=3.3050, MAE=2.4565
#     Fold 4/5: R²=0.2505, RMSE=3.1124, MAE=2.4238
#     Fold 5/5: R²=0.1307, RMSE=3.4825, MAE=2.7837
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2185 ± 0.0713
#     RMSE: 3.2749 ± 0.1225
#     MAE:  2.5688 ± 0.1321
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1384, RMSE=3.2619, MAE=2.5934
#     Fold 2/5: R²=0.1349, RMSE=3.5605, MAE=2.9320
#     Fold 3/5: R²=0.1538, RMSE=3.5778, MAE=2.6288
#     Fold 4/5: R²=0.1453, RMSE=3.3238, MAE=2.6379
#     Fold 5/5: R²=0.0878, RMSE=3.5674, MAE=2.8308
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1320 ± 0.0230
#     RMSE: 3.4583 ± 0.1366
#     MAE:  2.7246 ± 0.1328
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.1674, RMSE=3.2065, MAE=2.4429
#     Fold 2/5: R²=0.2385, RMSE=3.3406, MAE=2.7710
#     Fold 3/5: R²=0.2720, RMSE=3.3185, MAE=2.4845
#     Fold 4/5: R²=0.2341, RMSE=3.1463, MAE=2.4738
#     Fold 5/5: R²=0.1486, RMSE=3.4463, MAE=2.7745
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2121 ± 0.0464
#     RMSE: 3.2917 ± 0.1053
#     MAE:  2.5893 ± 0.1504
#
#   Training SVR...
#     Fold 1/5: R²=0.2734, RMSE=2.9955, MAE=2.3076
#     Fold 2/5: R²=0.2853, RMSE=3.2362, MAE=2.6737
#     Fold 3/5: R²=0.3788, RMSE=3.0653, MAE=2.2227
#     Fold 4/5: R²=0.3764, RMSE=2.8390, MAE=2.1071
#     Fold 5/5: R²=0.2417, RMSE=3.2525, MAE=2.5626
#
#   SVR 5-Fold CV Results:
#     R²:   0.3111 ± 0.0561
#     RMSE: 3.0777 ± 0.1546
#     MAE:  2.3748 ± 0.2116
#
#   Training KNN...
#     Fold 1/5: R²=0.2358, RMSE=3.0720, MAE=2.3911
#     Fold 2/5: R²=0.3631, RMSE=3.0550, MAE=2.3626
#     Fold 3/5: R²=0.3501, RMSE=3.1353, MAE=2.3328
#     Fold 4/5: R²=0.4006, RMSE=2.7833, MAE=2.1676
#     Fold 5/5: R²=0.2279, RMSE=3.2820, MAE=2.4677
#
#   KNN 5-Fold CV Results:
#     R²:   0.3155 ± 0.0703
#     RMSE: 3.0655 ± 0.1622
#     MAE:  2.3443 ± 0.0991
#
#   Training Lasso...
#     Fold 1/5: R²=0.1721, RMSE=3.1975, MAE=2.5099
#     Fold 2/5: R²=0.2117, RMSE=3.3989, MAE=2.8425
#     Fold 3/5: R²=0.2341, RMSE=3.4038, MAE=2.5217
#     Fold 4/5: R²=0.1795, RMSE=3.2565, MAE=2.5398
#     Fold 5/5: R²=0.1598, RMSE=3.4236, MAE=2.7556
#
#   Lasso 5-Fold CV Results:
#     R²:   0.1914 ± 0.0274
#     RMSE: 3.3361 ± 0.0914
#     MAE:  2.6339 ± 0.1379
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.2668, RMSE=3.0090, MAE=2.3183
#     Fold 2/5: R²=0.3192, RMSE=3.1585, MAE=2.6134
#     Fold 3/5: R²=0.3362, RMSE=3.1687, MAE=2.3035
#     Fold 4/5: R²=0.3398, RMSE=2.9211, MAE=2.2898
#     Fold 5/5: R²=0.2252, RMSE=3.2878, MAE=2.6135
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.2975 ± 0.0446
#     RMSE: 3.1090 ± 0.1291
#     MAE:  2.4277 ± 0.1519
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2130, RMSE=3.1175, MAE=2.4889
#     Fold 2/5: R²=0.2348, RMSE=3.3486, MAE=2.7542
#     Fold 3/5: R²=0.1423, RMSE=3.6020, MAE=2.6512
#     Fold 4/5: R²=0.1854, RMSE=3.2448, MAE=2.5646
#     Fold 5/5: R²=0.1463, RMSE=3.4511, MAE=2.7676
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1844 ± 0.0363
#     RMSE: 3.3528 ± 0.1666
#     MAE:  2.6453 ± 0.1076
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2999, RMSE=2.9402, MAE=2.2936
#     Fold 2/5: R²=0.3202, RMSE=3.1562, MAE=2.5091
#     Fold 3/5: R²=0.2574, RMSE=3.3515, MAE=2.4710
#     Fold 4/5: R²=0.2477, RMSE=3.1183, MAE=2.5089
#     Fold 5/5: R²=0.2430, RMSE=3.2499, MAE=2.5400
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2736 ± 0.0308
#     RMSE: 3.1632 ± 0.1377
#     MAE:  2.4645 ± 0.0882
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3022, RMSE=2.9354, MAE=2.2480
#     Fold 2/5: R²=0.3367, RMSE=3.1178, MAE=2.4822
#     Fold 3/5: R²=0.2572, RMSE=3.3520, MAE=2.4579
#     Fold 4/5: R²=0.2764, RMSE=3.0582, MAE=2.4553
#     Fold 5/5: R²=0.1796, RMSE=3.3832, MAE=2.6339
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2704 ± 0.0527
#     RMSE: 3.1693 ± 0.1725
#     MAE:  2.4555 ± 0.1230
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2329, RMSE=3.0778, MAE=2.4498
#     Fold 2/5: R²=0.2274, RMSE=3.3648, MAE=2.7271
#     Fold 3/5: R²=0.1659, RMSE=3.5521, MAE=2.6011
#     Fold 4/5: R²=0.1726, RMSE=3.2702, MAE=2.6229
#     Fold 5/5: R²=0.1495, RMSE=3.4446, MAE=2.7468
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1897 ± 0.0339
#     RMSE: 3.3419 ± 0.1614
#     MAE:  2.6295 ± 0.1062
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2643, RMSE=3.0141, MAE=2.3136
#     Fold 2/5: R²=0.3127, RMSE=3.1737, MAE=2.4831
#     Fold 3/5: R²=0.2286, RMSE=3.4160, MAE=2.4995
#     Fold 4/5: R²=0.2886, RMSE=3.0323, MAE=2.4564
#     Fold 5/5: R²=0.1865, RMSE=3.3689, MAE=2.6867
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2561 ± 0.0446
#     RMSE: 3.2010 ± 0.1665
#     MAE:  2.4878 ± 0.1192
#
#   Training SVR...
#     Fold 1/5: R²=0.3943, RMSE=2.7350, MAE=2.0667
#     Fold 2/5: R²=0.4447, RMSE=2.8527, MAE=2.2989
#     Fold 3/5: R²=0.3512, RMSE=3.1328, MAE=2.2050
#     Fold 4/5: R²=0.3490, RMSE=2.9007, MAE=2.2635
#     Fold 5/5: R²=0.4225, RMSE=2.8384, MAE=2.2908
#
#   SVR 5-Fold CV Results:
#     R²:   0.3923 ± 0.0380
#     RMSE: 2.8919 ± 0.1320
#     MAE:  2.2250 ± 0.0857
#
#   Training KNN...
#     Fold 1/5: R²=0.3175, RMSE=2.9031, MAE=2.1347
#     Fold 2/5: R²=0.3913, RMSE=2.9866, MAE=2.3485
#     Fold 3/5: R²=0.2804, RMSE=3.2993, MAE=2.4060
#     Fold 4/5: R²=0.2268, RMSE=3.1612, MAE=2.3335
#     Fold 5/5: R²=0.3227, RMSE=3.0739, MAE=2.3781
#
#   KNN 5-Fold CV Results:
#     R²:   0.3077 ± 0.0540
#     RMSE: 3.0848 ± 0.1376
#     MAE:  2.3202 ± 0.0960
#
#   Training Lasso...
#     Fold 1/5: R²=0.2398, RMSE=3.0640, MAE=2.3946
#     Fold 2/5: R²=0.3018, RMSE=3.1988, MAE=2.5458
#     Fold 3/5: R²=0.1025, RMSE=3.6846, MAE=2.7669
#     Fold 4/5: R²=0.1102, RMSE=3.3912, MAE=2.6765
#     Fold 5/5: R²=0.1633, RMSE=3.4165, MAE=2.7085
#
#   Lasso 5-Fold CV Results:
#     R²:   0.1835 ± 0.0768
#     RMSE: 3.3510 ± 0.2111
#     MAE:  2.6185 ± 0.1333
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3686, RMSE=2.7922, MAE=2.1372
#     Fold 2/5: R²=0.4054, RMSE=2.9519, MAE=2.3676
#     Fold 3/5: R²=0.2895, RMSE=3.2783, MAE=2.3690
#     Fold 4/5: R²=0.3158, RMSE=2.9737, MAE=2.3535
#     Fold 5/5: R²=0.2976, RMSE=3.1305, MAE=2.4617
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3354 ± 0.0445
#     RMSE: 3.0253 ± 0.1658
#     MAE:  2.3378 ± 0.1074
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2165, RMSE=3.1105, MAE=2.5050
#     Fold 2/5: R²=0.2429, RMSE=3.3308, MAE=2.7164
#     Fold 3/5: R²=0.0504, RMSE=3.7900, MAE=2.8046
#     Fold 4/5: R²=0.1649, RMSE=3.2854, MAE=2.6269
#     Fold 5/5: R²=0.0831, RMSE=3.5765, MAE=2.8904
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1516 ± 0.0744
#     RMSE: 3.4187 ± 0.2380
#     MAE:  2.7087 ± 0.1345
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3286, RMSE=2.8794, MAE=2.2370
#     Fold 2/5: R²=0.3064, RMSE=3.1881, MAE=2.6660
#     Fold 3/5: R²=0.3259, RMSE=3.1932, MAE=2.3820
#     Fold 4/5: R²=0.2121, RMSE=3.1911, MAE=2.4487
#     Fold 5/5: R²=0.2196, RMSE=3.2996, MAE=2.6064
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2785 ± 0.0518
#     RMSE: 3.1503 ± 0.1419
#     MAE:  2.4680 ± 0.1546
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3079, RMSE=2.9235, MAE=2.2406
#     Fold 2/5: R²=0.3169, RMSE=3.1638, MAE=2.6330
#     Fold 3/5: R²=0.3532, RMSE=3.1280, MAE=2.4011
#     Fold 4/5: R²=0.1668, RMSE=3.2816, MAE=2.4810
#     Fold 5/5: R²=0.1805, RMSE=3.3813, MAE=2.6283
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2651 ± 0.0763
#     RMSE: 3.1757 ± 0.1546
#     MAE:  2.4768 ± 0.1476
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2124, RMSE=3.1186, MAE=2.4986
#     Fold 2/5: R²=0.1671, RMSE=3.4937, MAE=2.8821
#     Fold 3/5: R²=0.1746, RMSE=3.5336, MAE=2.6193
#     Fold 4/5: R²=0.1446, RMSE=3.3250, MAE=2.6385
#     Fold 5/5: R²=0.1426, RMSE=3.4586, MAE=2.7479
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1683 ± 0.0253
#     RMSE: 3.3859 ± 0.1509
#     MAE:  2.6773 ± 0.1294
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2879, RMSE=2.9653, MAE=2.2944
#     Fold 2/5: R²=0.3047, RMSE=3.1921, MAE=2.6737
#     Fold 3/5: R²=0.3110, RMSE=3.2284, MAE=2.4691
#     Fold 4/5: R²=0.1103, RMSE=3.3911, MAE=2.5293
#     Fold 5/5: R²=0.2266, RMSE=3.2847, MAE=2.5676
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2481 ± 0.0751
#     RMSE: 3.2123 ± 0.1406
#     MAE:  2.5068 ± 0.1254
#
#   Training SVR...
#     Fold 1/5: R²=0.3948, RMSE=2.7338, MAE=2.1778
#     Fold 2/5: R²=0.4145, RMSE=2.9291, MAE=2.4184
#     Fold 3/5: R²=0.4315, RMSE=2.9324, MAE=2.2552
#     Fold 4/5: R²=0.3262, RMSE=2.9510, MAE=2.1897
#     Fold 5/5: R²=0.3404, RMSE=3.0335, MAE=2.2865
#
#   SVR 5-Fold CV Results:
#     R²:   0.3815 ± 0.0413
#     RMSE: 2.9160 ± 0.0986
#     MAE:  2.2655 ± 0.0864
#
#   Training KNN...
#     Fold 1/5: R²=0.3890, RMSE=2.7468, MAE=2.0993
#     Fold 2/5: R²=0.4403, RMSE=2.8638, MAE=2.2769
#     Fold 3/5: R²=0.4065, RMSE=2.9963, MAE=2.2801
#     Fold 4/5: R²=0.3642, RMSE=2.8667, MAE=2.1403
#     Fold 5/5: R²=0.3505, RMSE=3.0102, MAE=2.2645
#
#   KNN 5-Fold CV Results:
#     R²:   0.3901 ± 0.0317
#     RMSE: 2.8968 ± 0.0972
#     MAE:  2.2122 ± 0.0767
#
#   Training Lasso...
#     Fold 1/5: R²=0.2488, RMSE=3.0458, MAE=2.3796
#     Fold 2/5: R²=0.3406, RMSE=3.1085, MAE=2.5286
#     Fold 3/5: R²=0.2247, RMSE=3.4245, MAE=2.5674
#     Fold 4/5: R²=0.1536, RMSE=3.3076, MAE=2.5446
#     Fold 5/5: R²=0.1746, RMSE=3.3934, MAE=2.7125
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2284 ± 0.0656
#     RMSE: 3.2560 ± 0.1522
#     MAE:  2.5465 ± 0.1060
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3913, RMSE=2.7416, MAE=2.1267
#     Fold 2/5: R²=0.3842, RMSE=3.0041, MAE=2.4994
#     Fold 3/5: R²=0.3700, RMSE=3.0870, MAE=2.3206
#     Fold 4/5: R²=0.2771, RMSE=3.0567, MAE=2.3116
#     Fold 5/5: R²=0.2954, RMSE=3.1352, MAE=2.4506
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3436 ± 0.0477
#     RMSE: 3.0049 ± 0.1384
#     MAE:  2.3418 ± 0.1298
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2645, RMSE=3.0137, MAE=2.3990
#     Fold 2/5: R²=0.3039, RMSE=3.1939, MAE=2.6192
#     Fold 3/5: R²=0.1334, RMSE=3.6206, MAE=2.6857
#     Fold 4/5: R²=0.1704, RMSE=3.2746, MAE=2.5885
#     Fold 5/5: R²=0.1888, RMSE=3.3642, MAE=2.6772
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2122 ± 0.0627
#     RMSE: 3.2934 ± 0.2003
#     MAE:  2.5939 ± 0.1039
#
# ====================================================================================================
# NOISE TYPE: Mid Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3281, RMSE=2.8058, MAE=2.2936
#     Fold 2/5: R²=0.2858, RMSE=3.0271, MAE=2.4049
#     Fold 3/5: R²=0.2452, RMSE=3.3063, MAE=2.4703
#     Fold 4/5: R²=0.2916, RMSE=2.9518, MAE=2.4090
#     Fold 5/5: R²=0.2270, RMSE=3.3596, MAE=2.7295
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2755 ± 0.0358
#     RMSE: 3.0901 ± 0.2113
#     MAE:  2.4614 ± 0.1456
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3351, RMSE=2.7912, MAE=2.2270
#     Fold 2/5: R²=0.2601, RMSE=3.0811, MAE=2.4055
#     Fold 3/5: R²=0.1957, RMSE=3.4129, MAE=2.5617
#     Fold 4/5: R²=0.3055, RMSE=2.9226, MAE=2.3879
#     Fold 5/5: R²=0.2697, RMSE=3.2656, MAE=2.6555
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2732 ± 0.0470
#     RMSE: 3.0947 ± 0.2247
#     MAE:  2.4475 ± 0.1485
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2149, RMSE=3.0330, MAE=2.5085
#     Fold 2/5: R²=0.1677, RMSE=3.2677, MAE=2.5459
#     Fold 3/5: R²=0.1603, RMSE=3.4872, MAE=2.5861
#     Fold 4/5: R²=0.1825, RMSE=3.1709, MAE=2.5526
#     Fold 5/5: R²=0.1840, RMSE=3.4518, MAE=2.7458
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1819 ± 0.0188
#     RMSE: 3.2821 ± 0.1706
#     MAE:  2.5878 ± 0.0828
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2718, RMSE=2.9210, MAE=2.3424
#     Fold 2/5: R²=0.2779, RMSE=3.0437, MAE=2.3985
#     Fold 3/5: R²=0.1499, RMSE=3.5087, MAE=2.5829
#     Fold 4/5: R²=0.3077, RMSE=2.9180, MAE=2.4017
#     Fold 5/5: R²=0.1946, RMSE=3.4294, MAE=2.7759
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2404 ± 0.0587
#     RMSE: 3.1642 ± 0.2543
#     MAE:  2.5003 ± 0.1599
#
#   Training SVR...
#     Fold 1/5: R²=0.3935, RMSE=2.6659, MAE=2.0580
#     Fold 2/5: R²=0.3232, RMSE=2.9467, MAE=2.2802
#     Fold 3/5: R²=0.3488, RMSE=3.0710, MAE=2.2991
#     Fold 4/5: R²=0.4185, RMSE=2.6742, MAE=2.0821
#     Fold 5/5: R²=0.3097, RMSE=3.1748, MAE=2.5024
#
#   SVR 5-Fold CV Results:
#     R²:   0.3588 ± 0.0413
#     RMSE: 2.9065 ± 0.2062
#     MAE:  2.2444 ± 0.1624
#
#   Training KNN...
#     Fold 1/5: R²=0.4445, RMSE=2.5513, MAE=2.0628
#     Fold 2/5: R²=0.3509, RMSE=2.8858, MAE=2.1730
#     Fold 3/5: R²=0.3711, RMSE=3.0180, MAE=2.2290
#     Fold 4/5: R²=0.3566, RMSE=2.8131, MAE=2.2012
#     Fold 5/5: R²=0.2753, RMSE=3.2530, MAE=2.4554
#
#   KNN 5-Fold CV Results:
#     R²:   0.3597 ± 0.0539
#     RMSE: 2.9042 ± 0.2314
#     MAE:  2.2243 ± 0.1286
#
#   Training Lasso...
#     Fold 1/5: R²=0.3027, RMSE=2.8584, MAE=2.2751
#     Fold 2/5: R²=0.2053, RMSE=3.1930, MAE=2.5255
#     Fold 3/5: R²=0.2403, RMSE=3.3170, MAE=2.4868
#     Fold 4/5: R²=0.2253, RMSE=3.0867, MAE=2.5447
#     Fold 5/5: R²=0.2638, RMSE=3.2788, MAE=2.6480
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2475 ± 0.0336
#     RMSE: 3.1468 ± 0.1645
#     MAE:  2.4960 ± 0.1226
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3925, RMSE=2.6680, MAE=2.1502
#     Fold 2/5: R²=0.3244, RMSE=2.9442, MAE=2.3093
#     Fold 3/5: R²=0.3014, RMSE=3.1807, MAE=2.3731
#     Fold 4/5: R²=0.3717, RMSE=2.7798, MAE=2.2750
#     Fold 5/5: R²=0.3021, RMSE=3.1923, MAE=2.5533
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3384 ± 0.0372
#     RMSE: 2.9530 ± 0.2100
#     MAE:  2.3322 ± 0.1323
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3240, RMSE=2.8144, MAE=2.2923
#     Fold 2/5: R²=0.2683, RMSE=3.0640, MAE=2.3860
#     Fold 3/5: R²=0.2319, RMSE=3.3354, MAE=2.4598
#     Fold 4/5: R²=0.3166, RMSE=2.8991, MAE=2.3544
#     Fold 5/5: R²=0.2486, RMSE=3.3125, MAE=2.6367
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2779 ± 0.0366
#     RMSE: 3.0851 ± 0.2110
#     MAE:  2.4258 ± 0.1184
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3052, RMSE=2.8533, MAE=2.3135
#     Fold 2/5: R²=0.2292, RMSE=3.1447, MAE=2.3968
#     Fold 3/5: R²=0.2271, RMSE=3.3456, MAE=2.4758
#     Fold 4/5: R²=0.2347, RMSE=3.0681, MAE=2.4022
#     Fold 5/5: R²=0.2580, RMSE=3.2916, MAE=2.5199
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2508 ± 0.0293
#     RMSE: 3.1406 ± 0.1747
#     MAE:  2.4216 ± 0.0711
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2875, RMSE=2.8894, MAE=2.3604
#     Fold 2/5: R²=0.2107, RMSE=3.1823, MAE=2.4197
#     Fold 3/5: R²=0.2780, RMSE=3.2336, MAE=2.4461
#     Fold 4/5: R²=0.2765, RMSE=2.9831, MAE=2.3382
#     Fold 5/5: R²=0.2794, RMSE=3.2438, MAE=2.4711
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2664 ± 0.0281
#     RMSE: 3.1064 ± 0.1436
#     MAE:  2.4071 ± 0.0504
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2135, RMSE=3.0356, MAE=2.5236
#     Fold 2/5: R²=0.1777, RMSE=3.2482, MAE=2.5227
#     Fold 3/5: R²=0.1494, RMSE=3.5098, MAE=2.5990
#     Fold 4/5: R²=0.1808, RMSE=3.1741, MAE=2.5326
#     Fold 5/5: R²=0.1736, RMSE=3.4739, MAE=2.7208
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1790 ± 0.0205
#     RMSE: 3.2883 ± 0.1800
#     MAE:  2.5797 ± 0.0760
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2997, RMSE=2.8646, MAE=2.3104
#     Fold 2/5: R²=0.2319, RMSE=3.1392, MAE=2.3690
#     Fold 3/5: R²=0.2319, RMSE=3.3354, MAE=2.4886
#     Fold 4/5: R²=0.2180, RMSE=3.1012, MAE=2.3954
#     Fold 5/5: R²=0.2205, RMSE=3.3739, MAE=2.6058
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2404 ± 0.0302
#     RMSE: 3.1629 ± 0.1831
#     MAE:  2.4338 ± 0.1035
#
#   Training SVR...
#     Fold 1/5: R²=0.4096, RMSE=2.6302, MAE=2.0919
#     Fold 2/5: R²=0.3670, RMSE=2.8498, MAE=2.2061
#     Fold 3/5: R²=0.3163, RMSE=3.1468, MAE=2.3398
#     Fold 4/5: R²=0.3424, RMSE=2.8440, MAE=2.2200
#     Fold 5/5: R²=0.4200, RMSE=2.9102, MAE=2.2699
#
#   SVR 5-Fold CV Results:
#     R²:   0.3710 ± 0.0393
#     RMSE: 2.8762 ± 0.1653
#     MAE:  2.2255 ± 0.0816
#
#   Training KNN...
#     Fold 1/5: R²=0.3863, RMSE=2.6816, MAE=2.1491
#     Fold 2/5: R²=0.3538, RMSE=2.8794, MAE=2.2163
#     Fold 3/5: R²=0.2240, RMSE=3.3524, MAE=2.5172
#     Fold 4/5: R²=0.2539, RMSE=3.0292, MAE=2.3663
#     Fold 5/5: R²=0.3475, RMSE=3.0867, MAE=2.3643
#
#   KNN 5-Fold CV Results:
#     R²:   0.3131 ± 0.0627
#     RMSE: 3.0059 ± 0.2229
#     MAE:  2.3226 ± 0.1288
#
#   Training Lasso...
#     Fold 1/5: R²=0.3373, RMSE=2.7865, MAE=2.2160
#     Fold 2/5: R²=0.1896, RMSE=3.2245, MAE=2.5073
#     Fold 3/5: R²=0.1623, RMSE=3.4832, MAE=2.5592
#     Fold 4/5: R²=0.2086, RMSE=3.1199, MAE=2.4667
#     Fold 5/5: R²=0.2880, RMSE=3.2244, MAE=2.4990
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2372 ± 0.0653
#     RMSE: 3.1677 ± 0.2252
#     MAE:  2.4496 ± 0.1205
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3862, RMSE=2.6817, MAE=2.1789
#     Fold 2/5: R²=0.3165, RMSE=2.9612, MAE=2.2711
#     Fold 3/5: R²=0.2843, RMSE=3.2195, MAE=2.4031
#     Fold 4/5: R²=0.3099, RMSE=2.9133, MAE=2.2725
#     Fold 5/5: R²=0.3389, RMSE=3.1070, MAE=2.4107
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3272 ± 0.0343
#     RMSE: 2.9766 ± 0.1829
#     MAE:  2.3073 ± 0.0882
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2567, RMSE=2.9511, MAE=2.4372
#     Fold 2/5: R²=0.1962, RMSE=3.2113, MAE=2.4971
#     Fold 3/5: R²=0.1522, RMSE=3.5039, MAE=2.5775
#     Fold 4/5: R²=0.2470, RMSE=3.0432, MAE=2.4218
#     Fold 5/5: R²=0.1740, RMSE=3.4729, MAE=2.7538
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2052 ± 0.0406
#     RMSE: 3.2365 ± 0.2222
#     MAE:  2.5375 ± 0.1212
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3277, RMSE=2.8067, MAE=2.2513
#     Fold 2/5: R²=0.3012, RMSE=2.9943, MAE=2.2903
#     Fold 3/5: R²=0.2505, RMSE=3.2947, MAE=2.4506
#     Fold 4/5: R²=0.2841, RMSE=2.9674, MAE=2.3342
#     Fold 5/5: R²=0.2917, RMSE=3.2160, MAE=2.5197
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2910 ± 0.0251
#     RMSE: 3.0558 ± 0.1769
#     MAE:  2.3692 ± 0.1007
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3119, RMSE=2.8394, MAE=2.2438
#     Fold 2/5: R²=0.2846, RMSE=3.0297, MAE=2.3030
#     Fold 3/5: R²=0.2374, RMSE=3.3234, MAE=2.4069
#     Fold 4/5: R²=0.3340, RMSE=2.8619, MAE=2.2201
#     Fold 5/5: R²=0.3085, RMSE=3.1777, MAE=2.4316
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2953 ± 0.0329
#     RMSE: 3.0464 ± 0.1850
#     MAE:  2.3211 ± 0.0849
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2233, RMSE=3.0168, MAE=2.4719
#     Fold 2/5: R²=0.1582, RMSE=3.2864, MAE=2.5417
#     Fold 3/5: R²=0.1680, RMSE=3.4713, MAE=2.5518
#     Fold 4/5: R²=0.1821, RMSE=3.1717, MAE=2.4761
#     Fold 5/5: R²=0.2117, RMSE=3.3929, MAE=2.6820
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1886 ± 0.0250
#     RMSE: 3.2678 ± 0.1610
#     MAE:  2.5447 ± 0.0760
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2984, RMSE=2.8673, MAE=2.2748
#     Fold 2/5: R²=0.2751, RMSE=3.0496, MAE=2.3098
#     Fold 3/5: R²=0.2807, RMSE=3.2277, MAE=2.4009
#     Fold 4/5: R²=0.2738, RMSE=2.9886, MAE=2.3311
#     Fold 5/5: R²=0.3130, RMSE=3.1674, MAE=2.4406
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2882 ± 0.0152
#     RMSE: 3.0601 ± 0.1281
#     MAE:  2.3514 ± 0.0607
#
#   Training SVR...
#     Fold 1/5: R²=0.4590, RMSE=2.5176, MAE=1.9379
#     Fold 2/5: R²=0.3742, RMSE=2.8335, MAE=2.1244
#     Fold 3/5: R²=0.3622, RMSE=3.0393, MAE=2.2876
#     Fold 4/5: R²=0.4191, RMSE=2.6730, MAE=2.1066
#     Fold 5/5: R²=0.4079, RMSE=2.9404, MAE=2.2674
#
#   SVR 5-Fold CV Results:
#     R²:   0.4045 ± 0.0344
#     RMSE: 2.8008 ± 0.1865
#     MAE:  2.1448 ± 0.1266
#
#   Training KNN...
#     Fold 1/5: R²=0.5317, RMSE=2.3424, MAE=1.8669
#     Fold 2/5: R²=0.3957, RMSE=2.7843, MAE=2.0425
#     Fold 3/5: R²=0.3017, RMSE=3.1802, MAE=2.3181
#     Fold 4/5: R²=0.4646, RMSE=2.5662, MAE=2.0310
#     Fold 5/5: R²=0.3718, RMSE=3.0288, MAE=2.2928
#
#   KNN 5-Fold CV Results:
#     R²:   0.4131 ± 0.0789
#     RMSE: 2.7804 ± 0.3031
#     MAE:  2.1103 ± 0.1712
#
#   Training Lasso...
#     Fold 1/5: R²=0.3011, RMSE=2.8617, MAE=2.2346
#     Fold 2/5: R²=0.2065, RMSE=3.1908, MAE=2.4687
#     Fold 3/5: R²=0.2726, RMSE=3.2456, MAE=2.3902
#     Fold 4/5: R²=0.2483, RMSE=3.0407, MAE=2.4791
#     Fold 5/5: R²=0.2764, RMSE=3.2507, MAE=2.5513
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2610 ± 0.0320
#     RMSE: 3.1179 ± 0.1489
#     MAE:  2.4248 ± 0.1079
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4219, RMSE=2.6026, MAE=2.0721
#     Fold 2/5: R²=0.3389, RMSE=2.9124, MAE=2.1952
#     Fold 3/5: R²=0.3183, RMSE=3.1420, MAE=2.3065
#     Fold 4/5: R²=0.3871, RMSE=2.7457, MAE=2.1661
#     Fold 5/5: R²=0.3599, RMSE=3.0573, MAE=2.3742
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3652 ± 0.0364
#     RMSE: 2.8920 ± 0.1977
#     MAE:  2.2228 ± 0.1064
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3519, RMSE=2.7556, MAE=2.2371
#     Fold 2/5: R²=0.1961, RMSE=3.2116, MAE=2.4878
#     Fold 3/5: R²=0.1925, RMSE=3.4197, MAE=2.5240
#     Fold 4/5: R²=0.3155, RMSE=2.9016, MAE=2.3088
#     Fold 5/5: R²=0.2947, RMSE=3.2092, MAE=2.5280
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2701 ± 0.0646
#     RMSE: 3.0995 ± 0.2386
#     MAE:  2.4171 ± 0.1207
#
# ====================================================================================================
# NOISE TYPE: High Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2725, RMSE=3.5727, MAE=2.7684
#     Fold 2/5: R²=0.2018, RMSE=3.8508, MAE=2.7776
#     Fold 3/5: R²=0.2226, RMSE=3.8551, MAE=2.8592
#     Fold 4/5: R²=0.3086, RMSE=3.4909, MAE=2.6400
#     Fold 5/5: R²=0.2181, RMSE=3.6607, MAE=2.8012
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2447 ± 0.0397
#     RMSE: 3.6861 ± 0.1465
#     MAE:  2.7693 ± 0.0719
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2622, RMSE=3.5981, MAE=2.7537
#     Fold 2/5: R²=0.2210, RMSE=3.8042, MAE=2.7735
#     Fold 3/5: R²=0.2102, RMSE=3.8860, MAE=2.8896
#     Fold 4/5: R²=0.3152, RMSE=3.4742, MAE=2.6673
#     Fold 5/5: R²=0.1553, RMSE=3.8047, MAE=2.9113
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2328 ± 0.0535
#     RMSE: 3.7134 ± 0.1529
#     MAE:  2.7991 ± 0.0904
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1770, RMSE=3.8001, MAE=2.9086
#     Fold 2/5: R²=0.1104, RMSE=4.0653, MAE=2.8840
#     Fold 3/5: R²=0.1530, RMSE=4.0241, MAE=2.8954
#     Fold 4/5: R²=0.1889, RMSE=3.7810, MAE=2.8097
#     Fold 5/5: R²=0.1301, RMSE=3.8612, MAE=2.9050
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1519 ± 0.0290
#     RMSE: 3.9064 ± 0.1167
#     MAE:  2.8805 ± 0.0364
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2946, RMSE=3.5181, MAE=2.7159
#     Fold 2/5: R²=0.1853, RMSE=3.8903, MAE=2.8345
#     Fold 3/5: R²=0.1196, RMSE=4.1028, MAE=3.0358
#     Fold 4/5: R²=0.2723, RMSE=3.5812, MAE=2.7609
#     Fold 5/5: R²=0.1743, RMSE=3.7619, MAE=2.9133
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2092 ± 0.0650
#     RMSE: 3.7708 ± 0.2119
#     MAE:  2.8521 ± 0.1137
#
#   Training SVR...
#     Fold 1/5: R²=0.3501, RMSE=3.3769, MAE=2.5668
#     Fold 2/5: R²=0.3346, RMSE=3.5157, MAE=2.5851
#     Fold 3/5: R²=0.2515, RMSE=3.7830, MAE=2.8793
#     Fold 4/5: R²=0.4160, RMSE=3.2083, MAE=2.4103
#     Fold 5/5: R²=0.2284, RMSE=3.6365, MAE=2.7669
#
#   SVR 5-Fold CV Results:
#     R²:   0.3161 ± 0.0683
#     RMSE: 3.5041 ± 0.1996
#     MAE:  2.6417 ± 0.1640
#
#   Training KNN...
#     Fold 1/5: R²=0.3687, RMSE=3.3282, MAE=2.6179
#     Fold 2/5: R²=0.4043, RMSE=3.3265, MAE=2.4880
#     Fold 3/5: R²=0.2317, RMSE=3.8327, MAE=2.8526
#     Fold 4/5: R²=0.4088, RMSE=3.2280, MAE=2.3748
#     Fold 5/5: R²=0.1569, RMSE=3.8013, MAE=2.8378
#
#   KNN 5-Fold CV Results:
#     R²:   0.3141 ± 0.1016
#     RMSE: 3.5033 ± 0.2588
#     MAE:  2.6342 ± 0.1887
#
#   Training Lasso...
#     Fold 1/5: R²=0.2796, RMSE=3.5553, MAE=2.7041
#     Fold 2/5: R²=0.2022, RMSE=3.8498, MAE=2.9086
#     Fold 3/5: R²=0.2001, RMSE=3.9106, MAE=2.9117
#     Fold 4/5: R²=0.2829, RMSE=3.5551, MAE=2.7201
#     Fold 5/5: R²=0.1854, RMSE=3.7365, MAE=2.8884
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2300 ± 0.0422
#     RMSE: 3.7214 ± 0.1468
#     MAE:  2.8266 ± 0.0939
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3419, RMSE=3.3981, MAE=2.6128
#     Fold 2/5: R²=0.2923, RMSE=3.6258, MAE=2.6168
#     Fold 3/5: R²=0.2563, RMSE=3.7708, MAE=2.7838
#     Fold 4/5: R²=0.3737, RMSE=3.3224, MAE=2.5185
#     Fold 5/5: R²=0.2433, RMSE=3.6011, MAE=2.7492
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3015 ± 0.0497
#     RMSE: 3.5436 ± 0.1624
#     MAE:  2.6562 ± 0.0973
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1676, RMSE=3.8217, MAE=2.9156
#     Fold 2/5: R²=0.1450, RMSE=3.9854, MAE=2.8385
#     Fold 3/5: R²=0.1088, RMSE=4.1278, MAE=2.9684
#     Fold 4/5: R²=0.1708, RMSE=3.8229, MAE=2.8201
#     Fold 5/5: R²=0.1138, RMSE=3.8972, MAE=2.9300
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1412 ± 0.0260
#     RMSE: 3.9310 ± 0.1153
#     MAE:  2.8945 ± 0.0563
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2659, RMSE=3.5889, MAE=2.7579
#     Fold 2/5: R²=0.2935, RMSE=3.6229, MAE=2.6702
#     Fold 3/5: R²=0.3016, RMSE=3.6541, MAE=2.6779
#     Fold 4/5: R²=0.3508, RMSE=3.3827, MAE=2.6219
#     Fold 5/5: R²=0.1980, RMSE=3.7074, MAE=2.8043
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2820 ± 0.0501
#     RMSE: 3.5912 ± 0.1113
#     MAE:  2.7065 ± 0.0656
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2706, RMSE=3.5774, MAE=2.8454
#     Fold 2/5: R²=0.3006, RMSE=3.6046, MAE=2.6915
#     Fold 3/5: R²=0.3097, RMSE=3.6330, MAE=2.7064
#     Fold 4/5: R²=0.2925, RMSE=3.5312, MAE=2.7363
#     Fold 5/5: R²=0.1742, RMSE=3.7621, MAE=2.8205
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2695 ± 0.0494
#     RMSE: 3.6217 ± 0.0778
#     MAE:  2.7600 ± 0.0618
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1792, RMSE=3.7949, MAE=2.9392
#     Fold 2/5: R²=0.2028, RMSE=3.8484, MAE=2.7932
#     Fold 3/5: R²=0.2484, RMSE=3.7906, MAE=2.7258
#     Fold 4/5: R²=0.2296, RMSE=3.6849, MAE=2.8101
#     Fold 5/5: R²=0.1697, RMSE=3.7722, MAE=2.8554
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2060 ± 0.0297
#     RMSE: 3.7782 ± 0.0531
#     MAE:  2.8248 ± 0.0708
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.1836, RMSE=3.7848, MAE=2.9256
#     Fold 2/5: R²=0.3109, RMSE=3.5779, MAE=2.6056
#     Fold 3/5: R²=0.3291, RMSE=3.5814, MAE=2.6631
#     Fold 4/5: R²=0.2974, RMSE=3.5189, MAE=2.6942
#     Fold 5/5: R²=0.1448, RMSE=3.8283, MAE=2.9187
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2532 ± 0.0743
#     RMSE: 3.6583 ± 0.1239
#     MAE:  2.7614 ± 0.1343
#
#   Training SVR...
#     Fold 1/5: R²=0.3980, RMSE=3.2500, MAE=2.4081
#     Fold 2/5: R²=0.3921, RMSE=3.3605, MAE=2.5983
#     Fold 3/5: R²=0.4510, RMSE=3.2397, MAE=2.4559
#     Fold 4/5: R²=0.5265, RMSE=2.8889, MAE=2.2224
#     Fold 5/5: R²=0.3598, RMSE=3.3125, MAE=2.5197
#
#   SVR 5-Fold CV Results:
#     R²:   0.4255 ± 0.0584
#     RMSE: 3.2103 ± 0.1666
#     MAE:  2.4409 ± 0.1265
#
#   Training KNN...
#     Fold 1/5: R²=0.3797, RMSE=3.2990, MAE=2.5288
#     Fold 2/5: R²=0.3356, RMSE=3.5132, MAE=2.6232
#     Fold 3/5: R²=0.3807, RMSE=3.4411, MAE=2.4743
#     Fold 4/5: R²=0.4631, RMSE=3.0761, MAE=2.3350
#     Fold 5/5: R²=0.2783, RMSE=3.5169, MAE=2.6974
#
#   KNN 5-Fold CV Results:
#     R²:   0.3675 ± 0.0607
#     RMSE: 3.3693 ± 0.1665
#     MAE:  2.5317 ± 0.1248
#
#   Training Lasso...
#     Fold 1/5: R²=0.2068, RMSE=3.7306, MAE=2.8476
#     Fold 2/5: R²=0.1954, RMSE=3.8661, MAE=2.8812
#     Fold 3/5: R²=0.2445, RMSE=3.8005, MAE=2.8573
#     Fold 4/5: R²=0.2642, RMSE=3.6011, MAE=2.8482
#     Fold 5/5: R²=0.1766, RMSE=3.7565, MAE=2.8634
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2175 ± 0.0322
#     RMSE: 3.7510 ± 0.0879
#     MAE:  2.8595 ± 0.0123
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3436, RMSE=3.3938, MAE=2.6071
#     Fold 2/5: R²=0.3628, RMSE=3.4406, MAE=2.5460
#     Fold 3/5: R²=0.3974, RMSE=3.3944, MAE=2.4974
#     Fold 4/5: R²=0.4226, RMSE=3.1902, MAE=2.4675
#     Fold 5/5: R²=0.2892, RMSE=3.4902, MAE=2.6565
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3631 ± 0.0459
#     RMSE: 3.3818 ± 0.1022
#     MAE:  2.5549 ± 0.0694
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2208, RMSE=3.6976, MAE=2.8226
#     Fold 2/5: R²=0.2198, RMSE=3.8071, MAE=2.7404
#     Fold 3/5: R²=0.1867, RMSE=3.9433, MAE=2.8246
#     Fold 4/5: R²=0.1853, RMSE=3.7892, MAE=2.8073
#     Fold 5/5: R²=0.2499, RMSE=3.5853, MAE=2.7194
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2125 ± 0.0242
#     RMSE: 3.7645 ± 0.1192
#     MAE:  2.7829 ± 0.0442
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3216, RMSE=3.4501, MAE=2.7550
#     Fold 2/5: R²=0.2824, RMSE=3.6510, MAE=2.6623
#     Fold 3/5: R²=0.2735, RMSE=3.7270, MAE=2.7898
#     Fold 4/5: R²=0.3355, RMSE=3.4223, MAE=2.5770
#     Fold 5/5: R²=0.2653, RMSE=3.5484, MAE=2.7363
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2957 ± 0.0277
#     RMSE: 3.5598 ± 0.1161
#     MAE:  2.7041 ± 0.0760
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2885, RMSE=3.5334, MAE=2.8198
#     Fold 2/5: R²=0.3120, RMSE=3.5749, MAE=2.6658
#     Fold 3/5: R²=0.3074, RMSE=3.6389, MAE=2.8105
#     Fold 4/5: R²=0.3450, RMSE=3.3977, MAE=2.6058
#     Fold 5/5: R²=0.2493, RMSE=3.5868, MAE=2.7869
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3004 ± 0.0314
#     RMSE: 3.5463 ± 0.0816
#     MAE:  2.7378 ± 0.0861
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1914, RMSE=3.7667, MAE=2.9244
#     Fold 2/5: R²=0.1809, RMSE=3.9009, MAE=2.8237
#     Fold 3/5: R²=0.1994, RMSE=3.9123, MAE=2.8227
#     Fold 4/5: R²=0.2094, RMSE=3.7328, MAE=2.8111
#     Fold 5/5: R²=0.1860, RMSE=3.7350, MAE=2.8182
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1934 ± 0.0101
#     RMSE: 3.8096 ± 0.0802
#     MAE:  2.8400 ± 0.0424
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2897, RMSE=3.5303, MAE=2.7965
#     Fold 2/5: R²=0.2629, RMSE=3.7004, MAE=2.7324
#     Fold 3/5: R²=0.2552, RMSE=3.7736, MAE=2.8221
#     Fold 4/5: R²=0.3221, RMSE=3.4565, MAE=2.6532
#     Fold 5/5: R²=0.2123, RMSE=3.6741, MAE=2.8092
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2685 ± 0.0366
#     RMSE: 3.6270 ± 0.1162
#     MAE:  2.7627 ± 0.0628
#
#   Training SVR...
#     Fold 1/5: R²=0.4302, RMSE=3.1621, MAE=2.4424
#     Fold 2/5: R²=0.4273, RMSE=3.2618, MAE=2.4631
#     Fold 3/5: R²=0.3699, RMSE=3.4709, MAE=2.6400
#     Fold 4/5: R²=0.5434, RMSE=2.8367, MAE=2.1290
#     Fold 5/5: R²=0.2368, RMSE=3.6165, MAE=2.7741
#
#   SVR 5-Fold CV Results:
#     R²:   0.4015 ± 0.0997
#     RMSE: 3.2696 ± 0.2683
#     MAE:  2.4897 ± 0.2175
#
#   Training KNN...
#     Fold 1/5: R²=0.4235, RMSE=3.1804, MAE=2.5021
#     Fold 2/5: R²=0.4336, RMSE=3.2437, MAE=2.4163
#     Fold 3/5: R²=0.3181, RMSE=3.6108, MAE=2.7153
#     Fold 4/5: R²=0.4839, RMSE=3.0159, MAE=2.2574
#     Fold 5/5: R²=0.2179, RMSE=3.6612, MAE=2.6974
#
#   KNN 5-Fold CV Results:
#     R²:   0.3754 ± 0.0955
#     RMSE: 3.3424 ± 0.2515
#     MAE:  2.5177 ± 0.1730
#
#   Training Lasso...
#     Fold 1/5: R²=0.2540, RMSE=3.6179, MAE=2.7592
#     Fold 2/5: R²=0.2684, RMSE=3.6866, MAE=2.7294
#     Fold 3/5: R²=0.2635, RMSE=3.7525, MAE=2.7948
#     Fold 4/5: R²=0.3460, RMSE=3.3952, MAE=2.5952
#     Fold 5/5: R²=0.2357, RMSE=3.6191, MAE=2.8575
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2735 ± 0.0379
#     RMSE: 3.6143 ± 0.1203
#     MAE:  2.7472 ± 0.0872
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3848, RMSE=3.2855, MAE=2.5827
#     Fold 2/5: R²=0.3674, RMSE=3.4281, MAE=2.5351
#     Fold 3/5: R²=0.3497, RMSE=3.5261, MAE=2.6474
#     Fold 4/5: R²=0.4379, RMSE=3.1476, MAE=2.3990
#     Fold 5/5: R²=0.3051, RMSE=3.4511, MAE=2.6524
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3690 ± 0.0435
#     RMSE: 3.3677 ± 0.1348
#     MAE:  2.5633 ± 0.0929
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2073, RMSE=3.7296, MAE=2.8561
#     Fold 2/5: R²=0.2421, RMSE=3.7523, MAE=2.6853
#     Fold 3/5: R²=0.2129, RMSE=3.8792, MAE=2.7837
#     Fold 4/5: R²=0.2674, RMSE=3.5933, MAE=2.6698
#     Fold 5/5: R²=0.2152, RMSE=3.6673, MAE=2.7861
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2290 ± 0.0227
#     RMSE: 3.7243 ± 0.0951
#     MAE:  2.7562 ± 0.0695
#
# ========================================================================================================================
#                           K-FOLD CROSS-VALIDATION RESULTS SUMMARY
# ========================================================================================================================
#
# ====================================================================================================
# NOISE TYPE: Mean Noise
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.4165 ± 0.0621
#   RMSE: 2.8771 ± 0.2315
#   MAE:  2.1958 ± 0.1496
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.3982 ± 0.0977
#   RMSE: 2.9221 ± 0.3514
#   MAE:  2.2205 ± 0.2225
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.3859 ± 0.0491
#   RMSE: 2.9531 ± 0.2120
#   MAE:  2.2817 ± 0.1292
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.3742 ± 0.0409
#   RMSE: 2.9778 ± 0.1234
#   MAE:  2.2972 ± 0.0730
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.3699 ± 0.0590
#   RMSE: 2.9926 ± 0.2515
#   MAE:  2.3132 ± 0.1632
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.3672 ± 0.0542
#   RMSE: 2.9980 ± 0.2269
#   MAE:  2.3177 ± 0.1629
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Street View
#   R²:   0.3533 ± 0.0444
#   RMSE: 3.0315 ± 0.2117
#   MAE:  2.3778 ± 0.1308
# ...
# KNN                  (Base      ) + Fusion
#   R²:   0.3901 ± 0.0317
#   RMSE: 2.8968 ± 0.0972
#   MAE:  2.2122 ± 0.0767
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.3815 ± 0.0413
#   RMSE: 2.9160 ± 0.0986
#   MAE:  2.2655 ± 0.0864
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.3436 ± 0.0477
#   RMSE: 3.0049 ± 0.1384
#   MAE:  2.3418 ± 0.1298
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.3354 ± 0.0445
#   RMSE: 3.0253 ± 0.1658
#   MAE:  2.3378 ± 0.1074
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.3155 ± 0.0703
#   RMSE: 3.0655 ± 0.1622
#   MAE:  2.3443 ± 0.0991
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.3111 ± 0.0561
#   RMSE: 3.0777 ± 0.1546
#   MAE:  2.3748 ± 0.2116
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.3077 ± 0.0540
#   RMSE: 3.0848 ± 0.1376
#   MAE:  2.3202 ± 0.0960
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Street View
#   R²:   0.2975 ± 0.0446
#   RMSE: 3.1090 ± 0.1291
#   MAE:  2.4277 ± 0.1519
# ----------------------------------------------------------------------------------------------------
# XGBoost              (Base      ) + Fusion
#   R²:   0.2785 ± 0.0518
#   RMSE: 3.1503 ± 0.1419
#   MAE:  2.4680 ± 0.1546
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# NOISE TYPE: Mid Freq
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.4131 ± 0.0789
#   RMSE: 2.7804 ± 0.3031
#   MAE:  2.1103 ± 0.1712
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.4045 ± 0.0344
#   RMSE: 2.8008 ± 0.1865
#   MAE:  2.1448 ± 0.1266
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.3710 ± 0.0393
#   RMSE: 2.8762 ± 0.1653
#   MAE:  2.2255 ± 0.0816
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.3652 ± 0.0364
#   RMSE: 2.8920 ± 0.1977
#   MAE:  2.2228 ± 0.1064
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.3597 ± 0.0539
#   RMSE: 2.9042 ± 0.2314
#   MAE:  2.2243 ± 0.1286
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.3588 ± 0.0413
#   RMSE: 2.9065 ± 0.2062
#   MAE:  2.2444 ± 0.1624
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Street View
#   R²:   0.3384 ± 0.0372
#   RMSE: 2.9530 ± 0.2100
#   MAE:  2.3322 ± 0.1323
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.3272 ± 0.0343
#   RMSE: 2.9766 ± 0.1829
#   MAE:  2.3073 ± 0.0882
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.3131 ± 0.0627
#   RMSE: 3.0059 ± 0.2229
#   MAE:  2.3226 ± 0.1288
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Fusion
#   R²:   0.2953 ± 0.0329
#   RMSE: 3.0464 ± 0.1850
#   MAE:  2.3211 ± 0.0849
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# NOISE TYPE: High Freq
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.4255 ± 0.0584
#   RMSE: 3.2103 ± 0.1666
#   MAE:  2.4409 ± 0.1265
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.4015 ± 0.0997
#   RMSE: 3.2696 ± 0.2683
#   MAE:  2.4897 ± 0.2175
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.3754 ± 0.0955
#   RMSE: 3.3424 ± 0.2515
#   MAE:  2.5177 ± 0.1730
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.3690 ± 0.0435
#   RMSE: 3.3677 ± 0.1348
#   MAE:  2.5633 ± 0.0929
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.3675 ± 0.0607
#   RMSE: 3.3693 ± 0.1665
#   MAE:  2.5317 ± 0.1248
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.3631 ± 0.0459
#   RMSE: 3.3818 ± 0.1022
#   MAE:  2.5549 ± 0.0694
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.3161 ± 0.0683
#   RMSE: 3.5041 ± 0.1996
#   MAE:  2.6417 ± 0.1640
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.3141 ± 0.1016
#   RMSE: 3.5033 ± 0.2588
#   MAE:  2.6342 ± 0.1887
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Street View
#   R²:   0.3015 ± 0.0497
#   RMSE: 3.5436 ± 0.1624
#   MAE:  2.6562 ± 0.0973
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Fusion
#   R²:   0.3004 ± 0.0314
#   RMSE: 3.5463 ± 0.0816
#   MAE:  2.7378 ± 0.0861
# ----------------------------------------------------------------------------------------------------
#
# ========================================================================================================================
#                           OVERALL TOP 10 BEST MODELS
# ========================================================================================================================
#
# SVR                  (Base      )
#   Noise: High Freq, Features: Remote Sensing
#   R²:   0.4255 ± 0.0584
#   RMSE: 3.2103 ± 0.1666
#   MAE:  2.4409 ± 0.1265
#
# SVR                  (Base      )
#   Noise: Mean Noise, Features: Fusion
#   R²:   0.4165 ± 0.0621
#   RMSE: 2.8771 ± 0.2315
#   MAE:  2.1958 ± 0.1496
#
# KNN                  (Base      )
#   Noise: Mid Freq, Features: Fusion
#   R²:   0.4131 ± 0.0789
#   RMSE: 2.7804 ± 0.3031
#   MAE:  2.1103 ± 0.1712
#
# SVR                  (Base      )
#   Noise: Mid Freq, Features: Fusion
#   R²:   0.4045 ± 0.0344
#   RMSE: 2.8008 ± 0.1865
#   MAE:  2.1448 ± 0.1266
#
# SVR                  (Base      )
#   Noise: High Freq, Features: Fusion
#   R²:   0.4015 ± 0.0997
#   RMSE: 3.2696 ± 0.2683
#   MAE:  2.4897 ± 0.2175
#
# KNN                  (Base      )
#   Noise: Mean Noise, Features: Fusion
#   R²:   0.3982 ± 0.0977
#   RMSE: 2.9221 ± 0.3514
#   MAE:  2.2205 ± 0.2225
#
# SVR                  (Base      )
#   Noise: Low Freq, Features: Remote Sensing
#   R²:   0.3923 ± 0.0380
#   RMSE: 2.8919 ± 0.1320
#   MAE:  2.2250 ± 0.0857
#
# KNN                  (Base      )
#   Noise: Low Freq, Features: Fusion
#   R²:   0.3901 ± 0.0317
#   RMSE: 2.8968 ± 0.0972
#   MAE:  2.2122 ± 0.0767
#
# Voting               (Ensemble  )
#   Noise: Mean Noise, Features: Fusion
#   R²:   0.3859 ± 0.0491
#   RMSE: 2.9531 ± 0.2120
#   MAE:  2.2817 ± 0.1292
#
# SVR                  (Base      )
#   Noise: Low Freq, Features: Fusion
#   R²:   0.3815 ± 0.0413
#   RMSE: 2.9160 ± 0.0986
#   MAE:  2.2655 ± 0.0864
#
# ========================================================================================================================
#
# ========================================================================================================================
# Results saved to 'comprehensive_kfold_results.csv'
#
# ========================================================================================================================
# SAVING ALL BEST MODELS...
# ========================================================================================================================
#   ✓ Saved: Mean Noise - street - XGBoost
#   ✓ Saved: Mean Noise - street - LightGBM
#   ✓ Saved: Mean Noise - street - Random Forest
#   ✓ Saved: Mean Noise - street - Gradient Boosting
#   ✓ Saved: Mean Noise - street - SVR
#   ✓ Saved: Mean Noise - street - KNN
#   ✓ Saved: Mean Noise - street - Lasso
#   ✓ Saved: Mean Noise - street - Voting
#   ✓ Saved: Mean Noise - street - Stacking
#   ✓ Saved: Mean Noise - remote - XGBoost
#   ✓ Saved: Mean Noise - remote - LightGBM
#   ✓ Saved: Mean Noise - remote - Random Forest
#   ✓ Saved: Mean Noise - remote - Gradient Boosting
#   ✓ Saved: Mean Noise - remote - SVR
#   ✓ Saved: Mean Noise - remote - KNN
#   ✓ Saved: Mean Noise - remote - Lasso
#   ✓ Saved: Mean Noise - remote - Voting
#   ✓ Saved: Mean Noise - remote - Stacking
#   ✓ Saved: Mean Noise - fusion - XGBoost
#   ✓ Saved: Mean Noise - fusion - LightGBM
#   ✓ Saved: Mean Noise - fusion - Random Forest
#   ✓ Saved: Mean Noise - fusion - Gradient Boosting
#   ✓ Saved: Mean Noise - fusion - SVR
#   ✓ Saved: Mean Noise - fusion - KNN
#   ✓ Saved: Mean Noise - fusion - Lasso
#   ✓ Saved: Mean Noise - fusion - Voting
#   ✓ Saved: Mean Noise - fusion - Stacking
#   ✓ Saved: Low Freq - street - XGBoost
#   ✓ Saved: Low Freq - street - LightGBM
#   ✓ Saved: Low Freq - street - Random Forest
#   ✓ Saved: Low Freq - street - Gradient Boosting
#   ✓ Saved: Low Freq - street - SVR
#   ✓ Saved: Low Freq - street - KNN
#   ✓ Saved: Low Freq - street - Lasso
#   ✓ Saved: Low Freq - street - Voting
#   ✓ Saved: Low Freq - street - Stacking
#   ✓ Saved: Low Freq - remote - XGBoost
#   ✓ Saved: Low Freq - remote - LightGBM
#   ✓ Saved: Low Freq - remote - Random Forest
#   ✓ Saved: Low Freq - remote - Gradient Boosting
#   ✓ Saved: Low Freq - remote - SVR
#   ✓ Saved: Low Freq - remote - KNN
#   ✓ Saved: Low Freq - remote - Lasso
#   ✓ Saved: Low Freq - remote - Voting
#   ✓ Saved: Low Freq - remote - Stacking
#   ✓ Saved: Low Freq - fusion - XGBoost
#   ✓ Saved: Low Freq - fusion - LightGBM
#   ✓ Saved: Low Freq - fusion - Random Forest
#   ✓ Saved: Low Freq - fusion - Gradient Boosting
#   ✓ Saved: Low Freq - fusion - SVR
#   ✓ Saved: Low Freq - fusion - KNN
#   ✓ Saved: Low Freq - fusion - Lasso
#   ✓ Saved: Low Freq - fusion - Voting
#   ✓ Saved: Low Freq - fusion - Stacking
#   ✓ Saved: Mid Freq - street - XGBoost
#   ✓ Saved: Mid Freq - street - LightGBM
#   ✓ Saved: Mid Freq - street - Random Forest
#   ✓ Saved: Mid Freq - street - Gradient Boosting
#   ✓ Saved: Mid Freq - street - SVR
#   ✓ Saved: Mid Freq - street - KNN
#   ✓ Saved: Mid Freq - street - Lasso
#   ✓ Saved: Mid Freq - street - Voting
#   ✓ Saved: Mid Freq - street - Stacking
#   ✓ Saved: Mid Freq - remote - XGBoost
#   ✓ Saved: Mid Freq - remote - LightGBM
#   ✓ Saved: Mid Freq - remote - Random Forest
#   ✓ Saved: Mid Freq - remote - Gradient Boosting
#   ✓ Saved: Mid Freq - remote - SVR
#   ✓ Saved: Mid Freq - remote - KNN
#   ✓ Saved: Mid Freq - remote - Lasso
#   ✓ Saved: Mid Freq - remote - Voting
#   ✓ Saved: Mid Freq - remote - Stacking
#   ✓ Saved: Mid Freq - fusion - XGBoost
#   ✓ Saved: Mid Freq - fusion - LightGBM
#   ✓ Saved: Mid Freq - fusion - Random Forest
#   ✓ Saved: Mid Freq - fusion - Gradient Boosting
#   ✓ Saved: Mid Freq - fusion - SVR
#   ✓ Saved: Mid Freq - fusion - KNN
#   ✓ Saved: Mid Freq - fusion - Lasso
#   ✓ Saved: Mid Freq - fusion - Voting
#   ✓ Saved: Mid Freq - fusion - Stacking
#   ✓ Saved: High Freq - street - XGBoost
#   ✓ Saved: High Freq - street - LightGBM
#   ✓ Saved: High Freq - street - Random Forest
#   ✓ Saved: High Freq - street - Gradient Boosting
#   ✓ Saved: High Freq - street - SVR
#   ✓ Saved: High Freq - street - KNN
#   ✓ Saved: High Freq - street - Lasso
#   ✓ Saved: High Freq - street - Voting
#   ✓ Saved: High Freq - street - Stacking
#   ✓ Saved: High Freq - remote - XGBoost
#   ✓ Saved: High Freq - remote - LightGBM
#   ✓ Saved: High Freq - remote - Random Forest
#   ✓ Saved: High Freq - remote - Gradient Boosting
#   ✓ Saved: High Freq - remote - SVR
#   ✓ Saved: High Freq - remote - KNN
#   ✓ Saved: High Freq - remote - Lasso
#   ✓ Saved: High Freq - remote - Voting
#   ✓ Saved: High Freq - remote - Stacking
#   ✓ Saved: High Freq - fusion - XGBoost
#   ✓ Saved: High Freq - fusion - LightGBM
#   ✓ Saved: High Freq - fusion - Random Forest
#   ✓ Saved: High Freq - fusion - Gradient Boosting
#   ✓ Saved: High Freq - fusion - SVR
#   ✓ Saved: High Freq - fusion - KNN
#   ✓ Saved: High Freq - fusion - Lasso
#   ✓ Saved: High Freq - fusion - Voting
#   ✓ Saved: High Freq - fusion - Stacking
#
#   ✓ Saved complete predictor object
#
# ========================================================================================================================
# Successfully saved 108 models to 'saved_models' directory
# ========================================================================================================================
# ========================================================================================================================
#
# ========================================================================================================================
#                            EXPERIMENT COMPLETED SUCCESSFULLY
# ========================================================================================================================
#
# Summary:
# • Total models evaluated: 9 (7 base models + 2 ensemble models)
# • Base models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso
# • Ensemble models: Voting (7 models), Stacking (7 models + Lasso)
# • Feature types: Street View, Remote Sensing, Fusion
# • Noise types: Mean Noise, Low Freq, Mid Freq, High Freq
# • Cross-validation: 5-fold
# • Metrics: R², RMSE, MAE, MSE (all with mean ± std)
# • All models saved to 'saved_models/' directory
#
# Results saved to 'comprehensive_kfold_results.csv'
#
# ========================================================================================================================
# DEMONSTRATION: How to Load and Use Saved Models
# ========================================================================================================================
#
# 1. Loading a single model:
# Loaded model: Mean Noise - fusion - XGBoost
#   R²: 0.3296
#   RMSE: 3.0855
#   MAE: 2.4072
#
# 2. Making predictions with a saved model:
#   predictions = predictor.predict_with_saved_model(
#       X_new=new_data,
#       noise_type='Mean Noise',
#       feature_type='fusion',
#       model_name='XGBoost'
#   )
#
# 3. Loading complete predictor:
#   loaded_predictor = ComprehensiveKFoldNoisePredictor.load_complete_predictor('saved_models')

# %%
# 创建预测器
predictor = ComprehensiveKFoldNoisePredictor()

# 文件路径
street_view_path = './revise_data/features_dinov3-vitb16-pretrain-lvd1689m.npy'
remote_sensing_path = './revise_data/features_dinov3-vitl16-pretrain-sat493m.npy'
noise_labels_path = './revise_data/noise_labels_50.npy'

try:
    # 加载数据
    print("Loading data...")
    street_features, remote_features, fusion_features, labels = predictor.load_data(
        street_view_path, remote_sensing_path, noise_labels_path
    )
    
    # 准备特征字典
    features_dict = {
        'street': street_features,
        'remote': remote_features,
        'fusion': fusion_features
    }
    
    # 执行K折交叉验证并保存模型
    print("\nStarting comprehensive K-fold cross-validation...")
    results_df = predictor.k_fold_cross_validation_all_models(
        features_dict=features_dict,
        labels=labels,
        k=5,  # 5折交叉验证
        optimize_hyperparams=False,  # 设为True可启用超参数优化（会更慢）
        save_best_models=True  # 自动保存所有最佳模型
    )
    
    print(f"\n{'='*120}")
    print("                           EXPERIMENT COMPLETED SUCCESSFULLY")
    print(f"{'='*120}")
    print("\nSummary:")
    print("• Total models evaluated: 9 (7 base models + 2 ensemble models)")
    print("• Base models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso")
    print("• Ensemble models: Voting (7 models), Stacking (7 models + Lasso)")
    print("• Feature types: Street View, Remote Sensing, Fusion")
    print("• Noise types: Mean Noise, Low Freq, Mid Freq, High Freq")
    print("• Cross-validation: 5-fold")
    print("• Metrics: R², RMSE, MAE, MSE (all with mean ± std)")
    print("• All models saved to 'saved_models/' directory")
    print("\nResults saved to 'comprehensive_kfold_results.csv'")
    
    # ============ 演示如何使用保存的模型 ============
    print(f"\n{'='*120}")
    print("DEMONSTRATION: How to Load and Use Saved Models")
    print(f"{'='*120}")
    
    # 示例1: 加载单个模型
    print("\n1. Loading a single model:")
    try:
        model, preprocessors, info = predictor.load_saved_model(
            noise_type='Mean Noise',
            feature_type='fusion',
            model_name='XGBoost',
            save_dir='saved_models'
        )
    except:
        print("  (Model not found - will be available after training)")
    
    # 示例2: 使用保存的模型进行预测
    print("\n2. Making predictions with a saved model:")
    print("  predictions = predictor.predict_with_saved_model(")
    print("      X_new=new_data,")
    print("      noise_type='Mean Noise',")
    print("      feature_type='fusion',")
    print("      model_name='XGBoost'")
    print("  )")
    
    # 示例3: 加载完整的predictor
    print("\n3. Loading complete predictor:")
    print("  loaded_predictor = ComprehensiveKFoldNoisePredictor.load_complete_predictor('saved_models')")
    
except FileNotFoundError as e:
    print(f"File not found: {e}")
    print("Please ensure the following files exist:")
    print(f"- {street_view_path}")
    print(f"- {remote_sensing_path}")
    print(f"- {noise_labels_path}")
except Exception as e:
    print(f"Error occurred: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Loading data...
# Street view features shape: (923, 768)
# Remote sensing features shape: (923, 1024)
# Noise labels shape: (923, 4)
#
# Starting comprehensive K-fold cross-validation...
#
# ========================================================================================================================
#           K-FOLD CROSS-VALIDATION FOR ALL 8 MODELS + ENSEMBLES (K=5)
# ========================================================================================================================
# Models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso
# Ensembles: Voting (7 models), Stacking (7 models + Lasso)
#
# ====================================================================================================
# NOISE TYPE: Mean Noise
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3703, RMSE=2.6496, MAE=2.0483
#     Fold 2/5: R²=0.3269, RMSE=2.6060, MAE=1.9446
#     Fold 3/5: R²=0.3038, RMSE=2.8343, MAE=2.1008
#     Fold 4/5: R²=0.3439, RMSE=2.6721, MAE=2.0263
#     Fold 5/5: R²=0.3293, RMSE=2.9291, MAE=2.1659
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3348 ± 0.0219
#     RMSE: 2.7382 ± 0.1228
#     MAE:  2.0572 ± 0.0741
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3811, RMSE=2.6268, MAE=2.0540
#     Fold 2/5: R²=0.3041, RMSE=2.6496, MAE=1.9825
#     Fold 3/5: R²=0.3062, RMSE=2.8294, MAE=2.1183
#     Fold 4/5: R²=0.3248, RMSE=2.7106, MAE=2.1122
#     Fold 5/5: R²=0.3410, RMSE=2.9033, MAE=2.1575
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3315 ± 0.0282
#     RMSE: 2.7440 ± 0.1062
#     MAE:  2.0849 ± 0.0610
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2512, RMSE=2.8894, MAE=2.3107
#     Fold 2/5: R²=0.2381, RMSE=2.7725, MAE=2.0898
#     Fold 3/5: R²=0.2176, RMSE=3.0048, MAE=2.2889
#     Fold 4/5: R²=0.2303, RMSE=2.8941, MAE=2.1695
#     Fold 5/5: R²=0.2222, RMSE=3.1543, MAE=2.3595
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2319 ± 0.0119
#     RMSE: 2.9430 ± 0.1287
#     MAE:  2.2437 ± 0.0991
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3971, RMSE=2.5927, MAE=2.0096
#     Fold 2/5: R²=0.2974, RMSE=2.6624, MAE=2.0080
#     Fold 3/5: R²=0.3148, RMSE=2.8120, MAE=2.0979
#     Fold 4/5: R²=0.2893, RMSE=2.7811, MAE=2.1043
#     Fold 5/5: R²=0.3278, RMSE=2.9323, MAE=2.1646
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3253 ± 0.0383
#     RMSE: 2.7561 ± 0.1186
#     MAE:  2.0769 ± 0.0603
#
#   Training SVR...
#     Fold 1/5: R²=0.5427, RMSE=2.2579, MAE=1.7617
#     Fold 2/5: R²=0.4185, RMSE=2.4222, MAE=1.8499
#     Fold 3/5: R²=0.3855, RMSE=2.6629, MAE=1.9564
#     Fold 4/5: R²=0.5203, RMSE=2.2849, MAE=1.7261
#     Fold 5/5: R²=0.4003, RMSE=2.7697, MAE=2.0441
#
#   SVR 5-Fold CV Results:
#     R²:   0.4535 ± 0.0650
#     RMSE: 2.4795 ± 0.2040
#     MAE:  1.8677 ± 0.1188
#
#   Training KNN...
#     Fold 1/5: R²=0.5383, RMSE=2.2687, MAE=1.7431
#     Fold 2/5: R²=0.4926, RMSE=2.2626, MAE=1.7298
#     Fold 3/5: R²=0.4427, RMSE=2.5360, MAE=1.8490
#     Fold 4/5: R²=0.4631, RMSE=2.4171, MAE=1.8292
#     Fold 5/5: R²=0.3251, RMSE=2.9383, MAE=2.1048
#
#   KNN 5-Fold CV Results:
#     R²:   0.4524 ± 0.0713
#     RMSE: 2.4845 ± 0.2486
#     MAE:  1.8512 ± 0.1351
#
#   Training Lasso...
#     Fold 1/5: R²=0.3876, RMSE=2.6129, MAE=2.0568
#     Fold 2/5: R²=0.2830, RMSE=2.6895, MAE=1.9835
#     Fold 3/5: R²=0.2490, RMSE=2.9439, MAE=2.2246
#     Fold 4/5: R²=0.2750, RMSE=2.8089, MAE=2.1468
#     Fold 5/5: R²=0.2798, RMSE=3.0352, MAE=2.3040
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2949 ± 0.0479
#     RMSE: 2.8181 ± 0.1560
#     MAE:  2.1432 ± 0.1144
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4595, RMSE=2.4547, MAE=1.9170
#     Fold 2/5: R²=0.3979, RMSE=2.4647, MAE=1.8281
#     Fold 3/5: R²=0.3767, RMSE=2.6818, MAE=1.9981
#     Fold 4/5: R²=0.4238, RMSE=2.5041, MAE=1.8974
#     Fold 5/5: R²=0.3707, RMSE=2.8372, MAE=2.0857
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4057 ± 0.0327
#     RMSE: 2.5885 ± 0.1489
#     MAE:  1.9453 ± 0.0887
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3776, RMSE=2.6342, MAE=2.1110
#     Fold 2/5: R²=0.2876, RMSE=2.6810, MAE=2.0248
#     Fold 3/5: R²=0.2836, RMSE=2.8752, MAE=2.1722
#     Fold 4/5: R²=0.3653, RMSE=2.6281, MAE=1.9627
#     Fold 5/5: R²=0.2461, RMSE=3.1054, MAE=2.3397
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.3120 ± 0.0508
#     RMSE: 2.7848 ± 0.1838
#     MAE:  2.1221 ± 0.1303
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3757, RMSE=2.6383, MAE=2.0526
#     Fold 2/5: R²=0.3187, RMSE=2.6217, MAE=1.9769
#     Fold 3/5: R²=0.4084, RMSE=2.6129, MAE=1.9659
#     Fold 4/5: R²=0.4046, RMSE=2.5455, MAE=1.9459
#     Fold 5/5: R²=0.3344, RMSE=2.9180, MAE=2.2072
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3683 ± 0.0363
#     RMSE: 2.6673 ± 0.1293
#     MAE:  2.0297 ± 0.0958
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3760, RMSE=2.6377, MAE=2.0449
#     Fold 2/5: R²=0.3063, RMSE=2.6455, MAE=2.0036
#     Fold 3/5: R²=0.4440, RMSE=2.5329, MAE=1.8878
#     Fold 4/5: R²=0.4298, RMSE=2.4909, MAE=1.9127
#     Fold 5/5: R²=0.3482, RMSE=2.8874, MAE=2.1777
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3809 ± 0.0511
#     RMSE: 2.6389 ± 0.1378
#     MAE:  2.0054 ± 0.1036
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2272, RMSE=2.9353, MAE=2.3502
#     Fold 2/5: R²=0.2526, RMSE=2.7460, MAE=2.1232
#     Fold 3/5: R²=0.2787, RMSE=2.8850, MAE=2.1750
#     Fold 4/5: R²=0.2785, RMSE=2.8021, MAE=2.1049
#     Fold 5/5: R²=0.2196, RMSE=3.1594, MAE=2.3370
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2513 ± 0.0248
#     RMSE: 2.9056 ± 0.1428
#     MAE:  2.2181 ± 0.1051
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3588, RMSE=2.6737, MAE=2.0524
#     Fold 2/5: R²=0.3388, RMSE=2.5829, MAE=1.9522
#     Fold 3/5: R²=0.3781, RMSE=2.6788, MAE=1.9593
#     Fold 4/5: R²=0.3958, RMSE=2.5642, MAE=1.9444
#     Fold 5/5: R²=0.3065, RMSE=2.9785, MAE=2.2382
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3556 ± 0.0311
#     RMSE: 2.6956 ± 0.1488
#     MAE:  2.0293 ± 0.1116
#
#   Training SVR...
#     Fold 1/5: R²=0.5391, RMSE=2.2669, MAE=1.7376
#     Fold 2/5: R²=0.4896, RMSE=2.2691, MAE=1.7436
#     Fold 3/5: R²=0.4943, RMSE=2.4157, MAE=1.7151
#     Fold 4/5: R²=0.5882, RMSE=2.1171, MAE=1.6308
#     Fold 5/5: R²=0.5160, RMSE=2.4882, MAE=1.8933
#
#   SVR 5-Fold CV Results:
#     R²:   0.5254 ± 0.0359
#     RMSE: 2.3114 ± 0.1294
#     MAE:  1.7441 ± 0.0849
#
#   Training KNN...
#     Fold 1/5: R²=0.4543, RMSE=2.4666, MAE=1.9169
#     Fold 2/5: R²=0.4414, RMSE=2.3740, MAE=1.7898
#     Fold 3/5: R²=0.3277, RMSE=2.7853, MAE=2.0427
#     Fold 4/5: R²=0.5131, RMSE=2.3019, MAE=1.7137
#     Fold 5/5: R²=0.3534, RMSE=2.8759, MAE=2.0531
#
#   KNN 5-Fold CV Results:
#     R²:   0.4180 ± 0.0682
#     RMSE: 2.5607 ± 0.2282
#     MAE:  1.9032 ± 0.1348
#
#   Training Lasso...
#     Fold 1/5: R²=0.3858, RMSE=2.6168, MAE=2.0649
#     Fold 2/5: R²=0.2630, RMSE=2.7268, MAE=2.0391
#     Fold 3/5: R²=0.3542, RMSE=2.7298, MAE=2.0019
#     Fold 4/5: R²=0.3528, RMSE=2.6538, MAE=2.0076
#     Fold 5/5: R²=0.3282, RMSE=2.9314, MAE=2.2296
#
#   Lasso 5-Fold CV Results:
#     R²:   0.3368 ± 0.0412
#     RMSE: 2.7317 ± 0.1088
#     MAE:  2.0686 ± 0.0836
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4469, RMSE=2.4832, MAE=1.9548
#     Fold 2/5: R²=0.4106, RMSE=2.4385, MAE=1.8206
#     Fold 3/5: R²=0.4533, RMSE=2.5117, MAE=1.8528
#     Fold 4/5: R²=0.4837, RMSE=2.3703, MAE=1.7906
#     Fold 5/5: R²=0.3975, RMSE=2.7762, MAE=2.0738
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4384 ± 0.0310
#     RMSE: 2.5160 ± 0.1386
#     MAE:  1.8985 ± 0.1036
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3696, RMSE=2.6511, MAE=2.1031
#     Fold 2/5: R²=0.3807, RMSE=2.4996, MAE=1.9128
#     Fold 3/5: R²=0.3414, RMSE=2.7567, MAE=2.0471
#     Fold 4/5: R²=0.4257, RMSE=2.4999, MAE=1.8759
#     Fold 5/5: R²=0.2915, RMSE=3.0104, MAE=2.2503
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.3618 ± 0.0444
#     RMSE: 2.6835 ± 0.1901
#     MAE:  2.0378 ± 0.1351
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4841, RMSE=2.3983, MAE=1.8628
#     Fold 2/5: R²=0.3634, RMSE=2.5344, MAE=1.8867
#     Fold 3/5: R²=0.3839, RMSE=2.6664, MAE=1.9932
#     Fold 4/5: R²=0.4241, RMSE=2.5034, MAE=1.9059
#     Fold 5/5: R²=0.3674, RMSE=2.8446, MAE=2.1640
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.4046 ± 0.0452
#     RMSE: 2.5894 ± 0.1536
#     MAE:  1.9625 ± 0.1099
#
#   Training LightGBM...
#     Fold 1/5: R²=0.4329, RMSE=2.5144, MAE=1.9424
#     Fold 2/5: R²=0.3816, RMSE=2.4979, MAE=1.8419
#     Fold 3/5: R²=0.4167, RMSE=2.5943, MAE=1.9153
#     Fold 4/5: R²=0.4595, RMSE=2.4252, MAE=1.8420
#     Fold 5/5: R²=0.3923, RMSE=2.7882, MAE=2.1543
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.4166 ± 0.0280
#     RMSE: 2.5640 ± 0.1243
#     MAE:  1.9392 ± 0.1147
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2737, RMSE=2.8456, MAE=2.2912
#     Fold 2/5: R²=0.2529, RMSE=2.7455, MAE=2.0707
#     Fold 3/5: R²=0.2436, RMSE=2.9544, MAE=2.2102
#     Fold 4/5: R²=0.2488, RMSE=2.8592, MAE=2.1283
#     Fold 5/5: R²=0.2328, RMSE=3.1327, MAE=2.3282
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2504 ± 0.0135
#     RMSE: 2.9075 ± 0.1306
#     MAE:  2.2057 ± 0.0965
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.4678, RMSE=2.4359, MAE=1.8688
#     Fold 2/5: R²=0.3273, RMSE=2.6052, MAE=1.9374
#     Fold 3/5: R²=0.3867, RMSE=2.6602, MAE=2.0026
#     Fold 4/5: R²=0.4142, RMSE=2.5249, MAE=1.9282
#     Fold 5/5: R²=0.3498, RMSE=2.8839, MAE=2.1846
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3892 ± 0.0494
#     RMSE: 2.6220 ± 0.1512
#     MAE:  1.9843 ± 0.1088
#
#   Training SVR...
#     Fold 1/5: R²=0.5831, RMSE=2.1560, MAE=1.6846
#     Fold 2/5: R²=0.4635, RMSE=2.3266, MAE=1.6875
#     Fold 3/5: R²=0.4419, RMSE=2.5377, MAE=1.8601
#     Fold 4/5: R²=0.6088, RMSE=2.0634, MAE=1.5378
#     Fold 5/5: R²=0.4924, RMSE=2.5480, MAE=1.9147
#
#   SVR 5-Fold CV Results:
#     R²:   0.5179 ± 0.0662
#     RMSE: 2.3263 ± 0.1960
#     MAE:  1.7369 ± 0.1353
#
#   Training KNN...
#     Fold 1/5: R²=0.5792, RMSE=2.1659, MAE=1.6771
#     Fold 2/5: R²=0.4984, RMSE=2.2495, MAE=1.6303
#     Fold 3/5: R²=0.3348, RMSE=2.7706, MAE=1.9228
#     Fold 4/5: R²=0.5864, RMSE=2.1216, MAE=1.5943
#     Fold 5/5: R²=0.3606, RMSE=2.8599, MAE=2.0896
#
#   KNN 5-Fold CV Results:
#     R²:   0.4719 ± 0.1063
#     RMSE: 2.4335 ± 0.3157
#     MAE:  1.7828 ± 0.1917
#
#   Training Lasso...
#     Fold 1/5: R²=0.4103, RMSE=2.5641, MAE=1.9997
#     Fold 2/5: R²=0.3137, RMSE=2.6314, MAE=1.9748
#     Fold 3/5: R²=0.3735, RMSE=2.6888, MAE=2.0421
#     Fold 4/5: R²=0.3890, RMSE=2.5787, MAE=1.9973
#     Fold 5/5: R²=0.3475, RMSE=2.8890, MAE=2.2072
#
#   Lasso 5-Fold CV Results:
#     R²:   0.3668 ± 0.0335
#     RMSE: 2.6704 ± 0.1178
#     MAE:  2.0442 ± 0.0843
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.5151, RMSE=2.3251, MAE=1.8233
#     Fold 2/5: R²=0.4353, RMSE=2.3870, MAE=1.7321
#     Fold 3/5: R²=0.4257, RMSE=2.5742, MAE=1.9033
#     Fold 4/5: R²=0.5065, RMSE=2.3174, MAE=1.7480
#     Fold 5/5: R²=0.4111, RMSE=2.7446, MAE=2.0450
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4587 ± 0.0433
#     RMSE: 2.4697 ± 0.1658
#     MAE:  1.8503 ± 0.1148
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.4139, RMSE=2.5562, MAE=2.0327
#     Fold 2/5: R²=0.3433, RMSE=2.5740, MAE=1.8941
#     Fold 3/5: R²=0.2604, RMSE=2.9214, MAE=2.2137
#     Fold 4/5: R²=0.4174, RMSE=2.5179, MAE=1.8919
#     Fold 5/5: R²=0.3395, RMSE=2.9066, MAE=2.1646
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.3549 ± 0.0578
#     RMSE: 2.6952 ± 0.1796
#     MAE:  2.0394 ± 0.1334
#
# ====================================================================================================
# NOISE TYPE: Low Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2669, RMSE=2.7132, MAE=2.1140
#     Fold 2/5: R²=0.2461, RMSE=2.9094, MAE=2.3457
#     Fold 3/5: R²=0.2498, RMSE=3.0552, MAE=2.2886
#     Fold 4/5: R²=0.2665, RMSE=2.7403, MAE=2.0659
#     Fold 5/5: R²=0.1688, RMSE=2.8380, MAE=2.3032
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2396 ± 0.0364
#     RMSE: 2.8512 ± 0.1237
#     MAE:  2.2235 ± 0.1117
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2772, RMSE=2.6939, MAE=2.1352
#     Fold 2/5: R²=0.1947, RMSE=3.0069, MAE=2.4096
#     Fold 3/5: R²=0.2632, RMSE=3.0278, MAE=2.2913
#     Fold 4/5: R²=0.2477, RMSE=2.7753, MAE=2.1150
#     Fold 5/5: R²=0.1569, RMSE=2.8581, MAE=2.3225
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2280 ± 0.0452
#     RMSE: 2.8724 ± 0.1294
#     MAE:  2.2547 ± 0.1129
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1603, RMSE=2.9036, MAE=2.3035
#     Fold 2/5: R²=0.1546, RMSE=3.0810, MAE=2.5239
#     Fold 3/5: R²=0.1421, RMSE=3.2671, MAE=2.4515
#     Fold 4/5: R²=0.1551, RMSE=2.9411, MAE=2.3278
#     Fold 5/5: R²=0.1039, RMSE=2.9466, MAE=2.4043
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1432 ± 0.0205
#     RMSE: 3.0279 ± 0.1339
#     MAE:  2.4022 ± 0.0806
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2471, RMSE=2.7494, MAE=2.1350
#     Fold 2/5: R²=0.2090, RMSE=2.9801, MAE=2.4172
#     Fold 3/5: R²=0.2566, RMSE=3.0413, MAE=2.2709
#     Fold 4/5: R²=0.2603, RMSE=2.7519, MAE=2.0773
#     Fold 5/5: R²=0.1645, RMSE=2.8452, MAE=2.3016
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2275 ± 0.0364
#     RMSE: 2.8736 ± 0.1187
#     MAE:  2.2404 ± 0.1213
#
#   Training SVR...
#     Fold 1/5: R²=0.3189, RMSE=2.6151, MAE=1.9637
#     Fold 2/5: R²=0.3678, RMSE=2.6642, MAE=2.1398
#     Fold 3/5: R²=0.3791, RMSE=2.7796, MAE=2.0542
#     Fold 4/5: R²=0.4135, RMSE=2.4505, MAE=1.7307
#     Fold 5/5: R²=0.2994, RMSE=2.6053, MAE=2.0012
#
#   SVR 5-Fold CV Results:
#     R²:   0.3557 ± 0.0414
#     RMSE: 2.6229 ± 0.1062
#     MAE:  1.9779 ± 0.1370
#
#   Training KNN...
#     Fold 1/5: R²=0.2825, RMSE=2.6841, MAE=2.0236
#     Fold 2/5: R²=0.4259, RMSE=2.5388, MAE=1.8694
#     Fold 3/5: R²=0.2948, RMSE=2.9622, MAE=2.1573
#     Fold 4/5: R²=0.4325, RMSE=2.4105, MAE=1.7797
#     Fold 5/5: R²=0.2597, RMSE=2.6782, MAE=1.9723
#
#   KNN 5-Fold CV Results:
#     R²:   0.3391 ± 0.0745
#     RMSE: 2.6548 ± 0.1839
#     MAE:  1.9604 ± 0.1295
#
#   Training Lasso...
#     Fold 1/5: R²=0.1555, RMSE=2.9120, MAE=2.2625
#     Fold 2/5: R²=0.2398, RMSE=2.9216, MAE=2.3880
#     Fold 3/5: R²=0.2373, RMSE=3.0805, MAE=2.2912
#     Fold 4/5: R²=0.1542, RMSE=2.9426, MAE=2.2709
#     Fold 5/5: R²=0.1823, RMSE=2.8147, MAE=2.2908
#
#   Lasso 5-Fold CV Results:
#     R²:   0.1938 ± 0.0379
#     RMSE: 2.9343 ± 0.0853
#     MAE:  2.3007 ± 0.0451
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3180, RMSE=2.6169, MAE=2.0312
#     Fold 2/5: R²=0.3290, RMSE=2.7448, MAE=2.2005
#     Fold 3/5: R²=0.3158, RMSE=2.9177, MAE=2.1313
#     Fold 4/5: R²=0.3495, RMSE=2.5807, MAE=1.9277
#     Fold 5/5: R²=0.2623, RMSE=2.6735, MAE=2.1400
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3149 ± 0.0289
#     RMSE: 2.7067 ± 0.1192
#     MAE:  2.0862 ± 0.0961
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1797, RMSE=2.8699, MAE=2.2786
#     Fold 2/5: R²=0.2364, RMSE=2.9280, MAE=2.3929
#     Fold 3/5: R²=0.1169, RMSE=3.3149, MAE=2.4692
#     Fold 4/5: R²=0.2222, RMSE=2.8219, MAE=2.2090
#     Fold 5/5: R²=0.1461, RMSE=2.8765, MAE=2.3338
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1802 ± 0.0450
#     RMSE: 2.9622 ± 0.1795
#     MAE:  2.3367 ± 0.0899
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3085, RMSE=2.6350, MAE=2.0012
#     Fold 2/5: R²=0.3645, RMSE=2.6712, MAE=2.1342
#     Fold 3/5: R²=0.2840, RMSE=2.9849, MAE=2.1840
#     Fold 4/5: R²=0.3149, RMSE=2.6484, MAE=2.0648
#     Fold 5/5: R²=0.2689, RMSE=2.6616, MAE=2.0636
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3081 ± 0.0327
#     RMSE: 2.7202 ± 0.1329
#     MAE:  2.0896 ± 0.0632
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2686, RMSE=2.7099, MAE=2.0730
#     Fold 2/5: R²=0.3876, RMSE=2.6221, MAE=2.0735
#     Fold 3/5: R²=0.2982, RMSE=2.9551, MAE=2.2238
#     Fold 4/5: R²=0.3055, RMSE=2.6666, MAE=2.0705
#     Fold 5/5: R²=0.3553, RMSE=2.4994, MAE=1.9707
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3230 ± 0.0427
#     RMSE: 2.6906 ± 0.1498
#     MAE:  2.0823 ± 0.0810
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2171, RMSE=2.8036, MAE=2.1996
#     Fold 2/5: R²=0.2176, RMSE=2.9639, MAE=2.4186
#     Fold 3/5: R²=0.1879, RMSE=3.1789, MAE=2.3775
#     Fold 4/5: R²=0.1896, RMSE=2.8805, MAE=2.2412
#     Fold 5/5: R²=0.1921, RMSE=2.7979, MAE=2.2428
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2009 ± 0.0136
#     RMSE: 2.9249 ± 0.1406
#     MAE:  2.2959 ± 0.0858
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2713, RMSE=2.7049, MAE=2.0531
#     Fold 2/5: R²=0.2987, RMSE=2.8061, MAE=2.1862
#     Fold 3/5: R²=0.2895, RMSE=2.9732, MAE=2.1745
#     Fold 4/5: R²=0.2679, RMSE=2.7379, MAE=2.1056
#     Fold 5/5: R²=0.2284, RMSE=2.7342, MAE=2.1429
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2712 ± 0.0242
#     RMSE: 2.7913 ± 0.0968
#     MAE:  2.1325 ± 0.0486
#
#   Training SVR...
#     Fold 1/5: R²=0.4803, RMSE=2.2844, MAE=1.7343
#     Fold 2/5: R²=0.5014, RMSE=2.3661, MAE=1.8568
#     Fold 3/5: R²=0.4234, RMSE=2.6786, MAE=1.8430
#     Fold 4/5: R²=0.4930, RMSE=2.2783, MAE=1.6649
#     Fold 5/5: R²=0.5019, RMSE=2.1969, MAE=1.6945
#
#   SVR 5-Fold CV Results:
#     R²:   0.4800 ± 0.0294
#     RMSE: 2.3609 ± 0.1676
#     MAE:  1.7587 ± 0.0778
#
#   Training KNN...
#     Fold 1/5: R²=0.4076, RMSE=2.4388, MAE=1.8216
#     Fold 2/5: R²=0.4040, RMSE=2.5868, MAE=2.0224
#     Fold 3/5: R²=0.3435, RMSE=2.8580, MAE=2.0888
#     Fold 4/5: R²=0.3505, RMSE=2.5788, MAE=1.8350
#     Fold 5/5: R²=0.3812, RMSE=2.4485, MAE=1.8409
#
#   KNN 5-Fold CV Results:
#     R²:   0.3774 ± 0.0265
#     RMSE: 2.5822 ± 0.1514
#     MAE:  1.9217 ± 0.1115
#
#   Training Lasso...
#     Fold 1/5: R²=0.1858, RMSE=2.8591, MAE=2.2062
#     Fold 2/5: R²=0.2727, RMSE=2.8577, MAE=2.3154
#     Fold 3/5: R²=0.0922, RMSE=3.3608, MAE=2.5188
#     Fold 4/5: R²=0.1529, RMSE=2.9450, MAE=2.2233
#     Fold 5/5: R²=0.1779, RMSE=2.8224, MAE=2.1930
#
#   Lasso 5-Fold CV Results:
#     R²:   0.1763 ± 0.0583
#     RMSE: 2.9690 ± 0.2000
#     MAE:  2.2913 ± 0.1216
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3725, RMSE=2.5101, MAE=1.8988
#     Fold 2/5: R²=0.4146, RMSE=2.5637, MAE=2.0511
#     Fold 3/5: R²=0.3225, RMSE=2.9033, MAE=2.1162
#     Fold 4/5: R²=0.3693, RMSE=2.5412, MAE=1.9224
#     Fold 5/5: R²=0.3661, RMSE=2.4783, MAE=1.9217
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3690 ± 0.0292
#     RMSE: 2.5993 ± 0.1547
#     MAE:  1.9820 ± 0.0859
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1791, RMSE=2.8710, MAE=2.2920
#     Fold 2/5: R²=0.1599, RMSE=3.0713, MAE=2.5306
#     Fold 3/5: R²=0.0271, RMSE=3.4793, MAE=2.6248
#     Fold 4/5: R²=0.2152, RMSE=2.8346, MAE=2.2155
#     Fold 5/5: R²=0.0116, RMSE=3.0947, MAE=2.5377
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1186 ± 0.0831
#     RMSE: 3.0702 ± 0.2294
#     MAE:  2.4401 ± 0.1576
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3597, RMSE=2.5356, MAE=1.9393
#     Fold 2/5: R²=0.4024, RMSE=2.5903, MAE=2.1218
#     Fold 3/5: R²=0.3547, RMSE=2.8337, MAE=2.1681
#     Fold 4/5: R²=0.1994, RMSE=2.8630, MAE=2.1645
#     Fold 5/5: R²=0.2472, RMSE=2.7008, MAE=2.1093
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3127 ± 0.0763
#     RMSE: 2.7047 ± 0.1291
#     MAE:  2.1006 ± 0.0839
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3430, RMSE=2.5683, MAE=1.9818
#     Fold 2/5: R²=0.3715, RMSE=2.6564, MAE=2.1584
#     Fold 3/5: R²=0.3291, RMSE=2.8893, MAE=2.2176
#     Fold 4/5: R²=0.2947, RMSE=2.6873, MAE=1.9982
#     Fold 5/5: R²=0.2415, RMSE=2.7109, MAE=2.1100
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3160 ± 0.0447
#     RMSE: 2.7024 ± 0.1052
#     MAE:  2.0932 ± 0.0910
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1929, RMSE=2.8467, MAE=2.2505
#     Fold 2/5: R²=0.1952, RMSE=3.0060, MAE=2.4776
#     Fold 3/5: R²=0.1539, RMSE=3.2446, MAE=2.4146
#     Fold 4/5: R²=0.1792, RMSE=2.8989, MAE=2.2685
#     Fold 5/5: R²=0.1616, RMSE=2.8501, MAE=2.3050
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1766 ± 0.0165
#     RMSE: 2.9692 ± 0.1492
#     MAE:  2.3432 ± 0.0881
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3570, RMSE=2.5408, MAE=2.0060
#     Fold 2/5: R²=0.3754, RMSE=2.6482, MAE=2.2012
#     Fold 3/5: R²=0.3251, RMSE=2.8979, MAE=2.1759
#     Fold 4/5: R²=0.2152, RMSE=2.8345, MAE=2.1395
#     Fold 5/5: R²=0.2338, RMSE=2.7247, MAE=2.1597
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3013 ± 0.0650
#     RMSE: 2.7292 ± 0.1278
#     MAE:  2.1364 ± 0.0683
#
#   Training SVR...
#     Fold 1/5: R²=0.4845, RMSE=2.2751, MAE=1.7004
#     Fold 2/5: R²=0.4472, RMSE=2.4914, MAE=2.0137
#     Fold 3/5: R²=0.4561, RMSE=2.6015, MAE=1.9408
#     Fold 4/5: R²=0.4225, RMSE=2.4316, MAE=1.7502
#     Fold 5/5: R²=0.4268, RMSE=2.3566, MAE=1.7503
#
#   SVR 5-Fold CV Results:
#     R²:   0.4474 ± 0.0223
#     RMSE: 2.4312 ± 0.1119
#     MAE:  1.8311 ± 0.1229
#
#   Training KNN...
#     Fold 1/5: R²=0.4364, RMSE=2.3789, MAE=1.7971
#     Fold 2/5: R²=0.4848, RMSE=2.4051, MAE=1.8961
#     Fold 3/5: R²=0.4325, RMSE=2.6572, MAE=1.9102
#     Fold 4/5: R²=0.3865, RMSE=2.5061, MAE=1.7968
#     Fold 5/5: R²=0.4300, RMSE=2.3502, MAE=1.6817
#
#   KNN 5-Fold CV Results:
#     R²:   0.4340 ± 0.0312
#     RMSE: 2.4595 ± 0.1120
#     MAE:  1.8164 ± 0.0825
#
#   Training Lasso...
#     Fold 1/5: R²=0.2703, RMSE=2.7067, MAE=2.0715
#     Fold 2/5: R²=0.3519, RMSE=2.6976, MAE=2.2143
#     Fold 3/5: R²=0.2367, RMSE=3.0818, MAE=2.3279
#     Fold 4/5: R²=0.2351, RMSE=2.7985, MAE=2.0962
#     Fold 5/5: R²=0.2168, RMSE=2.7547, MAE=2.1896
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2622 ± 0.0481
#     RMSE: 2.8079 ± 0.1417
#     MAE:  2.1799 ± 0.0916
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4198, RMSE=2.4136, MAE=1.8373
#     Fold 2/5: R²=0.4325, RMSE=2.5242, MAE=2.0735
#     Fold 3/5: R²=0.3797, RMSE=2.7781, MAE=2.0781
#     Fold 4/5: R²=0.3472, RMSE=2.5853, MAE=1.9342
#     Fold 5/5: R²=0.3443, RMSE=2.5206, MAE=1.9459
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3847 ± 0.0363
#     RMSE: 2.5644 ± 0.1203
#     MAE:  1.9738 ± 0.0914
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2538, RMSE=2.7372, MAE=2.1385
#     Fold 2/5: R²=0.3270, RMSE=2.7489, MAE=2.2600
#     Fold 3/5: R²=0.1662, RMSE=3.2210, MAE=2.4076
#     Fold 4/5: R²=0.2418, RMSE=2.7862, MAE=2.1354
#     Fold 5/5: R²=0.1672, RMSE=2.8406, MAE=2.2751
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2312 ± 0.0602
#     RMSE: 2.8668 ± 0.1808
#     MAE:  2.2433 ± 0.1009
#
# ====================================================================================================
# NOISE TYPE: Mid Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3446, RMSE=2.5949, MAE=2.0174
#     Fold 2/5: R²=0.2422, RMSE=2.7483, MAE=2.1258
#     Fold 3/5: R²=0.2584, RMSE=2.8546, MAE=2.1272
#     Fold 4/5: R²=0.3564, RMSE=2.5403, MAE=1.9824
#     Fold 5/5: R²=0.2641, RMSE=2.9287, MAE=2.1881
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2932 ± 0.0475
#     RMSE: 2.7334 ± 0.1480
#     MAE:  2.0882 ± 0.0763
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3917, RMSE=2.4999, MAE=1.9678
#     Fold 2/5: R²=0.3105, RMSE=2.6215, MAE=2.0113
#     Fold 3/5: R²=0.2745, RMSE=2.8235, MAE=2.0931
#     Fold 4/5: R²=0.3239, RMSE=2.6038, MAE=1.9995
#     Fold 5/5: R²=0.2451, RMSE=2.9662, MAE=2.2487
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3091 ± 0.0497
#     RMSE: 2.7030 ± 0.1682
#     MAE:  2.0641 ± 0.1012
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2356, RMSE=2.8024, MAE=2.2165
#     Fold 2/5: R²=0.1719, RMSE=2.8730, MAE=2.2177
#     Fold 3/5: R²=0.1824, RMSE=2.9973, MAE=2.2350
#     Fold 4/5: R²=0.2117, RMSE=2.8115, MAE=2.1637
#     Fold 5/5: R²=0.1903, RMSE=3.0722, MAE=2.3152
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1984 ± 0.0227
#     RMSE: 2.9113 ± 0.1064
#     MAE:  2.2296 ± 0.0490
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3858, RMSE=2.5120, MAE=1.9323
#     Fold 2/5: R²=0.2755, RMSE=2.6873, MAE=2.0567
#     Fold 3/5: R²=0.2555, RMSE=2.8601, MAE=2.1606
#     Fold 4/5: R²=0.3369, RMSE=2.5786, MAE=1.9947
#     Fold 5/5: R²=0.2576, RMSE=2.9415, MAE=2.2226
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3023 ± 0.0511
#     RMSE: 2.7159 ± 0.1631
#     MAE:  2.0734 ± 0.1061
#
#   Training SVR...
#     Fold 1/5: R²=0.4654, RMSE=2.3436, MAE=1.8239
#     Fold 2/5: R²=0.3809, RMSE=2.4841, MAE=1.9416
#     Fold 3/5: R²=0.3705, RMSE=2.6301, MAE=1.8832
#     Fold 4/5: R²=0.4991, RMSE=2.2410, MAE=1.7276
#     Fold 5/5: R²=0.3754, RMSE=2.6981, MAE=2.0253
#
#   SVR 5-Fold CV Results:
#     R²:   0.4183 ± 0.0534
#     RMSE: 2.4794 ± 0.1708
#     MAE:  1.8803 ± 0.1013
#
#   Training KNN...
#     Fold 1/5: R²=0.5084, RMSE=2.2473, MAE=1.6987
#     Fold 2/5: R²=0.4640, RMSE=2.3114, MAE=1.7574
#     Fold 3/5: R²=0.4054, RMSE=2.5561, MAE=1.8406
#     Fold 4/5: R²=0.4609, RMSE=2.3250, MAE=1.7576
#     Fold 5/5: R²=0.3764, RMSE=2.6960, MAE=1.9463
#
#   KNN 5-Fold CV Results:
#     R²:   0.4430 ± 0.0467
#     RMSE: 2.4272 ± 0.1703
#     MAE:  1.8001 ± 0.0860
#
#   Training Lasso...
#     Fold 1/5: R²=0.3071, RMSE=2.6682, MAE=2.0659
#     Fold 2/5: R²=0.2336, RMSE=2.7640, MAE=2.1104
#     Fold 3/5: R²=0.2168, RMSE=2.9336, MAE=2.2133
#     Fold 4/5: R²=0.2304, RMSE=2.7779, MAE=2.1830
#     Fold 5/5: R²=0.2749, RMSE=2.9072, MAE=2.2262
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2525 ± 0.0335
#     RMSE: 2.8102 ± 0.0979
#     MAE:  2.1598 ± 0.0618
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4359, RMSE=2.4075, MAE=1.8831
#     Fold 2/5: R²=0.3590, RMSE=2.5276, MAE=1.9395
#     Fold 3/5: R²=0.3473, RMSE=2.6780, MAE=1.9835
#     Fold 4/5: R²=0.4201, RMSE=2.4114, MAE=1.8668
#     Fold 5/5: R²=0.3424, RMSE=2.7686, MAE=2.0764
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3809 ± 0.0391
#     RMSE: 2.5586 ± 0.1441
#     MAE:  1.9499 ± 0.0757
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3390, RMSE=2.6061, MAE=2.0783
#     Fold 2/5: R²=0.3053, RMSE=2.6314, MAE=2.0551
#     Fold 3/5: R²=0.2589, RMSE=2.8537, MAE=2.1190
#     Fold 4/5: R²=0.3853, RMSE=2.4827, MAE=1.8947
#     Fold 5/5: R²=0.2563, RMSE=2.9442, MAE=2.1940
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.3090 ± 0.0490
#     RMSE: 2.7036 ± 0.1697
#     MAE:  2.0682 ± 0.0988
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4150, RMSE=2.4517, MAE=1.9305
#     Fold 2/5: R²=0.3730, RMSE=2.4998, MAE=1.8464
#     Fold 3/5: R²=0.3597, RMSE=2.6524, MAE=1.9742
#     Fold 4/5: R²=0.3940, RMSE=2.4651, MAE=1.8796
#     Fold 5/5: R²=0.2891, RMSE=2.8785, MAE=2.1019
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3662 ± 0.0428
#     RMSE: 2.5895 ± 0.1612
#     MAE:  1.9465 ± 0.0891
#
#   Training LightGBM...
#     Fold 1/5: R²=0.4254, RMSE=2.4297, MAE=1.8789
#     Fold 2/5: R²=0.3785, RMSE=2.4889, MAE=1.8560
#     Fold 3/5: R²=0.3823, RMSE=2.6052, MAE=1.9575
#     Fold 4/5: R²=0.4653, RMSE=2.3155, MAE=1.7593
#     Fold 5/5: R²=0.3422, RMSE=2.7689, MAE=2.0663
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3988 ± 0.0425
#     RMSE: 2.5216 ± 0.1550
#     MAE:  1.9036 ± 0.1030
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2463, RMSE=2.7828, MAE=2.2134
#     Fold 2/5: R²=0.2608, RMSE=2.7145, MAE=2.0690
#     Fold 3/5: R²=0.2276, RMSE=2.9132, MAE=2.1775
#     Fold 4/5: R²=0.2796, RMSE=2.6876, MAE=2.0424
#     Fold 5/5: R²=0.2520, RMSE=2.9527, MAE=2.1770
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2533 ± 0.0171
#     RMSE: 2.8102 ± 0.1057
#     MAE:  2.1358 ± 0.0673
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.4066, RMSE=2.4692, MAE=1.9775
#     Fold 2/5: R²=0.3625, RMSE=2.5208, MAE=1.8452
#     Fold 3/5: R²=0.3244, RMSE=2.7247, MAE=1.9982
#     Fold 4/5: R²=0.3822, RMSE=2.4889, MAE=1.8789
#     Fold 5/5: R²=0.2962, RMSE=2.8642, MAE=2.0931
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3544 ± 0.0396
#     RMSE: 2.6136 ± 0.1550
#     MAE:  1.9586 ± 0.0886
#
#   Training SVR...
#     Fold 1/5: R²=0.5402, RMSE=2.1736, MAE=1.7037
#     Fold 2/5: R²=0.5008, RMSE=2.2306, MAE=1.7013
#     Fold 3/5: R²=0.4522, RMSE=2.4535, MAE=1.7797
#     Fold 4/5: R²=0.5523, RMSE=2.1186, MAE=1.5847
#     Fold 5/5: R²=0.5236, RMSE=2.3564, MAE=1.7958
#
#   SVR 5-Fold CV Results:
#     R²:   0.5138 ± 0.0353
#     RMSE: 2.2665 ± 0.1223
#     MAE:  1.7130 ± 0.0748
#
#   Training KNN...
#     Fold 1/5: R²=0.4613, RMSE=2.3526, MAE=1.7994
#     Fold 2/5: R²=0.4404, RMSE=2.3618, MAE=1.7458
#     Fold 3/5: R²=0.3257, RMSE=2.7220, MAE=1.9891
#     Fold 4/5: R²=0.4413, RMSE=2.3669, MAE=1.7754
#     Fold 5/5: R²=0.3699, RMSE=2.7099, MAE=1.9744
#
#   KNN 5-Fold CV Results:
#     R²:   0.4077 ± 0.0514
#     RMSE: 2.5026 ± 0.1743
#     MAE:  1.8568 ± 0.1035
#
#   Training Lasso...
#     Fold 1/5: R²=0.3467, RMSE=2.5908, MAE=2.0609
#     Fold 2/5: R²=0.2706, RMSE=2.6963, MAE=2.0047
#     Fold 3/5: R²=0.2602, RMSE=2.8512, MAE=2.1198
#     Fold 4/5: R²=0.3745, RMSE=2.5043, MAE=1.9329
#     Fold 5/5: R²=0.3129, RMSE=2.8300, MAE=2.1023
#
#   Lasso 5-Fold CV Results:
#     R²:   0.3130 ± 0.0436
#     RMSE: 2.6945 ± 0.1340
#     MAE:  2.0441 ± 0.0683
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4653, RMSE=2.3438, MAE=1.8432
#     Fold 2/5: R²=0.4264, RMSE=2.3912, MAE=1.7715
#     Fold 3/5: R²=0.3970, RMSE=2.5741, MAE=1.9091
#     Fold 4/5: R²=0.4737, RMSE=2.2972, MAE=1.7391
#     Fold 5/5: R²=0.3919, RMSE=2.6623, MAE=1.9690
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4309 ± 0.0338
#     RMSE: 2.4537 ± 0.1404
#     MAE:  1.8464 ± 0.0850
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3785, RMSE=2.5270, MAE=2.0243
#     Fold 2/5: R²=0.3625, RMSE=2.5209, MAE=1.9292
#     Fold 3/5: R²=0.2995, RMSE=2.7744, MAE=2.0534
#     Fold 4/5: R²=0.4420, RMSE=2.3655, MAE=1.7907
#     Fold 5/5: R²=0.2913, RMSE=2.8740, MAE=2.1574
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.3547 ± 0.0553
#     RMSE: 2.6123 ± 0.1851
#     MAE:  1.9910 ± 0.1238
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4383, RMSE=2.4024, MAE=1.8752
#     Fold 2/5: R²=0.4084, RMSE=2.4283, MAE=1.7967
#     Fold 3/5: R²=0.3594, RMSE=2.6531, MAE=1.9449
#     Fold 4/5: R²=0.4186, RMSE=2.4145, MAE=1.8571
#     Fold 5/5: R²=0.3015, RMSE=2.8532, MAE=2.1276
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3852 ± 0.0493
#     RMSE: 2.5503 ± 0.1775
#     MAE:  1.9203 ± 0.1139
#
#   Training LightGBM...
#     Fold 1/5: R²=0.4395, RMSE=2.3998, MAE=1.9097
#     Fold 2/5: R²=0.4023, RMSE=2.4407, MAE=1.8282
#     Fold 3/5: R²=0.3187, RMSE=2.7361, MAE=1.9917
#     Fold 4/5: R²=0.4111, RMSE=2.4300, MAE=1.8416
#     Fold 5/5: R²=0.3602, RMSE=2.7307, MAE=2.0833
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3864 ± 0.0423
#     RMSE: 2.5475 ± 0.1524
#     MAE:  1.9309 ± 0.0958
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2719, RMSE=2.7351, MAE=2.1510
#     Fold 2/5: R²=0.2520, RMSE=2.7305, MAE=2.0800
#     Fold 3/5: R²=0.2078, RMSE=2.9504, MAE=2.2361
#     Fold 4/5: R²=0.2531, RMSE=2.7366, MAE=2.0720
#     Fold 5/5: R²=0.1967, RMSE=3.0600, MAE=2.2709
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2363 ± 0.0289
#     RMSE: 2.8425 ± 0.1373
#     MAE:  2.1620 ± 0.0804
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.4659, RMSE=2.3425, MAE=1.8245
#     Fold 2/5: R²=0.3645, RMSE=2.5168, MAE=1.8629
#     Fold 3/5: R²=0.3362, RMSE=2.7007, MAE=1.9908
#     Fold 4/5: R²=0.4130, RMSE=2.4260, MAE=1.9106
#     Fold 5/5: R²=0.3213, RMSE=2.8126, MAE=2.1064
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3802 ± 0.0531
#     RMSE: 2.5597 ± 0.1736
#     MAE:  1.9390 ± 0.1004
#
#   Training SVR...
#     Fold 1/5: R²=0.5632, RMSE=2.1184, MAE=1.6779
#     Fold 2/5: R²=0.4670, RMSE=2.3049, MAE=1.6831
#     Fold 3/5: R²=0.4392, RMSE=2.4822, MAE=1.7667
#     Fold 4/5: R²=0.5589, RMSE=2.1030, MAE=1.5783
#     Fold 5/5: R²=0.5067, RMSE=2.3978, MAE=1.8049
#
#   SVR 5-Fold CV Results:
#     R²:   0.5070 ± 0.0491
#     RMSE: 2.2813 ± 0.1502
#     MAE:  1.7022 ± 0.0787
#
#   Training KNN...
#     Fold 1/5: R²=0.5996, RMSE=2.0283, MAE=1.5716
#     Fold 2/5: R²=0.4820, RMSE=2.2722, MAE=1.6458
#     Fold 3/5: R²=0.3052, RMSE=2.7631, MAE=1.8797
#     Fold 4/5: R²=0.6063, RMSE=1.9870, MAE=1.5111
#     Fold 5/5: R²=0.4322, RMSE=2.5725, MAE=1.8598
#
#   KNN 5-Fold CV Results:
#     R²:   0.4851 ± 0.1122
#     RMSE: 2.3246 ± 0.3027
#     MAE:  1.6936 ± 0.1502
#
#   Training Lasso...
#     Fold 1/5: R²=0.3639, RMSE=2.5565, MAE=1.9925
#     Fold 2/5: R²=0.3056, RMSE=2.6309, MAE=1.9722
#     Fold 3/5: R²=0.2830, RMSE=2.8068, MAE=2.0980
#     Fold 4/5: R²=0.3520, RMSE=2.5491, MAE=2.0432
#     Fold 5/5: R²=0.2980, RMSE=2.8605, MAE=2.1493
#
#   Lasso 5-Fold CV Results:
#     R²:   0.3205 ± 0.0316
#     RMSE: 2.6808 ± 0.1292
#     MAE:  2.0510 ± 0.0657
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.5006, RMSE=2.2652, MAE=1.7833
#     Fold 2/5: R²=0.4347, RMSE=2.3738, MAE=1.7426
#     Fold 3/5: R²=0.3814, RMSE=2.6072, MAE=1.8943
#     Fold 4/5: R²=0.4983, RMSE=2.2428, MAE=1.7256
#     Fold 5/5: R²=0.4032, RMSE=2.6375, MAE=1.9515
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4436 ± 0.0486
#     RMSE: 2.4253 ± 0.1672
#     MAE:  1.8195 ± 0.0884
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3856, RMSE=2.5125, MAE=1.9882
#     Fold 2/5: R²=0.3415, RMSE=2.5620, MAE=1.9179
#     Fold 3/5: R²=0.1843, RMSE=2.9938, MAE=2.2487
#     Fold 4/5: R²=0.4586, RMSE=2.3300, MAE=1.7472
#     Fold 5/5: R²=0.3232, RMSE=2.8087, MAE=2.0907
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.3386 ± 0.0902
#     RMSE: 2.6414 ± 0.2333
#     MAE:  1.9986 ± 0.1678
#
# ====================================================================================================
# NOISE TYPE: High Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3137, RMSE=3.0664, MAE=2.3150
#     Fold 2/5: R²=0.2963, RMSE=3.0504, MAE=2.2314
#     Fold 3/5: R²=0.2462, RMSE=3.3035, MAE=2.3672
#     Fold 4/5: R²=0.3166, RMSE=3.0832, MAE=2.2474
#     Fold 5/5: R²=0.2654, RMSE=3.2441, MAE=2.5410
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2877 ± 0.0276
#     RMSE: 3.1495 ± 0.1037
#     MAE:  2.3404 ± 0.1115
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2941, RMSE=3.1099, MAE=2.3164
#     Fold 2/5: R²=0.2840, RMSE=3.0770, MAE=2.3014
#     Fold 3/5: R²=0.2322, RMSE=3.3342, MAE=2.4073
#     Fold 4/5: R²=0.3264, RMSE=3.0611, MAE=2.2171
#     Fold 5/5: R²=0.2156, RMSE=3.3522, MAE=2.6032
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2705 ± 0.0408
#     RMSE: 3.1869 ± 0.1287
#     MAE:  2.3691 ± 0.1317
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2095, RMSE=3.2910, MAE=2.4328
#     Fold 2/5: R²=0.1542, RMSE=3.3443, MAE=2.3620
#     Fold 3/5: R²=0.1557, RMSE=3.4963, MAE=2.5312
#     Fold 4/5: R²=0.2016, RMSE=3.3325, MAE=2.3357
#     Fold 5/5: R²=0.1862, RMSE=3.4145, MAE=2.6142
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1814 ± 0.0229
#     RMSE: 3.3757 ± 0.0722
#     MAE:  2.4552 ± 0.1044
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3106, RMSE=3.0732, MAE=2.2975
#     Fold 2/5: R²=0.2892, RMSE=3.0659, MAE=2.2906
#     Fold 3/5: R²=0.2400, RMSE=3.3172, MAE=2.3913
#     Fold 4/5: R²=0.3100, RMSE=3.0981, MAE=2.2639
#     Fold 5/5: R²=0.2562, RMSE=3.2643, MAE=2.5412
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2812 ± 0.0286
#     RMSE: 3.1637 ± 0.1056
#     MAE:  2.3569 ± 0.1017
#
#   Training SVR...
#     Fold 1/5: R²=0.4356, RMSE=2.7808, MAE=2.0821
#     Fold 2/5: R²=0.3567, RMSE=2.9166, MAE=2.1683
#     Fold 3/5: R²=0.3091, RMSE=3.1627, MAE=2.3014
#     Fold 4/5: R²=0.4642, RMSE=2.7301, MAE=1.9594
#     Fold 5/5: R²=0.3258, RMSE=3.1079, MAE=2.4083
#
#   SVR 5-Fold CV Results:
#     R²:   0.3783 ± 0.0611
#     RMSE: 2.9396 ± 0.1719
#     MAE:  2.1839 ± 0.1582
#
#   Training KNN...
#     Fold 1/5: R²=0.4086, RMSE=2.8464, MAE=2.1405
#     Fold 2/5: R²=0.3772, RMSE=2.8698, MAE=2.1498
#     Fold 3/5: R²=0.3635, RMSE=3.0357, MAE=2.1927
#     Fold 4/5: R²=0.4507, RMSE=2.7643, MAE=1.9403
#     Fold 5/5: R²=0.2395, RMSE=3.3009, MAE=2.4806
#
#   KNN 5-Fold CV Results:
#     R²:   0.3679 ± 0.0709
#     RMSE: 2.9634 ± 0.1904
#     MAE:  2.1808 ± 0.1735
#
#   Training Lasso...
#     Fold 1/5: R²=0.2563, RMSE=3.1920, MAE=2.3835
#     Fold 2/5: R²=0.2811, RMSE=3.0833, MAE=2.3166
#     Fold 3/5: R²=0.1516, RMSE=3.5047, MAE=2.5301
#     Fold 4/5: R²=0.2648, RMSE=3.1980, MAE=2.3460
#     Fold 5/5: R²=0.2451, RMSE=3.2887, MAE=2.5702
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2398 ± 0.0456
#     RMSE: 3.2533 ± 0.1415
#     MAE:  2.4293 ± 0.1017
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3717, RMSE=2.9339, MAE=2.1771
#     Fold 2/5: R²=0.3516, RMSE=2.9282, MAE=2.1337
#     Fold 3/5: R²=0.2963, RMSE=3.1919, MAE=2.2703
#     Fold 4/5: R²=0.3902, RMSE=2.9125, MAE=2.0757
#     Fold 5/5: R²=0.3063, RMSE=3.1526, MAE=2.4600
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3432 ± 0.0365
#     RMSE: 3.0238 ± 0.1220
#     MAE:  2.2234 ± 0.1343
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1186, RMSE=3.4749, MAE=2.5750
#     Fold 2/5: R²=0.1721, RMSE=3.3088, MAE=2.3498
#     Fold 3/5: R²=-0.0288, RMSE=3.8594, MAE=2.7874
#     Fold 4/5: R²=0.1252, RMSE=3.4883, MAE=2.4509
#     Fold 5/5: R²=0.0766, RMSE=3.6372, MAE=2.7578
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.0928 ± 0.0679
#     RMSE: 3.5537 ± 0.1849
#     MAE:  2.5842 ± 0.1698
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3621, RMSE=2.9562, MAE=2.1503
#     Fold 2/5: R²=0.3231, RMSE=2.9919, MAE=2.1414
#     Fold 3/5: R²=0.3470, RMSE=3.0748, MAE=2.2389
#     Fold 4/5: R²=0.3470, RMSE=3.0139, MAE=2.0939
#     Fold 5/5: R²=0.2015, RMSE=3.3824, MAE=2.4817
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3161 ± 0.0587
#     RMSE: 3.0838 ± 0.1542
#     MAE:  2.2212 ± 0.1384
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3793, RMSE=2.9160, MAE=2.1341
#     Fold 2/5: R²=0.2970, RMSE=3.0491, MAE=2.1683
#     Fold 3/5: R²=0.3246, RMSE=3.1271, MAE=2.2727
#     Fold 4/5: R²=0.3933, RMSE=2.9050, MAE=2.0554
#     Fold 5/5: R²=0.2129, RMSE=3.3581, MAE=2.4656
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3214 ± 0.0647
#     RMSE: 3.0710 ± 0.1659
#     MAE:  2.2192 ± 0.1416
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2152, RMSE=3.2791, MAE=2.4190
#     Fold 2/5: R²=0.2635, RMSE=3.1207, MAE=2.2564
#     Fold 3/5: R²=0.2527, RMSE=3.2892, MAE=2.3730
#     Fold 4/5: R²=0.2414, RMSE=3.2485, MAE=2.2858
#     Fold 5/5: R²=0.1718, RMSE=3.4447, MAE=2.5899
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2289 ± 0.0328
#     RMSE: 3.2764 ± 0.1034
#     MAE:  2.3848 ± 0.1181
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2677, RMSE=3.1674, MAE=2.3224
#     Fold 2/5: R²=0.2918, RMSE=3.0602, MAE=2.1944
#     Fold 3/5: R²=0.3640, RMSE=3.0344, MAE=2.1895
#     Fold 4/5: R²=0.3140, RMSE=3.0890, MAE=2.2202
#     Fold 5/5: R²=0.1309, RMSE=3.5287, MAE=2.6067
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2737 ± 0.0782
#     RMSE: 3.1759 ± 0.1819
#     MAE:  2.3066 ± 0.1575
#
#   Training SVR...
#     Fold 1/5: R²=0.5100, RMSE=2.5909, MAE=1.9309
#     Fold 2/5: R²=0.5183, RMSE=2.5239, MAE=1.9124
#     Fold 3/5: R²=0.5613, RMSE=2.5203, MAE=1.7727
#     Fold 4/5: R²=0.6328, RMSE=2.2601, MAE=1.6307
#     Fold 5/5: R²=0.4235, RMSE=2.8739, MAE=2.0979
#
#   SVR 5-Fold CV Results:
#     R²:   0.5292 ± 0.0684
#     RMSE: 2.5538 ± 0.1960
#     MAE:  1.8689 ± 0.1576
#
#   Training KNN...
#     Fold 1/5: R²=0.4653, RMSE=2.7065, MAE=2.1052
#     Fold 2/5: R²=0.4015, RMSE=2.8132, MAE=2.0181
#     Fold 3/5: R²=0.4341, RMSE=2.8623, MAE=1.9366
#     Fold 4/5: R²=0.5416, RMSE=2.5251, MAE=1.8432
#     Fold 5/5: R²=0.3226, RMSE=3.1153, MAE=2.3124
#
#   KNN 5-Fold CV Results:
#     R²:   0.4330 ± 0.0722
#     RMSE: 2.8045 ± 0.1937
#     MAE:  2.0431 ± 0.1602
#
#   Training Lasso...
#     Fold 1/5: R²=0.2299, RMSE=3.2482, MAE=2.4207
#     Fold 2/5: R²=0.2596, RMSE=3.1291, MAE=2.3241
#     Fold 3/5: R²=0.2220, RMSE=3.3562, MAE=2.4349
#     Fold 4/5: R²=0.2082, RMSE=3.3188, MAE=2.3950
#     Fold 5/5: R²=0.2391, RMSE=3.3017, MAE=2.5526
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2317 ± 0.0172
#     RMSE: 3.2708 ± 0.0789
#     MAE:  2.4254 ± 0.0741
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4201, RMSE=2.8186, MAE=2.0790
#     Fold 2/5: R²=0.4248, RMSE=2.7580, MAE=2.0088
#     Fold 3/5: R²=0.4170, RMSE=2.9054, MAE=2.0570
#     Fold 4/5: R²=0.4520, RMSE=2.7610, MAE=1.9491
#     Fold 5/5: R²=0.3180, RMSE=3.1258, MAE=2.3316
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4064 ± 0.0459
#     RMSE: 2.8738 ± 0.1369
#     MAE:  2.0851 ± 0.1311
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3075, RMSE=3.0802, MAE=2.2705
#     Fold 2/5: R²=0.2958, RMSE=3.0515, MAE=2.1863
#     Fold 3/5: R²=-0.0434, RMSE=3.8866, MAE=2.8105
#     Fold 4/5: R²=-0.0429, RMSE=3.8088, MAE=2.6632
#     Fold 5/5: R²=0.2922, RMSE=3.1843, MAE=2.4030
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1619 ± 0.1674
#     RMSE: 3.4023 ± 0.3672
#     MAE:  2.4667 ± 0.2358
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4202, RMSE=2.8184, MAE=2.1728
#     Fold 2/5: R²=0.3214, RMSE=2.9956, MAE=2.2128
#     Fold 3/5: R²=0.3576, RMSE=3.0497, MAE=2.1899
#     Fold 4/5: R²=0.3616, RMSE=2.9799, MAE=2.1811
#     Fold 5/5: R²=0.2690, RMSE=3.2362, MAE=2.4898
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3460 ± 0.0498
#     RMSE: 3.0160 ± 0.1345
#     MAE:  2.2493 ± 0.1210
#
#   Training LightGBM...
#     Fold 1/5: R²=0.4182, RMSE=2.8232, MAE=2.1718
#     Fold 2/5: R²=0.3400, RMSE=2.9542, MAE=2.1890
#     Fold 3/5: R²=0.3462, RMSE=3.0766, MAE=2.2480
#     Fold 4/5: R²=0.3951, RMSE=2.9007, MAE=2.1910
#     Fold 5/5: R²=0.3011, RMSE=3.1644, MAE=2.4848
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3601 ± 0.0417
#     RMSE: 2.9838 ± 0.1223
#     MAE:  2.2569 ± 0.1168
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2435, RMSE=3.2194, MAE=2.3705
#     Fold 2/5: R²=0.2080, RMSE=3.2362, MAE=2.3006
#     Fold 3/5: R²=0.1871, RMSE=3.4307, MAE=2.4039
#     Fold 4/5: R²=0.2167, RMSE=3.3009, MAE=2.3433
#     Fold 5/5: R²=0.1836, RMSE=3.4199, MAE=2.5852
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2078 ± 0.0218
#     RMSE: 3.3214 ± 0.0891
#     MAE:  2.4007 ± 0.0982
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3789, RMSE=2.9169, MAE=2.2129
#     Fold 2/5: R²=0.2833, RMSE=3.0785, MAE=2.2675
#     Fold 3/5: R²=0.3370, RMSE=3.0983, MAE=2.1718
#     Fold 4/5: R²=0.3698, RMSE=2.9608, MAE=2.1834
#     Fold 5/5: R²=0.1942, RMSE=3.3978, MAE=2.5844
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3126 ± 0.0681
#     RMSE: 3.0905 ± 0.1683
#     MAE:  2.2840 ± 0.1538
#
#   Training SVR...
#     Fold 1/5: R²=0.5040, RMSE=2.6068, MAE=1.9650
#     Fold 2/5: R²=0.4791, RMSE=2.6244, MAE=1.9074
#     Fold 3/5: R²=0.4653, RMSE=2.7825, MAE=2.0301
#     Fold 4/5: R²=0.6213, RMSE=2.2952, MAE=1.7273
#     Fold 5/5: R²=0.3780, RMSE=2.9851, MAE=2.3262
#
#   SVR 5-Fold CV Results:
#     R²:   0.4895 ± 0.0784
#     RMSE: 2.6588 ± 0.2271
#     MAE:  1.9912 ± 0.1955
#
#   Training KNN...
#     Fold 1/5: R²=0.5056, RMSE=2.6025, MAE=1.9164
#     Fold 2/5: R²=0.4668, RMSE=2.6554, MAE=1.9698
#     Fold 3/5: R²=0.4480, RMSE=2.8269, MAE=2.0397
#     Fold 4/5: R²=0.5851, RMSE=2.4025, MAE=1.7309
#     Fold 5/5: R²=0.3335, RMSE=3.0901, MAE=2.2891
#
#   KNN 5-Fold CV Results:
#     R²:   0.4678 ± 0.0820
#     RMSE: 2.7155 ± 0.2311
#     MAE:  1.9892 ± 0.1816
#
#   Training Lasso...
#     Fold 1/5: R²=0.2590, RMSE=3.1861, MAE=2.4010
#     Fold 2/5: R²=0.3308, RMSE=2.9748, MAE=2.1605
#     Fold 3/5: R²=0.2725, RMSE=3.2455, MAE=2.3346
#     Fold 4/5: R²=0.3175, RMSE=3.0812, MAE=2.2861
#     Fold 5/5: R²=0.2412, RMSE=3.2971, MAE=2.5905
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2842 ± 0.0343
#     RMSE: 3.1570 ± 0.1160
#     MAE:  2.3545 ± 0.1418
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4596, RMSE=2.7208, MAE=2.0400
#     Fold 2/5: R²=0.4178, RMSE=2.7746, MAE=2.0342
#     Fold 3/5: R²=0.4042, RMSE=2.9371, MAE=2.0953
#     Fold 4/5: R²=0.4766, RMSE=2.6984, MAE=1.9811
#     Fold 5/5: R²=0.3436, RMSE=3.0666, MAE=2.3858
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4204 ± 0.0466
#     RMSE: 2.8395 ± 0.1409
#     MAE:  2.1073 ± 0.1439
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2822, RMSE=3.1360, MAE=2.3275
#     Fold 2/5: R²=0.2972, RMSE=3.0485, MAE=2.1609
#     Fold 3/5: R²=-0.0418, RMSE=3.8837, MAE=2.8079
#     Fold 4/5: R²=0.3873, RMSE=2.9193, MAE=2.0591
#     Fold 5/5: R²=0.2528, RMSE=3.2717, MAE=2.5250
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2356 ± 0.1458
#     RMSE: 3.2518 ± 0.3362
#     MAE:  2.3761 ± 0.2675
#
# ========================================================================================================================
#                           K-FOLD CROSS-VALIDATION RESULTS SUMMARY
# ========================================================================================================================
#
# ====================================================================================================
# NOISE TYPE: Mean Noise
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.5254 ± 0.0359
#   RMSE: 2.3114 ± 0.1294
#   MAE:  1.7441 ± 0.0849
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.5179 ± 0.0662
#   RMSE: 2.3263 ± 0.1960
#   MAE:  1.7369 ± 0.1353
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.4719 ± 0.1063
#   RMSE: 2.4335 ± 0.3157
#   MAE:  1.7828 ± 0.1917
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.4587 ± 0.0433
#   RMSE: 2.4697 ± 0.1658
#   MAE:  1.8503 ± 0.1148
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.4535 ± 0.0650
#   RMSE: 2.4795 ± 0.2040
#   MAE:  1.8677 ± 0.1188
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.4524 ± 0.0713
#   RMSE: 2.4845 ± 0.2486
#   MAE:  1.8512 ± 0.1351
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.4384 ± 0.0310
#   RMSE: 2.5160 ± 0.1386
#   MAE:  1.8985 ± 0.1036
# ...
# SVR                  (Base      ) + Fusion
#   R²:   0.4474 ± 0.0223
#   RMSE: 2.4312 ± 0.1119
#   MAE:  1.8311 ± 0.1229
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.4340 ± 0.0312
#   RMSE: 2.4595 ± 0.1120
#   MAE:  1.8164 ± 0.0825
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.3847 ± 0.0363
#   RMSE: 2.5644 ± 0.1203
#   MAE:  1.9738 ± 0.0914
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.3774 ± 0.0265
#   RMSE: 2.5822 ± 0.1514
#   MAE:  1.9217 ± 0.1115
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.3690 ± 0.0292
#   RMSE: 2.5993 ± 0.1547
#   MAE:  1.9820 ± 0.0859
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.3557 ± 0.0414
#   RMSE: 2.6229 ± 0.1062
#   MAE:  1.9779 ± 0.1370
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.3391 ± 0.0745
#   RMSE: 2.6548 ± 0.1839
#   MAE:  1.9604 ± 0.1295
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Remote Sensing
#   R²:   0.3230 ± 0.0427
#   RMSE: 2.6906 ± 0.1498
#   MAE:  2.0823 ± 0.0810
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Fusion
#   R²:   0.3160 ± 0.0447
#   RMSE: 2.7024 ± 0.1052
#   MAE:  2.0932 ± 0.0910
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# NOISE TYPE: Mid Freq
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.5138 ± 0.0353
#   RMSE: 2.2665 ± 0.1223
#   MAE:  1.7130 ± 0.0748
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.5070 ± 0.0491
#   RMSE: 2.2813 ± 0.1502
#   MAE:  1.7022 ± 0.0787
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.4851 ± 0.1122
#   RMSE: 2.3246 ± 0.3027
#   MAE:  1.6936 ± 0.1502
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.4436 ± 0.0486
#   RMSE: 2.4253 ± 0.1672
#   MAE:  1.8195 ± 0.0884
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.4430 ± 0.0467
#   RMSE: 2.4272 ± 0.1703
#   MAE:  1.8001 ± 0.0860
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.4309 ± 0.0338
#   RMSE: 2.4537 ± 0.1404
#   MAE:  1.8464 ± 0.0850
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.4183 ± 0.0534
#   RMSE: 2.4794 ± 0.1708
#   MAE:  1.8803 ± 0.1013
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.4077 ± 0.0514
#   RMSE: 2.5026 ± 0.1743
#   MAE:  1.8568 ± 0.1035
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Remote Sensing
#   R²:   0.3988 ± 0.0425
#   RMSE: 2.5216 ± 0.1550
#   MAE:  1.9036 ± 0.1030
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Fusion
#   R²:   0.3864 ± 0.0423
#   RMSE: 2.5475 ± 0.1524
#   MAE:  1.9309 ± 0.0958
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# NOISE TYPE: High Freq
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.5292 ± 0.0684
#   RMSE: 2.5538 ± 0.1960
#   MAE:  1.8689 ± 0.1576
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.4895 ± 0.0784
#   RMSE: 2.6588 ± 0.2271
#   MAE:  1.9912 ± 0.1955
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.4678 ± 0.0820
#   RMSE: 2.7155 ± 0.2311
#   MAE:  1.9892 ± 0.1816
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.4330 ± 0.0722
#   RMSE: 2.8045 ± 0.1937
#   MAE:  2.0431 ± 0.1602
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.4204 ± 0.0466
#   RMSE: 2.8395 ± 0.1409
#   MAE:  2.1073 ± 0.1439
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.4064 ± 0.0459
#   RMSE: 2.8738 ± 0.1369
#   MAE:  2.0851 ± 0.1311
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.3783 ± 0.0611
#   RMSE: 2.9396 ± 0.1719
#   MAE:  2.1839 ± 0.1582
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.3679 ± 0.0709
#   RMSE: 2.9634 ± 0.1904
#   MAE:  2.1808 ± 0.1735
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Fusion
#   R²:   0.3601 ± 0.0417
#   RMSE: 2.9838 ± 0.1223
#   MAE:  2.2569 ± 0.1168
# ----------------------------------------------------------------------------------------------------
# XGBoost              (Base      ) + Fusion
#   R²:   0.3460 ± 0.0498
#   RMSE: 3.0160 ± 0.1345
#   MAE:  2.2493 ± 0.1210
# ----------------------------------------------------------------------------------------------------
#
# ========================================================================================================================
#                           OVERALL TOP 10 BEST MODELS
# ========================================================================================================================
#
# SVR                  (Base      )
#   Noise: High Freq, Features: Remote Sensing
#   R²:   0.5292 ± 0.0684
#   RMSE: 2.5538 ± 0.1960
#   MAE:  1.8689 ± 0.1576
#
# SVR                  (Base      )
#   Noise: Mean Noise, Features: Remote Sensing
#   R²:   0.5254 ± 0.0359
#   RMSE: 2.3114 ± 0.1294
#   MAE:  1.7441 ± 0.0849
#
# SVR                  (Base      )
#   Noise: Mean Noise, Features: Fusion
#   R²:   0.5179 ± 0.0662
#   RMSE: 2.3263 ± 0.1960
#   MAE:  1.7369 ± 0.1353
#
# SVR                  (Base      )
#   Noise: Mid Freq, Features: Remote Sensing
#   R²:   0.5138 ± 0.0353
#   RMSE: 2.2665 ± 0.1223
#   MAE:  1.7130 ± 0.0748
#
# SVR                  (Base      )
#   Noise: Mid Freq, Features: Fusion
#   R²:   0.5070 ± 0.0491
#   RMSE: 2.2813 ± 0.1502
#   MAE:  1.7022 ± 0.0787
#
# SVR                  (Base      )
#   Noise: High Freq, Features: Fusion
#   R²:   0.4895 ± 0.0784
#   RMSE: 2.6588 ± 0.2271
#   MAE:  1.9912 ± 0.1955
#
# KNN                  (Base      )
#   Noise: Mid Freq, Features: Fusion
#   R²:   0.4851 ± 0.1122
#   RMSE: 2.3246 ± 0.3027
#   MAE:  1.6936 ± 0.1502
#
# SVR                  (Base      )
#   Noise: Low Freq, Features: Remote Sensing
#   R²:   0.4800 ± 0.0294
#   RMSE: 2.3609 ± 0.1676
#   MAE:  1.7587 ± 0.0778
#
# KNN                  (Base      )
#   Noise: Mean Noise, Features: Fusion
#   R²:   0.4719 ± 0.1063
#   RMSE: 2.4335 ± 0.3157
#   MAE:  1.7828 ± 0.1917
#
# KNN                  (Base      )
#   Noise: High Freq, Features: Fusion
#   R²:   0.4678 ± 0.0820
#   RMSE: 2.7155 ± 0.2311
#   MAE:  1.9892 ± 0.1816
#
# ========================================================================================================================
#
# ========================================================================================================================
# Results saved to 'comprehensive_kfold_results.csv'
#
# ========================================================================================================================
# SAVING ALL BEST MODELS...
# ========================================================================================================================
#   ✓ Saved: Mean Noise - street - XGBoost
#   ✓ Saved: Mean Noise - street - LightGBM
#   ✓ Saved: Mean Noise - street - Random Forest
#   ✓ Saved: Mean Noise - street - Gradient Boosting
#   ✓ Saved: Mean Noise - street - SVR
#   ✓ Saved: Mean Noise - street - KNN
#   ✓ Saved: Mean Noise - street - Lasso
#   ✓ Saved: Mean Noise - street - Voting
#   ✓ Saved: Mean Noise - street - Stacking
#   ✓ Saved: Mean Noise - remote - XGBoost
#   ✓ Saved: Mean Noise - remote - LightGBM
#   ✓ Saved: Mean Noise - remote - Random Forest
#   ✓ Saved: Mean Noise - remote - Gradient Boosting
#   ✓ Saved: Mean Noise - remote - SVR
#   ✓ Saved: Mean Noise - remote - KNN
#   ✓ Saved: Mean Noise - remote - Lasso
#   ✓ Saved: Mean Noise - remote - Voting
#   ✓ Saved: Mean Noise - remote - Stacking
#   ✓ Saved: Mean Noise - fusion - XGBoost
#   ✓ Saved: Mean Noise - fusion - LightGBM
#   ✓ Saved: Mean Noise - fusion - Random Forest
#   ✓ Saved: Mean Noise - fusion - Gradient Boosting
#   ✓ Saved: Mean Noise - fusion - SVR
#   ✓ Saved: Mean Noise - fusion - KNN
#   ✓ Saved: Mean Noise - fusion - Lasso
#   ✓ Saved: Mean Noise - fusion - Voting
#   ✓ Saved: Mean Noise - fusion - Stacking
#   ✓ Saved: Low Freq - street - XGBoost
#   ✓ Saved: Low Freq - street - LightGBM
#   ✓ Saved: Low Freq - street - Random Forest
#   ✓ Saved: Low Freq - street - Gradient Boosting
#   ✓ Saved: Low Freq - street - SVR
#   ✓ Saved: Low Freq - street - KNN
#   ✓ Saved: Low Freq - street - Lasso
#   ✓ Saved: Low Freq - street - Voting
#   ✓ Saved: Low Freq - street - Stacking
#   ✓ Saved: Low Freq - remote - XGBoost
#   ✓ Saved: Low Freq - remote - LightGBM
#   ✓ Saved: Low Freq - remote - Random Forest
#   ✓ Saved: Low Freq - remote - Gradient Boosting
#   ✓ Saved: Low Freq - remote - SVR
#   ✓ Saved: Low Freq - remote - KNN
#   ✓ Saved: Low Freq - remote - Lasso
#   ✓ Saved: Low Freq - remote - Voting
#   ✓ Saved: Low Freq - remote - Stacking
#   ✓ Saved: Low Freq - fusion - XGBoost
#   ✓ Saved: Low Freq - fusion - LightGBM
#   ✓ Saved: Low Freq - fusion - Random Forest
#   ✓ Saved: Low Freq - fusion - Gradient Boosting
#   ✓ Saved: Low Freq - fusion - SVR
#   ✓ Saved: Low Freq - fusion - KNN
#   ✓ Saved: Low Freq - fusion - Lasso
#   ✓ Saved: Low Freq - fusion - Voting
#   ✓ Saved: Low Freq - fusion - Stacking
#   ✓ Saved: Mid Freq - street - XGBoost
#   ✓ Saved: Mid Freq - street - LightGBM
#   ✓ Saved: Mid Freq - street - Random Forest
#   ✓ Saved: Mid Freq - street - Gradient Boosting
#   ✓ Saved: Mid Freq - street - SVR
#   ✓ Saved: Mid Freq - street - KNN
#   ✓ Saved: Mid Freq - street - Lasso
#   ✓ Saved: Mid Freq - street - Voting
#   ✓ Saved: Mid Freq - street - Stacking
#   ✓ Saved: Mid Freq - remote - XGBoost
#   ✓ Saved: Mid Freq - remote - LightGBM
#   ✓ Saved: Mid Freq - remote - Random Forest
#   ✓ Saved: Mid Freq - remote - Gradient Boosting
#   ✓ Saved: Mid Freq - remote - SVR
#   ✓ Saved: Mid Freq - remote - KNN
#   ✓ Saved: Mid Freq - remote - Lasso
#   ✓ Saved: Mid Freq - remote - Voting
#   ✓ Saved: Mid Freq - remote - Stacking
#   ✓ Saved: Mid Freq - fusion - XGBoost
#   ✓ Saved: Mid Freq - fusion - LightGBM
#   ✓ Saved: Mid Freq - fusion - Random Forest
#   ✓ Saved: Mid Freq - fusion - Gradient Boosting
#   ✓ Saved: Mid Freq - fusion - SVR
#   ✓ Saved: Mid Freq - fusion - KNN
#   ✓ Saved: Mid Freq - fusion - Lasso
#   ✓ Saved: Mid Freq - fusion - Voting
#   ✓ Saved: Mid Freq - fusion - Stacking
#   ✓ Saved: High Freq - street - XGBoost
#   ✓ Saved: High Freq - street - LightGBM
#   ✓ Saved: High Freq - street - Random Forest
#   ✓ Saved: High Freq - street - Gradient Boosting
#   ✓ Saved: High Freq - street - SVR
#   ✓ Saved: High Freq - street - KNN
#   ✓ Saved: High Freq - street - Lasso
#   ✓ Saved: High Freq - street - Voting
#   ✓ Saved: High Freq - street - Stacking
#   ✓ Saved: High Freq - remote - XGBoost
#   ✓ Saved: High Freq - remote - LightGBM
#   ✓ Saved: High Freq - remote - Random Forest
#   ✓ Saved: High Freq - remote - Gradient Boosting
#   ✓ Saved: High Freq - remote - SVR
#   ✓ Saved: High Freq - remote - KNN
#   ✓ Saved: High Freq - remote - Lasso
#   ✓ Saved: High Freq - remote - Voting
#   ✓ Saved: High Freq - remote - Stacking
#   ✓ Saved: High Freq - fusion - XGBoost
#   ✓ Saved: High Freq - fusion - LightGBM
#   ✓ Saved: High Freq - fusion - Random Forest
#   ✓ Saved: High Freq - fusion - Gradient Boosting
#   ✓ Saved: High Freq - fusion - SVR
#   ✓ Saved: High Freq - fusion - KNN
#   ✓ Saved: High Freq - fusion - Lasso
#   ✓ Saved: High Freq - fusion - Voting
#   ✓ Saved: High Freq - fusion - Stacking
#
#   ✓ Saved complete predictor object
#
# ========================================================================================================================
# Successfully saved 108 models to 'saved_models' directory
# ========================================================================================================================
# ========================================================================================================================
#
# ========================================================================================================================
#                            EXPERIMENT COMPLETED SUCCESSFULLY
# ========================================================================================================================
#
# Summary:
# • Total models evaluated: 9 (7 base models + 2 ensemble models)
# • Base models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso
# • Ensemble models: Voting (7 models), Stacking (7 models + Lasso)
# • Feature types: Street View, Remote Sensing, Fusion
# • Noise types: Mean Noise, Low Freq, Mid Freq, High Freq
# • Cross-validation: 5-fold
# • Metrics: R², RMSE, MAE, MSE (all with mean ± std)
# • All models saved to 'saved_models/' directory
#
# Results saved to 'comprehensive_kfold_results.csv'
#
# ========================================================================================================================
# DEMONSTRATION: How to Load and Use Saved Models
# ========================================================================================================================
#
# 1. Loading a single model:
# Loaded model: Mean Noise - fusion - XGBoost
#   R²: 0.4046
#   RMSE: 2.5894
#   MAE: 1.9625
#
# 2. Making predictions with a saved model:
#   predictions = predictor.predict_with_saved_model(
#       X_new=new_data,
#       noise_type='Mean Noise',
#       feature_type='fusion',
#       model_name='XGBoost'
#   )
#
# 3. Loading complete predictor:
#   loaded_predictor = ComprehensiveKFoldNoisePredictor.load_complete_predictor('saved_models')

# %%
# 创建预测器
predictor = ComprehensiveKFoldNoisePredictor()

# 文件路径
street_view_path = './revise_data/features_dinov3-vitb16-pretrain-lvd1689m.npy'
remote_sensing_path = './revise_data/features_dinov3-vitl16-pretrain-sat493m.npy'
noise_labels_path = './revise_data/noise_labels_100.npy'

try:
    # 加载数据
    print("Loading data...")
    street_features, remote_features, fusion_features, labels = predictor.load_data(
        street_view_path, remote_sensing_path, noise_labels_path
    )
    
    # 准备特征字典
    features_dict = {
        'street': street_features,
        'remote': remote_features,
        'fusion': fusion_features
    }
    
    # 执行K折交叉验证并保存模型
    print("\nStarting comprehensive K-fold cross-validation...")
    results_df = predictor.k_fold_cross_validation_all_models(
        features_dict=features_dict,
        labels=labels,
        k=5,  # 5折交叉验证
        optimize_hyperparams=False,  # 设为True可启用超参数优化（会更慢）
        save_best_models=True  # 自动保存所有最佳模型
    )
    
    print(f"\n{'='*120}")
    print("                           EXPERIMENT COMPLETED SUCCESSFULLY")
    print(f"{'='*120}")
    print("\nSummary:")
    print("• Total models evaluated: 9 (7 base models + 2 ensemble models)")
    print("• Base models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso")
    print("• Ensemble models: Voting (7 models), Stacking (7 models + Lasso)")
    print("• Feature types: Street View, Remote Sensing, Fusion")
    print("• Noise types: Mean Noise, Low Freq, Mid Freq, High Freq")
    print("• Cross-validation: 5-fold")
    print("• Metrics: R², RMSE, MAE, MSE (all with mean ± std)")
    print("• All models saved to 'saved_models/' directory")
    print("\nResults saved to 'comprehensive_kfold_results.csv'")
    
    # ============ 演示如何使用保存的模型 ============
    print(f"\n{'='*120}")
    print("DEMONSTRATION: How to Load and Use Saved Models")
    print(f"{'='*120}")
    
    # 示例1: 加载单个模型
    print("\n1. Loading a single model:")
    try:
        model, preprocessors, info = predictor.load_saved_model(
            noise_type='Mean Noise',
            feature_type='fusion',
            model_name='XGBoost',
            save_dir='saved_models'
        )
    except:
        print("  (Model not found - will be available after training)")
    
    # 示例2: 使用保存的模型进行预测
    print("\n2. Making predictions with a saved model:")
    print("  predictions = predictor.predict_with_saved_model(")
    print("      X_new=new_data,")
    print("      noise_type='Mean Noise',")
    print("      feature_type='fusion',")
    print("      model_name='XGBoost'")
    print("  )")
    
    # 示例3: 加载完整的predictor
    print("\n3. Loading complete predictor:")
    print("  loaded_predictor = ComprehensiveKFoldNoisePredictor.load_complete_predictor('saved_models')")
    
except FileNotFoundError as e:
    print(f"File not found: {e}")
    print("Please ensure the following files exist:")
    print(f"- {street_view_path}")
    print(f"- {remote_sensing_path}")
    print(f"- {noise_labels_path}")
except Exception as e:
    print(f"Error occurred: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Loading data...
# Street view features shape: (923, 768)
# Remote sensing features shape: (923, 1024)
# Noise labels shape: (923, 4)
#
# Starting comprehensive K-fold cross-validation...
#
# ========================================================================================================================
#           K-FOLD CROSS-VALIDATION FOR ALL 8 MODELS + ENSEMBLES (K=5)
# ========================================================================================================================
# Models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso
# Ensembles: Voting (7 models), Stacking (7 models + Lasso)
#
# ====================================================================================================
# NOISE TYPE: Mean Noise
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4111, RMSE=2.2515, MAE=1.7678
#     Fold 2/5: R²=0.3657, RMSE=2.1504, MAE=1.5759
#     Fold 3/5: R²=0.3743, RMSE=2.4517, MAE=1.7801
#     Fold 4/5: R²=0.3629, RMSE=2.4104, MAE=1.8008
#     Fold 5/5: R²=0.3648, RMSE=2.5581, MAE=1.8688
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3757 ± 0.0181
#     RMSE: 2.3644 ± 0.1455
#     MAE:  1.7587 ± 0.0978
#
#   Training LightGBM...
#     Fold 1/5: R²=0.4092, RMSE=2.2551, MAE=1.7829
#     Fold 2/5: R²=0.3413, RMSE=2.1912, MAE=1.6154
#     Fold 3/5: R²=0.3476, RMSE=2.5035, MAE=1.8031
#     Fold 4/5: R²=0.3794, RMSE=2.3789, MAE=1.8284
#     Fold 5/5: R²=0.3785, RMSE=2.5303, MAE=1.9004
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3712 ± 0.0246
#     RMSE: 2.3718 ± 0.1332
#     MAE:  1.7861 ± 0.0941
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2541, RMSE=2.5339, MAE=1.9797
#     Fold 2/5: R²=0.2321, RMSE=2.3660, MAE=1.8011
#     Fold 3/5: R²=0.2536, RMSE=2.6776, MAE=2.0045
#     Fold 4/5: R²=0.2129, RMSE=2.6790, MAE=2.0595
#     Fold 5/5: R²=0.2420, RMSE=2.7944, MAE=2.1218
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2390 ± 0.0154
#     RMSE: 2.6102 ± 0.1474
#     MAE:  1.9933 ± 0.1078
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3965, RMSE=2.2792, MAE=1.7453
#     Fold 2/5: R²=0.4141, RMSE=2.0666, MAE=1.5285
#     Fold 3/5: R²=0.3429, RMSE=2.5125, MAE=1.7867
#     Fold 4/5: R²=0.3388, RMSE=2.4555, MAE=1.8456
#     Fold 5/5: R²=0.3617, RMSE=2.5642, MAE=1.9034
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3708 ± 0.0298
#     RMSE: 2.3756 ± 0.1819
#     MAE:  1.7619 ± 0.1284
#
#   Training SVR...
#     Fold 1/5: R²=0.5883, RMSE=1.8825, MAE=1.4374
#     Fold 2/5: R²=0.4712, RMSE=1.9634, MAE=1.4165
#     Fold 3/5: R²=0.4795, RMSE=2.2360, MAE=1.5768
#     Fold 4/5: R²=0.5189, RMSE=2.0946, MAE=1.6073
#     Fold 5/5: R²=0.4612, RMSE=2.3560, MAE=1.7140
#
#   SVR 5-Fold CV Results:
#     R²:   0.5038 ± 0.0466
#     RMSE: 2.1065 ± 0.1731
#     MAE:  1.5504 ± 0.1108
#
#   Training KNN...
#     Fold 1/5: R²=0.5924, RMSE=1.8732, MAE=1.4273
#     Fold 2/5: R²=0.5357, RMSE=1.8397, MAE=1.3161
#     Fold 3/5: R²=0.5281, RMSE=2.1291, MAE=1.4833
#     Fold 4/5: R²=0.4902, RMSE=2.1560, MAE=1.6203
#     Fold 5/5: R²=0.4228, RMSE=2.4386, MAE=1.6980
#
#   KNN 5-Fold CV Results:
#     R²:   0.5138 ± 0.0560
#     RMSE: 2.0873 ± 0.2177
#     MAE:  1.5090 ± 0.1361
#
#   Training Lasso...
#     Fold 1/5: R²=0.3615, RMSE=2.3443, MAE=1.8726
#     Fold 2/5: R²=0.3134, RMSE=2.2373, MAE=1.6775
#     Fold 3/5: R²=0.3110, RMSE=2.5726, MAE=1.8837
#     Fold 4/5: R²=0.2441, RMSE=2.6254, MAE=2.0258
#     Fold 5/5: R²=0.2925, RMSE=2.6998, MAE=2.0528
#
#   Lasso 5-Fold CV Results:
#     R²:   0.3045 ± 0.0379
#     RMSE: 2.4959 ± 0.1756
#     MAE:  1.9025 ± 0.1339
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4863, RMSE=2.1028, MAE=1.6351
#     Fold 2/5: R²=0.4480, RMSE=2.0059, MAE=1.4641
#     Fold 3/5: R²=0.4387, RMSE=2.3222, MAE=1.6799
#     Fold 4/5: R²=0.4264, RMSE=2.2870, MAE=1.7484
#     Fold 5/5: R²=0.4134, RMSE=2.4582, MAE=1.7932
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4426 ± 0.0248
#     RMSE: 2.2352 ± 0.1613
#     MAE:  1.6641 ± 0.1139
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3735, RMSE=2.3222, MAE=1.8368
#     Fold 2/5: R²=0.3451, RMSE=2.1850, MAE=1.6688
#     Fold 3/5: R²=0.2945, RMSE=2.6034, MAE=1.9203
#     Fold 4/5: R²=0.3559, RMSE=2.4234, MAE=1.8655
#     Fold 5/5: R²=0.2591, RMSE=2.7628, MAE=2.0680
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.3256 ± 0.0424
#     RMSE: 2.4594 ± 0.2040
#     MAE:  1.8719 ± 0.1291
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4377, RMSE=2.2000, MAE=1.6639
#     Fold 2/5: R²=0.4925, RMSE=1.9234, MAE=1.4513
#     Fold 3/5: R²=0.4360, RMSE=2.3277, MAE=1.6473
#     Fold 4/5: R²=0.4614, RMSE=2.2162, MAE=1.6897
#     Fold 5/5: R²=0.3666, RMSE=2.5545, MAE=1.8652
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.4388 ± 0.0415
#     RMSE: 2.2443 ± 0.2044
#     MAE:  1.6635 ± 0.1316
#
#   Training LightGBM...
#     Fold 1/5: R²=0.4351, RMSE=2.2052, MAE=1.6506
#     Fold 2/5: R²=0.4833, RMSE=1.9408, MAE=1.4721
#     Fold 3/5: R²=0.4272, RMSE=2.3458, MAE=1.6309
#     Fold 4/5: R²=0.5117, RMSE=2.1102, MAE=1.6667
#     Fold 5/5: R²=0.3982, RMSE=2.4899, MAE=1.8409
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.4511 ± 0.0408
#     RMSE: 2.2184 ± 0.1891
#     MAE:  1.6522 ± 0.1172
#
#   Training Random Forest...
#     Fold 1/5: R²=0.3074, RMSE=2.4417, MAE=1.8911
#     Fold 2/5: R²=0.3400, RMSE=2.1934, MAE=1.6751
#     Fold 3/5: R²=0.2790, RMSE=2.6317, MAE=1.9099
#     Fold 4/5: R²=0.3199, RMSE=2.4903, MAE=1.8746
#     Fold 5/5: R²=0.2594, RMSE=2.7622, MAE=2.0499
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.3012 ± 0.0288
#     RMSE: 2.5039 ± 0.1916
#     MAE:  1.8801 ± 0.1199
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3852, RMSE=2.3004, MAE=1.7434
#     Fold 2/5: R²=0.5055, RMSE=1.8986, MAE=1.4330
#     Fold 3/5: R²=0.4067, RMSE=2.3873, MAE=1.6770
#     Fold 4/5: R²=0.4291, RMSE=2.2817, MAE=1.7450
#     Fold 5/5: R²=0.3537, RMSE=2.5803, MAE=1.9037
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.4161 ± 0.0512
#     RMSE: 2.2897 ± 0.2223
#     MAE:  1.7004 ± 0.1531
#
#   Training SVR...
#     Fold 1/5: R²=0.6361, RMSE=1.7699, MAE=1.3156
#     Fold 2/5: R²=0.6772, RMSE=1.5340, MAE=1.0692
#     Fold 3/5: R²=0.5870, RMSE=1.9918, MAE=1.2885
#     Fold 4/5: R²=0.6992, RMSE=1.6561, MAE=1.2449
#     Fold 5/5: R²=0.6435, RMSE=1.9163, MAE=1.3927
#
#   SVR 5-Fold CV Results:
#     R²:   0.6486 ± 0.0384
#     RMSE: 1.7736 ± 0.1669
#     MAE:  1.2622 ± 0.1078
#
#   Training KNN...
#     Fold 1/5: R²=0.5709, RMSE=1.9219, MAE=1.3857
#     Fold 2/5: R²=0.6109, RMSE=1.6842, MAE=1.2004
#     Fold 3/5: R²=0.4865, RMSE=2.2210, MAE=1.5259
#     Fold 4/5: R²=0.5756, RMSE=1.9673, MAE=1.4662
#     Fold 5/5: R²=0.5055, RMSE=2.2571, MAE=1.5919
#
#   KNN 5-Fold CV Results:
#     R²:   0.5499 ± 0.0465
#     RMSE: 2.0103 ± 0.2104
#     MAE:  1.4340 ± 0.1351
#
#   Training Lasso...
#     Fold 1/5: R²=0.4312, RMSE=2.2128, MAE=1.6868
#     Fold 2/5: R²=0.3543, RMSE=2.1695, MAE=1.5734
#     Fold 3/5: R²=0.3948, RMSE=2.4112, MAE=1.7441
#     Fold 4/5: R²=0.4783, RMSE=2.1812, MAE=1.6963
#     Fold 5/5: R²=0.3892, RMSE=2.5086, MAE=1.8794
#
#   Lasso 5-Fold CV Results:
#     R²:   0.4095 ± 0.0421
#     RMSE: 2.2966 ± 0.1375
#     MAE:  1.7160 ± 0.0991
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.5168, RMSE=2.0395, MAE=1.5344
#     Fold 2/5: R²=0.5652, RMSE=1.7804, MAE=1.3201
#     Fold 3/5: R²=0.4883, RMSE=2.2171, MAE=1.5443
#     Fold 4/5: R²=0.5641, RMSE=1.9938, MAE=1.5326
#     Fold 5/5: R²=0.4668, RMSE=2.3436, MAE=1.7128
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.5202 ± 0.0396
#     RMSE: 2.0749 ± 0.1934
#     MAE:  1.5288 ± 0.1247
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.4916, RMSE=2.0919, MAE=1.6054
#     Fold 2/5: R²=0.5339, RMSE=1.8432, MAE=1.3726
#     Fold 3/5: R²=0.3865, RMSE=2.4276, MAE=1.7361
#     Fold 4/5: R²=0.5421, RMSE=2.0434, MAE=1.5446
#     Fold 5/5: R²=0.3708, RMSE=2.5460, MAE=1.9132
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.4650 ± 0.0727
#     RMSE: 2.1904 ± 0.2587
#     MAE:  1.6344 ± 0.1820
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.5054, RMSE=2.0634, MAE=1.5323
#     Fold 2/5: R²=0.4583, RMSE=1.9873, MAE=1.4247
#     Fold 3/5: R²=0.4400, RMSE=2.3194, MAE=1.6888
#     Fold 4/5: R²=0.4615, RMSE=2.2161, MAE=1.6950
#     Fold 5/5: R²=0.3110, RMSE=2.6643, MAE=1.9296
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.4352 ± 0.0657
#     RMSE: 2.2501 ± 0.2373
#     MAE:  1.6541 ± 0.1710
#
#   Training LightGBM...
#     Fold 1/5: R²=0.5353, RMSE=2.0000, MAE=1.5069
#     Fold 2/5: R²=0.4690, RMSE=1.9674, MAE=1.4083
#     Fold 3/5: R²=0.4713, RMSE=2.2536, MAE=1.6342
#     Fold 4/5: R²=0.4473, RMSE=2.2451, MAE=1.7430
#     Fold 5/5: R²=0.3868, RMSE=2.5133, MAE=1.8400
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.4620 ± 0.0477
#     RMSE: 2.1959 ± 0.1985
#     MAE:  1.6265 ± 0.1557
#
#   Training Random Forest...
#     Fold 1/5: R²=0.3009, RMSE=2.4532, MAE=1.8822
#     Fold 2/5: R²=0.3137, RMSE=2.2367, MAE=1.6905
#     Fold 3/5: R²=0.2613, RMSE=2.6639, MAE=1.9474
#     Fold 4/5: R²=0.2722, RMSE=2.5761, MAE=1.9509
#     Fold 5/5: R²=0.2258, RMSE=2.8242, MAE=2.0899
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2748 ± 0.0309
#     RMSE: 2.5508 ± 0.1982
#     MAE:  1.9122 ± 0.1299
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.4986, RMSE=2.0774, MAE=1.5301
#     Fold 2/5: R²=0.4345, RMSE=2.0304, MAE=1.4564
#     Fold 3/5: R²=0.4384, RMSE=2.3228, MAE=1.6693
#     Fold 4/5: R²=0.4444, RMSE=2.2509, MAE=1.6785
#     Fold 5/5: R²=0.2790, RMSE=2.7253, MAE=1.9835
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.4190 ± 0.0737
#     RMSE: 2.2813 ± 0.2467
#     MAE:  1.6636 ± 0.1808
#
#   Training SVR...
#     Fold 1/5: R²=0.6593, RMSE=1.7125, MAE=1.2889
#     Fold 2/5: R²=0.5838, RMSE=1.7419, MAE=1.2327
#     Fold 3/5: R²=0.5424, RMSE=2.0967, MAE=1.4611
#     Fold 4/5: R²=0.6385, RMSE=1.8156, MAE=1.3822
#     Fold 5/5: R²=0.5581, RMSE=2.1337, MAE=1.5567
#
#   SVR 5-Fold CV Results:
#     R²:   0.5964 ± 0.0453
#     RMSE: 1.9001 ± 0.1792
#     MAE:  1.3843 ± 0.1164
#
#   Training KNN...
#     Fold 1/5: R²=0.6291, RMSE=1.7868, MAE=1.3174
#     Fold 2/5: R²=0.5651, RMSE=1.7805, MAE=1.2006
#     Fold 3/5: R²=0.4779, RMSE=2.2395, MAE=1.4750
#     Fold 4/5: R²=0.5861, RMSE=1.9427, MAE=1.3652
#     Fold 5/5: R²=0.5182, RMSE=2.2278, MAE=1.6107
#
#   KNN 5-Fold CV Results:
#     R²:   0.5553 ± 0.0526
#     RMSE: 1.9955 ± 0.2030
#     MAE:  1.3938 ± 0.1397
#
#   Training Lasso...
#     Fold 1/5: R²=0.4394, RMSE=2.1967, MAE=1.6597
#     Fold 2/5: R²=0.3949, RMSE=2.1002, MAE=1.5444
#     Fold 3/5: R²=0.3995, RMSE=2.4017, MAE=1.7399
#     Fold 4/5: R²=0.4059, RMSE=2.3276, MAE=1.8271
#     Fold 5/5: R²=0.3305, RMSE=2.6263, MAE=1.9649
#
#   Lasso 5-Fold CV Results:
#     R²:   0.3940 ± 0.0354
#     RMSE: 2.3305 ± 0.1808
#     MAE:  1.7472 ± 0.1433
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.5664, RMSE=1.9320, MAE=1.4463
#     Fold 2/5: R²=0.5258, RMSE=1.8593, MAE=1.3142
#     Fold 3/5: R²=0.4883, RMSE=2.2171, MAE=1.5786
#     Fold 4/5: R²=0.5221, RMSE=2.0876, MAE=1.5843
#     Fold 5/5: R²=0.4214, RMSE=2.4415, MAE=1.7650
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.5048 ± 0.0485
#     RMSE: 2.1075 ± 0.2080
#     MAE:  1.5377 ± 0.1509
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.5004, RMSE=2.0737, MAE=1.6084
#     Fold 2/5: R²=0.4477, RMSE=2.0066, MAE=1.4903
#     Fold 3/5: R²=0.3092, RMSE=2.5761, MAE=1.8781
#     Fold 4/5: R²=0.4937, RMSE=2.1486, MAE=1.6220
#     Fold 5/5: R²=0.3431, RMSE=2.6014, MAE=1.9196
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.4188 ± 0.0786
#     RMSE: 2.2813 ± 0.2552
#     MAE:  1.7037 ± 0.1663
#
# ====================================================================================================
# NOISE TYPE: Low Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2942, RMSE=2.3976, MAE=1.9178
#     Fold 2/5: R²=0.2681, RMSE=2.5215, MAE=1.9970
#     Fold 3/5: R²=0.3348, RMSE=2.4794, MAE=1.8462
#     Fold 4/5: R²=0.2751, RMSE=2.6361, MAE=1.9784
#     Fold 5/5: R²=0.2055, RMSE=2.5201, MAE=2.0439
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2755 ± 0.0420
#     RMSE: 2.5109 ± 0.0771
#     MAE:  1.9567 ± 0.0685
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2945, RMSE=2.3971, MAE=1.9123
#     Fold 2/5: R²=0.3023, RMSE=2.4619, MAE=1.9663
#     Fold 3/5: R²=0.2967, RMSE=2.5493, MAE=1.9002
#     Fold 4/5: R²=0.2756, RMSE=2.6352, MAE=1.9614
#     Fold 5/5: R²=0.2306, RMSE=2.4800, MAE=1.9848
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2799 ± 0.0263
#     RMSE: 2.5047 ± 0.0813
#     MAE:  1.9450 ± 0.0328
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1881, RMSE=2.5715, MAE=2.0426
#     Fold 2/5: R²=0.1742, RMSE=2.6784, MAE=2.1618
#     Fold 3/5: R²=0.1771, RMSE=2.7576, MAE=2.0845
#     Fold 4/5: R²=0.1803, RMSE=2.8031, MAE=2.2074
#     Fold 5/5: R²=0.1151, RMSE=2.6596, MAE=2.2109
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1670 ± 0.0263
#     RMSE: 2.6940 ± 0.0805
#     MAE:  2.1414 ± 0.0672
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2400, RMSE=2.4879, MAE=1.9880
#     Fold 2/5: R²=0.2732, RMSE=2.5128, MAE=1.9388
#     Fold 3/5: R²=0.2811, RMSE=2.5776, MAE=1.9288
#     Fold 4/5: R²=0.2485, RMSE=2.6840, MAE=1.9785
#     Fold 5/5: R²=0.1810, RMSE=2.5586, MAE=2.0828
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2447 ± 0.0353
#     RMSE: 2.5642 ± 0.0679
#     MAE:  1.9834 ± 0.0546
#
#   Training SVR...
#     Fold 1/5: R²=0.4071, RMSE=2.1974, MAE=1.6518
#     Fold 2/5: R²=0.4106, RMSE=2.2627, MAE=1.7426
#     Fold 3/5: R²=0.4884, RMSE=2.1744, MAE=1.5588
#     Fold 4/5: R²=0.4272, RMSE=2.3432, MAE=1.7281
#     Fold 5/5: R²=0.3378, RMSE=2.3008, MAE=1.7949
#
#   SVR 5-Fold CV Results:
#     R²:   0.4142 ± 0.0481
#     RMSE: 2.2557 ± 0.0628
#     MAE:  1.6952 ± 0.0822
#
#   Training KNN...
#     Fold 1/5: R²=0.3903, RMSE=2.2283, MAE=1.6937
#     Fold 2/5: R²=0.4586, RMSE=2.1686, MAE=1.6136
#     Fold 3/5: R²=0.4507, RMSE=2.2530, MAE=1.6530
#     Fold 4/5: R²=0.4320, RMSE=2.3333, MAE=1.7122
#     Fold 5/5: R²=0.2510, RMSE=2.4469, MAE=1.8210
#
#   KNN 5-Fold CV Results:
#     R²:   0.3965 ± 0.0765
#     RMSE: 2.2860 ± 0.0963
#     MAE:  1.6987 ± 0.0700
#
#   Training Lasso...
#     Fold 1/5: R²=0.1945, RMSE=2.5613, MAE=1.9865
#     Fold 2/5: R²=0.2317, RMSE=2.5834, MAE=2.0706
#     Fold 3/5: R²=0.2749, RMSE=2.5885, MAE=1.8860
#     Fold 4/5: R²=0.2335, RMSE=2.7106, MAE=2.0869
#     Fold 5/5: R²=0.1337, RMSE=2.6315, MAE=2.1501
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2137 ± 0.0474
#     RMSE: 2.6151 ± 0.0529
#     MAE:  2.0360 ± 0.0914
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3614, RMSE=2.2806, MAE=1.7925
#     Fold 2/5: R²=0.3691, RMSE=2.3410, MAE=1.8282
#     Fold 3/5: R²=0.3905, RMSE=2.3734, MAE=1.7349
#     Fold 4/5: R²=0.3601, RMSE=2.4766, MAE=1.8503
#     Fold 5/5: R²=0.2754, RMSE=2.4066, MAE=1.9342
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3513 ± 0.0395
#     RMSE: 2.3756 ± 0.0654
#     MAE:  1.8280 ± 0.0659
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1494, RMSE=2.6320, MAE=2.0917
#     Fold 2/5: R²=0.1968, RMSE=2.6415, MAE=2.1427
#     Fold 3/5: R²=0.0346, RMSE=2.9868, MAE=2.3086
#     Fold 4/5: R²=0.1509, RMSE=2.8528, MAE=2.2868
#     Fold 5/5: R²=0.1357, RMSE=2.6284, MAE=2.1877
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1335 ± 0.0536
#     RMSE: 2.7483 ± 0.1464
#     MAE:  2.2035 ± 0.0830
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4439, RMSE=2.1283, MAE=1.6317
#     Fold 2/5: R²=0.4294, RMSE=2.2264, MAE=1.7217
#     Fold 3/5: R²=0.3530, RMSE=2.4451, MAE=1.8512
#     Fold 4/5: R²=0.3522, RMSE=2.4919, MAE=1.9304
#     Fold 5/5: R²=0.3167, RMSE=2.3371, MAE=1.8143
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3790 ± 0.0490
#     RMSE: 2.3258 ± 0.1348
#     MAE:  1.7899 ± 0.1037
#
#   Training LightGBM...
#     Fold 1/5: R²=0.4674, RMSE=2.0828, MAE=1.6159
#     Fold 2/5: R²=0.4468, RMSE=2.1923, MAE=1.6880
#     Fold 3/5: R²=0.4368, RMSE=2.2814, MAE=1.7623
#     Fold 4/5: R²=0.3619, RMSE=2.4733, MAE=1.9336
#     Fold 5/5: R²=0.3611, RMSE=2.2599, MAE=1.7518
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.4148 ± 0.0446
#     RMSE: 2.2579 ± 0.1280
#     MAE:  1.7503 ± 0.1055
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2932, RMSE=2.3993, MAE=1.8892
#     Fold 2/5: R²=0.2747, RMSE=2.5100, MAE=2.0070
#     Fold 3/5: R²=0.2575, RMSE=2.6195, MAE=1.9991
#     Fold 4/5: R²=0.2179, RMSE=2.7380, MAE=2.1566
#     Fold 5/5: R²=0.2006, RMSE=2.5279, MAE=2.0603
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2488 ± 0.0346
#     RMSE: 2.5589 ± 0.1136
#     MAE:  2.0225 ± 0.0871
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.4595, RMSE=2.0982, MAE=1.6055
#     Fold 2/5: R²=0.3945, RMSE=2.2934, MAE=1.7683
#     Fold 3/5: R²=0.3671, RMSE=2.4185, MAE=1.8311
#     Fold 4/5: R²=0.3031, RMSE=2.5846, MAE=2.0138
#     Fold 5/5: R²=0.3250, RMSE=2.3229, MAE=1.8622
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3698 ± 0.0550
#     RMSE: 2.3435 ± 0.1593
#     MAE:  1.8162 ± 0.1327
#
#   Training SVR...
#     Fold 1/5: R²=0.6204, RMSE=1.7582, MAE=1.2834
#     Fold 2/5: R²=0.5922, RMSE=1.8821, MAE=1.3656
#     Fold 3/5: R²=0.6000, RMSE=1.9226, MAE=1.3598
#     Fold 4/5: R²=0.5667, RMSE=2.0380, MAE=1.5019
#     Fold 5/5: R²=0.5919, RMSE=1.8061, MAE=1.4053
#
#   SVR 5-Fold CV Results:
#     R²:   0.5943 ± 0.0172
#     RMSE: 1.8814 ± 0.0970
#     MAE:  1.3832 ± 0.0713
#
#   Training KNN...
#     Fold 1/5: R²=0.4892, RMSE=2.0397, MAE=1.5011
#     Fold 2/5: R²=0.5028, RMSE=2.0783, MAE=1.5299
#     Fold 3/5: R²=0.5141, RMSE=2.1190, MAE=1.5329
#     Fold 4/5: R²=0.3623, RMSE=2.4723, MAE=1.7485
#     Fold 5/5: R²=0.4094, RMSE=2.1728, MAE=1.5833
#
#   KNN 5-Fold CV Results:
#     R²:   0.4556 ± 0.0593
#     RMSE: 2.1764 ± 0.1544
#     MAE:  1.5792 ± 0.0887
#
#   Training Lasso...
#     Fold 1/5: R²=0.2335, RMSE=2.4985, MAE=1.9007
#     Fold 2/5: R²=0.3075, RMSE=2.4526, MAE=1.9782
#     Fold 3/5: R²=0.2359, RMSE=2.6574, MAE=2.0723
#     Fold 4/5: R²=0.1773, RMSE=2.8082, MAE=2.1198
#     Fold 5/5: R²=0.2298, RMSE=2.4812, MAE=1.9773
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2368 ± 0.0415
#     RMSE: 2.5796 ± 0.1347
#     MAE:  2.0097 ± 0.0774
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.5043, RMSE=2.0093, MAE=1.5217
#     Fold 2/5: R²=0.4906, RMSE=2.1035, MAE=1.6293
#     Fold 3/5: R²=0.4526, RMSE=2.2491, MAE=1.6792
#     Fold 4/5: R²=0.3995, RMSE=2.3992, MAE=1.8328
#     Fold 5/5: R²=0.4079, RMSE=2.1755, MAE=1.7145
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4510 ± 0.0423
#     RMSE: 2.1873 ± 0.1324
#     MAE:  1.6755 ± 0.1020
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1602, RMSE=2.6152, MAE=2.0728
#     Fold 2/5: R²=0.2644, RMSE=2.5279, MAE=2.0568
#     Fold 3/5: R²=0.1229, RMSE=2.8470, MAE=2.2070
#     Fold 4/5: R²=0.1749, RMSE=2.8124, MAE=2.2642
#     Fold 5/5: R²=0.0211, RMSE=2.7973, MAE=2.3467
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1487 ± 0.0789
#     RMSE: 2.7200 ± 0.1253
#     MAE:  2.1895 ± 0.1112
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4117, RMSE=2.1889, MAE=1.6722
#     Fold 2/5: R²=0.4005, RMSE=2.2820, MAE=1.7838
#     Fold 3/5: R²=0.3906, RMSE=2.3732, MAE=1.7527
#     Fold 4/5: R²=0.2970, RMSE=2.5959, MAE=1.9326
#     Fold 5/5: R²=0.3300, RMSE=2.3142, MAE=1.8512
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3660 ± 0.0446
#     RMSE: 2.3508 ± 0.1363
#     MAE:  1.7985 ± 0.0884
#
#   Training LightGBM...
#     Fold 1/5: R²=0.4466, RMSE=2.1229, MAE=1.6576
#     Fold 2/5: R²=0.3963, RMSE=2.2901, MAE=1.7908
#     Fold 3/5: R²=0.3803, RMSE=2.3931, MAE=1.7834
#     Fold 4/5: R²=0.3435, RMSE=2.5086, MAE=1.8321
#     Fold 5/5: R²=0.3343, RMSE=2.3067, MAE=1.8398
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3802 ± 0.0403
#     RMSE: 2.3243 ± 0.1271
#     MAE:  1.7807 ± 0.0654
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2364, RMSE=2.4939, MAE=1.9884
#     Fold 2/5: R²=0.2421, RMSE=2.5659, MAE=2.0575
#     Fold 3/5: R²=0.2225, RMSE=2.6805, MAE=2.0543
#     Fold 4/5: R²=0.2231, RMSE=2.7289, MAE=2.1512
#     Fold 5/5: R²=0.2124, RMSE=2.5091, MAE=2.0851
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2273 ± 0.0106
#     RMSE: 2.5957 ± 0.0935
#     MAE:  2.0673 ± 0.0526
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.4129, RMSE=2.1868, MAE=1.7026
#     Fold 2/5: R²=0.4173, RMSE=2.2498, MAE=1.7669
#     Fold 3/5: R²=0.3649, RMSE=2.4226, MAE=1.8190
#     Fold 4/5: R²=0.2868, RMSE=2.6147, MAE=1.9177
#     Fold 5/5: R²=0.2822, RMSE=2.3953, MAE=1.9148
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3528 ± 0.0588
#     RMSE: 2.3738 ± 0.1492
#     MAE:  1.8242 ± 0.0837
#
#   Training SVR...
#     Fold 1/5: R²=0.5945, RMSE=1.8173, MAE=1.3502
#     Fold 2/5: R²=0.5191, RMSE=2.0439, MAE=1.5343
#     Fold 3/5: R²=0.5942, RMSE=1.9365, MAE=1.4164
#     Fold 4/5: R²=0.5204, RMSE=2.1441, MAE=1.5980
#     Fold 5/5: R²=0.5177, RMSE=1.9635, MAE=1.4817
#
#   SVR 5-Fold CV Results:
#     R²:   0.5492 ± 0.0369
#     RMSE: 1.9811 ± 0.1092
#     MAE:  1.4761 ± 0.0868
#
#   Training KNN...
#     Fold 1/5: R²=0.4878, RMSE=2.0424, MAE=1.4545
#     Fold 2/5: R²=0.5116, RMSE=2.0598, MAE=1.4996
#     Fold 3/5: R²=0.4927, RMSE=2.1652, MAE=1.5598
#     Fold 4/5: R²=0.5039, RMSE=2.1807, MAE=1.5364
#     Fold 5/5: R²=0.4434, RMSE=2.1093, MAE=1.5731
#
#   KNN 5-Fold CV Results:
#     R²:   0.4879 ± 0.0238
#     RMSE: 2.1115 ± 0.0550
#     MAE:  1.5247 ± 0.0431
#
#   Training Lasso...
#     Fold 1/5: R²=0.3214, RMSE=2.3508, MAE=1.8268
#     Fold 2/5: R²=0.3352, RMSE=2.4030, MAE=1.8872
#     Fold 3/5: R²=0.2742, RMSE=2.5899, MAE=1.9084
#     Fold 4/5: R²=0.2878, RMSE=2.6128, MAE=1.9849
#     Fold 5/5: R²=0.2713, RMSE=2.4134, MAE=1.9304
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2980 ± 0.0258
#     RMSE: 2.4740 ± 0.1064
#     MAE:  1.9075 ± 0.0518
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4879, RMSE=2.0422, MAE=1.5466
#     Fold 2/5: R²=0.4641, RMSE=2.1577, MAE=1.6816
#     Fold 3/5: R²=0.4455, RMSE=2.2637, MAE=1.6645
#     Fold 4/5: R²=0.4062, RMSE=2.3857, MAE=1.7815
#     Fold 5/5: R²=0.4110, RMSE=2.1698, MAE=1.7195
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4429 ± 0.0311
#     RMSE: 2.2038 ± 0.1150
#     MAE:  1.6787 ± 0.0773
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2590, RMSE=2.4567, MAE=1.9240
#     Fold 2/5: R²=0.2892, RMSE=2.4849, MAE=1.9911
#     Fold 3/5: R²=0.1816, RMSE=2.7501, MAE=2.0940
#     Fold 4/5: R²=0.2392, RMSE=2.7004, MAE=2.1148
#     Fold 5/5: R²=0.2428, RMSE=2.4602, MAE=2.0080
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2424 ± 0.0351
#     RMSE: 2.5704 ± 0.1278
#     MAE:  2.0264 ± 0.0699
#
# ====================================================================================================
# NOISE TYPE: Mid Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3007, RMSE=2.3694, MAE=1.7980
#     Fold 2/5: R²=0.2956, RMSE=2.2516, MAE=1.6660
#     Fold 3/5: R²=0.3496, RMSE=2.4124, MAE=1.7195
#     Fold 4/5: R²=0.3141, RMSE=2.3917, MAE=1.8087
#     Fold 5/5: R²=0.3057, RMSE=2.5825, MAE=1.9271
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3131 ± 0.0192
#     RMSE: 2.4015 ± 0.1063
#     MAE:  1.7838 ± 0.0887
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3297, RMSE=2.3198, MAE=1.7507
#     Fold 2/5: R²=0.3171, RMSE=2.2170, MAE=1.7129
#     Fold 3/5: R²=0.3174, RMSE=2.4715, MAE=1.7573
#     Fold 4/5: R²=0.3375, RMSE=2.3505, MAE=1.8027
#     Fold 5/5: R²=0.3286, RMSE=2.5397, MAE=1.9105
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3260 ± 0.0078
#     RMSE: 2.3797 ± 0.1140
#     MAE:  1.7868 ± 0.0681
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2041, RMSE=2.5277, MAE=1.9578
#     Fold 2/5: R²=0.1788, RMSE=2.4311, MAE=1.8732
#     Fold 3/5: R²=0.2374, RMSE=2.6122, MAE=1.9290
#     Fold 4/5: R²=0.2047, RMSE=2.5753, MAE=1.9723
#     Fold 5/5: R²=0.2052, RMSE=2.7631, MAE=2.0807
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2061 ± 0.0186
#     RMSE: 2.5819 ± 0.1091
#     MAE:  1.9626 ± 0.0681
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3144, RMSE=2.3461, MAE=1.7605
#     Fold 2/5: R²=0.2759, RMSE=2.2828, MAE=1.7053
#     Fold 3/5: R²=0.3394, RMSE=2.4313, MAE=1.7570
#     Fold 4/5: R²=0.2513, RMSE=2.4987, MAE=1.8846
#     Fold 5/5: R²=0.3325, RMSE=2.5321, MAE=1.9321
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3027 ± 0.0338
#     RMSE: 2.4182 ± 0.0929
#     MAE:  1.8079 ± 0.0856
#
#   Training SVR...
#     Fold 1/5: R²=0.5224, RMSE=1.9581, MAE=1.4911
#     Fold 2/5: R²=0.4688, RMSE=1.9554, MAE=1.5183
#     Fold 3/5: R²=0.4908, RMSE=2.1345, MAE=1.4772
#     Fold 4/5: R²=0.4968, RMSE=2.0486, MAE=1.5538
#     Fold 5/5: R²=0.4346, RMSE=2.3305, MAE=1.7514
#
#   SVR 5-Fold CV Results:
#     R²:   0.4827 ± 0.0295
#     RMSE: 2.0854 ± 0.1393
#     MAE:  1.5584 ± 0.1000
#
#   Training KNN...
#     Fold 1/5: R²=0.5554, RMSE=1.8893, MAE=1.4469
#     Fold 2/5: R²=0.5417, RMSE=1.8161, MAE=1.3834
#     Fold 3/5: R²=0.5388, RMSE=2.0315, MAE=1.4382
#     Fold 4/5: R²=0.4792, RMSE=2.0840, MAE=1.5384
#     Fold 5/5: R²=0.4443, RMSE=2.3104, MAE=1.6875
#
#   KNN 5-Fold CV Results:
#     R²:   0.5119 ± 0.0428
#     RMSE: 2.0263 ± 0.1715
#     MAE:  1.4989 ± 0.1066
#
#   Training Lasso...
#     Fold 1/5: R²=0.3176, RMSE=2.3405, MAE=1.8102
#     Fold 2/5: R²=0.2880, RMSE=2.2638, MAE=1.7437
#     Fold 3/5: R²=0.2655, RMSE=2.5636, MAE=1.8936
#     Fold 4/5: R²=0.1620, RMSE=2.6436, MAE=2.0457
#     Fold 5/5: R²=0.2443, RMSE=2.6943, MAE=2.0331
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2555 ± 0.0527
#     RMSE: 2.5011 ± 0.1695
#     MAE:  1.9052 ± 0.1194
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4270, RMSE=2.1448, MAE=1.6189
#     Fold 2/5: R²=0.4078, RMSE=2.0645, MAE=1.5758
#     Fold 3/5: R²=0.4302, RMSE=2.2580, MAE=1.6184
#     Fold 4/5: R²=0.3950, RMSE=2.2462, MAE=1.7157
#     Fold 5/5: R²=0.3830, RMSE=2.4345, MAE=1.8128
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4086 ± 0.0181
#     RMSE: 2.2296 ± 0.1245
#     MAE:  1.6683 ± 0.0856
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3408, RMSE=2.3005, MAE=1.7945
#     Fold 2/5: R²=0.3124, RMSE=2.2246, MAE=1.7490
#     Fold 3/5: R²=0.2693, RMSE=2.5570, MAE=1.8657
#     Fold 4/5: R²=0.3659, RMSE=2.2996, MAE=1.7667
#     Fold 5/5: R²=0.2675, RMSE=2.6527, MAE=1.9781
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.3112 ± 0.0388
#     RMSE: 2.4069 ± 0.1668
#     MAE:  1.8308 ± 0.0837
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4639, RMSE=2.0746, MAE=1.5813
#     Fold 2/5: R²=0.4258, RMSE=2.0328, MAE=1.4906
#     Fold 3/5: R²=0.3603, RMSE=2.3926, MAE=1.6273
#     Fold 4/5: R²=0.4837, RMSE=2.0750, MAE=1.5658
#     Fold 5/5: R²=0.3188, RMSE=2.5580, MAE=1.7909
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.4105 ± 0.0622
#     RMSE: 2.2266 ± 0.2103
#     MAE:  1.6112 ± 0.1000
#
#   Training LightGBM...
#     Fold 1/5: R²=0.5065, RMSE=1.9904, MAE=1.5098
#     Fold 2/5: R²=0.4629, RMSE=1.9661, MAE=1.4481
#     Fold 3/5: R²=0.3934, RMSE=2.3298, MAE=1.6021
#     Fold 4/5: R²=0.4887, RMSE=2.0650, MAE=1.5964
#     Fold 5/5: R²=0.4014, RMSE=2.3980, MAE=1.7274
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.4506 ± 0.0456
#     RMSE: 2.1498 ± 0.1791
#     MAE:  1.5767 ± 0.0946
#
#   Training Random Forest...
#     Fold 1/5: R²=0.3135, RMSE=2.3476, MAE=1.7952
#     Fold 2/5: R²=0.3093, RMSE=2.2295, MAE=1.6828
#     Fold 3/5: R²=0.2683, RMSE=2.5589, MAE=1.8476
#     Fold 4/5: R²=0.3192, RMSE=2.3827, MAE=1.8119
#     Fold 5/5: R²=0.2495, RMSE=2.6851, MAE=1.9280
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2920 ± 0.0278
#     RMSE: 2.4408 ± 0.1614
#     MAE:  1.8131 ± 0.0796
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.4858, RMSE=2.0317, MAE=1.5661
#     Fold 2/5: R²=0.4810, RMSE=1.9326, MAE=1.4336
#     Fold 3/5: R²=0.3666, RMSE=2.3807, MAE=1.6555
#     Fold 4/5: R²=0.4598, RMSE=2.1225, MAE=1.5834
#     Fold 5/5: R²=0.3318, RMSE=2.5335, MAE=1.7875
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.4250 ± 0.0635
#     RMSE: 2.2002 ± 0.2235
#     MAE:  1.6052 ± 0.1160
#
#   Training SVR...
#     Fold 1/5: R²=0.6411, RMSE=1.6974, MAE=1.2520
#     Fold 2/5: R²=0.6327, RMSE=1.6258, MAE=1.1648
#     Fold 3/5: R²=0.5417, RMSE=2.0252, MAE=1.3522
#     Fold 4/5: R²=0.6650, RMSE=1.6715, MAE=1.2240
#     Fold 5/5: R²=0.6364, RMSE=1.8690, MAE=1.3334
#
#   SVR 5-Fold CV Results:
#     R²:   0.6234 ± 0.0424
#     RMSE: 1.7778 ± 0.1486
#     MAE:  1.2653 ± 0.0695
#
#   Training KNN...
#     Fold 1/5: R²=0.5850, RMSE=1.8252, MAE=1.3234
#     Fold 2/5: R²=0.5467, RMSE=1.8063, MAE=1.2188
#     Fold 3/5: R²=0.4338, RMSE=2.2510, MAE=1.5162
#     Fold 4/5: R²=0.5167, RMSE=2.0076, MAE=1.4767
#     Fold 5/5: R²=0.5076, RMSE=2.1748, MAE=1.4970
#
#   KNN 5-Fold CV Results:
#     R²:   0.5180 ± 0.0500
#     RMSE: 2.0130 ± 0.1793
#     MAE:  1.4064 ± 0.1160
#
#   Training Lasso...
#     Fold 1/5: R²=0.4423, RMSE=2.1160, MAE=1.6244
#     Fold 2/5: R²=0.3220, RMSE=2.2090, MAE=1.6081
#     Fold 3/5: R²=0.3138, RMSE=2.4780, MAE=1.7565
#     Fold 4/5: R²=0.4579, RMSE=2.1262, MAE=1.6899
#     Fold 5/5: R²=0.3390, RMSE=2.5198, MAE=1.8429
#
#   Lasso 5-Fold CV Results:
#     R²:   0.3750 ± 0.0621
#     RMSE: 2.2898 ± 0.1743
#     MAE:  1.7043 ± 0.0869
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.5511, RMSE=1.8984, MAE=1.4282
#     Fold 2/5: R²=0.5171, RMSE=1.8643, MAE=1.3438
#     Fold 3/5: R²=0.4340, RMSE=2.2504, MAE=1.5425
#     Fold 4/5: R²=0.5429, RMSE=1.9525, MAE=1.4793
#     Fold 5/5: R²=0.4500, RMSE=2.2986, MAE=1.6180
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4990 ± 0.0481
#     RMSE: 2.0528 ± 0.1838
#     MAE:  1.4824 ± 0.0940
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.4922, RMSE=2.0190, MAE=1.5391
#     Fold 2/5: R²=0.4484, RMSE=1.9926, MAE=1.4891
#     Fold 3/5: R²=0.3694, RMSE=2.3754, MAE=1.6640
#     Fold 4/5: R²=0.4906, RMSE=2.0611, MAE=1.5412
#     Fold 5/5: R²=0.2754, RMSE=2.6383, MAE=1.9479
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.4152 ± 0.0829
#     RMSE: 2.2173 ± 0.2516
#     MAE:  1.6363 ± 0.1662
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4944, RMSE=2.0147, MAE=1.5191
#     Fold 2/5: R²=0.4660, RMSE=1.9604, MAE=1.3965
#     Fold 3/5: R²=0.3857, RMSE=2.3446, MAE=1.6770
#     Fold 4/5: R²=0.4374, RMSE=2.1661, MAE=1.6347
#     Fold 5/5: R²=0.3840, RMSE=2.4325, MAE=1.7735
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.4335 ± 0.0436
#     RMSE: 2.1837 ± 0.1825
#     MAE:  1.6002 ± 0.1305
#
#   Training LightGBM...
#     Fold 1/5: R²=0.4737, RMSE=2.0555, MAE=1.5629
#     Fold 2/5: R²=0.4460, RMSE=1.9967, MAE=1.4396
#     Fold 3/5: R²=0.4230, RMSE=2.2723, MAE=1.6368
#     Fold 4/5: R²=0.4299, RMSE=2.1804, MAE=1.7022
#     Fold 5/5: R²=0.4287, RMSE=2.3426, MAE=1.7284
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.4403 ± 0.0184
#     RMSE: 2.1695 ± 0.1292
#     MAE:  1.6140 ± 0.1043
#
#   Training Random Forest...
#     Fold 1/5: R²=0.3028, RMSE=2.3658, MAE=1.8189
#     Fold 2/5: R²=0.3021, RMSE=2.2412, MAE=1.7038
#     Fold 3/5: R²=0.2829, RMSE=2.5332, MAE=1.8367
#     Fold 4/5: R²=0.2681, RMSE=2.4705, MAE=1.8796
#     Fold 5/5: R²=0.2426, RMSE=2.6973, MAE=1.9929
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2797 ± 0.0226
#     RMSE: 2.4616 ± 0.1540
#     MAE:  1.8464 ± 0.0936
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.4666, RMSE=2.0693, MAE=1.5753
#     Fold 2/5: R²=0.4217, RMSE=2.0401, MAE=1.4494
#     Fold 3/5: R²=0.3942, RMSE=2.3283, MAE=1.6633
#     Fold 4/5: R²=0.3766, RMSE=2.2800, MAE=1.7357
#     Fold 5/5: R²=0.4081, RMSE=2.3845, MAE=1.7751
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.4135 ± 0.0305
#     RMSE: 2.2204 ± 0.1396
#     MAE:  1.6398 ± 0.1170
#
#   Training SVR...
#     Fold 1/5: R²=0.6638, RMSE=1.6428, MAE=1.2340
#     Fold 2/5: R²=0.5729, RMSE=1.7532, MAE=1.2512
#     Fold 3/5: R²=0.5395, RMSE=2.0299, MAE=1.3599
#     Fold 4/5: R²=0.6117, RMSE=1.7995, MAE=1.3299
#     Fold 5/5: R²=0.5811, RMSE=2.0061, MAE=1.4661
#
#   SVR 5-Fold CV Results:
#     R²:   0.5938 ± 0.0419
#     RMSE: 1.8463 ± 0.1493
#     MAE:  1.3282 ± 0.0834
#
#   Training KNN...
#     Fold 1/5: R²=0.6264, RMSE=1.7317, MAE=1.2771
#     Fold 2/5: R²=0.5832, RMSE=1.7320, MAE=1.1840
#     Fold 3/5: R²=0.4578, RMSE=2.2027, MAE=1.4562
#     Fold 4/5: R²=0.5975, RMSE=1.8322, MAE=1.3621
#     Fold 5/5: R²=0.5451, RMSE=2.0904, MAE=1.5284
#
#   KNN 5-Fold CV Results:
#     R²:   0.5620 ± 0.0583
#     RMSE: 1.9178 ± 0.1936
#     MAE:  1.3615 ± 0.1228
#
#   Training Lasso...
#     Fold 1/5: R²=0.4286, RMSE=2.1418, MAE=1.6022
#     Fold 2/5: R²=0.3577, RMSE=2.1501, MAE=1.6032
#     Fold 3/5: R²=0.3867, RMSE=2.3427, MAE=1.6652
#     Fold 4/5: R²=0.3753, RMSE=2.2825, MAE=1.8146
#     Fold 5/5: R²=0.3534, RMSE=2.4922, MAE=1.8086
#
#   Lasso 5-Fold CV Results:
#     R²:   0.3803 ± 0.0269
#     RMSE: 2.2819 ± 0.1303
#     MAE:  1.6988 ± 0.0950
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.5484, RMSE=1.9040, MAE=1.4276
#     Fold 2/5: R²=0.5139, RMSE=1.8704, MAE=1.3369
#     Fold 3/5: R²=0.4665, RMSE=2.1848, MAE=1.5267
#     Fold 4/5: R²=0.5043, RMSE=2.0331, MAE=1.5511
#     Fold 5/5: R²=0.4735, RMSE=2.2489, MAE=1.6347
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.5014 ± 0.0296
#     RMSE: 2.0482 ± 0.1494
#     MAE:  1.4954 ± 0.1031
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.4628, RMSE=2.0768, MAE=1.5870
#     Fold 2/5: R²=0.3958, RMSE=2.0854, MAE=1.5578
#     Fold 3/5: R²=0.2604, RMSE=2.5726, MAE=1.8497
#     Fold 4/5: R²=0.4428, RMSE=2.1556, MAE=1.6350
#     Fold 5/5: R²=0.3610, RMSE=2.4776, MAE=1.8250
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.3845 ± 0.0716
#     RMSE: 2.2736 ± 0.2093
#     MAE:  1.6909 ± 0.1223
#
# ====================================================================================================
# NOISE TYPE: High Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3745, RMSE=2.4325, MAE=1.8670
#     Fold 2/5: R²=0.2635, RMSE=2.6287, MAE=1.8926
#     Fold 3/5: R²=0.2789, RMSE=2.8183, MAE=1.9257
#     Fold 4/5: R²=0.3269, RMSE=2.8891, MAE=1.9913
#     Fold 5/5: R²=0.2879, RMSE=2.8520, MAE=2.1223
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3064 ± 0.0400
#     RMSE: 2.7241 ± 0.1712
#     MAE:  1.9598 ± 0.0913
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3925, RMSE=2.3972, MAE=1.8617
#     Fold 2/5: R²=0.1715, RMSE=2.7881, MAE=2.0135
#     Fold 3/5: R²=0.3244, RMSE=2.7281, MAE=1.8781
#     Fold 4/5: R²=0.3336, RMSE=2.8748, MAE=2.0229
#     Fold 5/5: R²=0.2609, RMSE=2.9055, MAE=2.1622
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2966 ± 0.0752
#     RMSE: 2.7388 ± 0.1820
#     MAE:  1.9877 ± 0.1098
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2441, RMSE=2.6741, MAE=2.0281
#     Fold 2/5: R²=0.1343, RMSE=2.8499, MAE=2.0342
#     Fold 3/5: R²=0.1916, RMSE=2.9842, MAE=2.0491
#     Fold 4/5: R²=0.1612, RMSE=3.2252, MAE=2.2264
#     Fold 5/5: R²=0.1891, RMSE=3.0434, MAE=2.2538
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1840 ± 0.0365
#     RMSE: 2.9554 ± 0.1853
#     MAE:  2.1183 ± 0.1000
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3841, RMSE=2.4137, MAE=1.8473
#     Fold 2/5: R²=0.1915, RMSE=2.7542, MAE=1.9221
#     Fold 3/5: R²=0.2605, RMSE=2.8542, MAE=1.9272
#     Fold 4/5: R²=0.2543, RMSE=3.0411, MAE=2.0756
#     Fold 5/5: R²=0.2285, RMSE=2.9685, MAE=2.1605
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2638 ± 0.0649
#     RMSE: 2.8063 ± 0.2193
#     MAE:  1.9866 ± 0.1143
#
#   Training SVR...
#     Fold 1/5: R²=0.4768, RMSE=2.2248, MAE=1.6828
#     Fold 2/5: R²=0.3845, RMSE=2.4030, MAE=1.7339
#     Fold 3/5: R²=0.4232, RMSE=2.5207, MAE=1.7977
#     Fold 4/5: R²=0.4432, RMSE=2.6277, MAE=1.8086
#     Fold 5/5: R²=0.3708, RMSE=2.6808, MAE=1.9608
#
#   SVR 5-Fold CV Results:
#     R²:   0.4197 ± 0.0386
#     RMSE: 2.4914 ± 0.1638
#     MAE:  1.7968 ± 0.0938
#
#   Training KNN...
#     Fold 1/5: R²=0.5209, RMSE=2.1289, MAE=1.6718
#     Fold 2/5: R²=0.4225, RMSE=2.3278, MAE=1.6537
#     Fold 3/5: R²=0.4207, RMSE=2.5262, MAE=1.7022
#     Fold 4/5: R²=0.4717, RMSE=2.5596, MAE=1.7098
#     Fold 5/5: R²=0.3131, RMSE=2.8011, MAE=2.0514
#
#   KNN 5-Fold CV Results:
#     R²:   0.4298 ± 0.0690
#     RMSE: 2.4687 ± 0.2269
#     MAE:  1.7578 ± 0.1482
#
#   Training Lasso...
#     Fold 1/5: R²=0.1978, RMSE=2.7548, MAE=2.0697
#     Fold 2/5: R²=0.3143, RMSE=2.5365, MAE=1.9199
#     Fold 3/5: R²=0.1896, RMSE=2.9878, MAE=2.0321
#     Fold 4/5: R²=0.1691, RMSE=3.2100, MAE=2.2970
#     Fold 5/5: R²=0.2331, RMSE=2.9596, MAE=2.1785
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2208 ± 0.0511
#     RMSE: 2.8897 ± 0.2281
#     MAE:  2.0994 ± 0.1288
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4279, RMSE=2.3262, MAE=1.7720
#     Fold 2/5: R²=0.3382, RMSE=2.4919, MAE=1.7848
#     Fold 3/5: R²=0.3603, RMSE=2.6545, MAE=1.7824
#     Fold 4/5: R²=0.3563, RMSE=2.8253, MAE=1.9362
#     Fold 5/5: R²=0.3278, RMSE=2.7709, MAE=2.0412
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3621 ± 0.0350
#     RMSE: 2.6138 ± 0.1837
#     MAE:  1.8633 ± 0.1077
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=-0.0011, RMSE=3.0773, MAE=2.2900
#     Fold 2/5: R²=0.1519, RMSE=2.8208, MAE=1.9981
#     Fold 3/5: R²=-0.0279, RMSE=3.3649, MAE=2.3505
#     Fold 4/5: R²=-0.0285, RMSE=3.5713, MAE=2.4627
#     Fold 5/5: R²=0.0795, RMSE=3.2425, MAE=2.4038
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.0348 ± 0.0706
#     RMSE: 3.2154 ± 0.2548
#     MAE:  2.3010 ± 0.1619
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3477, RMSE=2.4841, MAE=1.8483
#     Fold 2/5: R²=0.3824, RMSE=2.4071, MAE=1.6243
#     Fold 3/5: R²=0.4441, RMSE=2.4745, MAE=1.6930
#     Fold 4/5: R²=0.4762, RMSE=2.5486, MAE=1.7707
#     Fold 5/5: R²=0.3002, RMSE=2.8271, MAE=2.0421
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.3901 ± 0.0637
#     RMSE: 2.5483 ± 0.1464
#     MAE:  1.7957 ± 0.1442
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3287, RMSE=2.5199, MAE=1.8607
#     Fold 2/5: R²=0.3471, RMSE=2.4749, MAE=1.6981
#     Fold 3/5: R²=0.3957, RMSE=2.5800, MAE=1.7800
#     Fold 4/5: R²=0.4485, RMSE=2.6152, MAE=1.7587
#     Fold 5/5: R²=0.3356, RMSE=2.7548, MAE=1.9678
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.3711 ± 0.0452
#     RMSE: 2.5890 ± 0.0960
#     MAE:  1.8131 ± 0.0933
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2406, RMSE=2.6803, MAE=1.9705
#     Fold 2/5: R²=0.2952, RMSE=2.5715, MAE=1.7487
#     Fold 3/5: R²=0.2731, RMSE=2.8297, MAE=1.9299
#     Fold 4/5: R²=0.2920, RMSE=2.9630, MAE=2.0557
#     Fold 5/5: R²=0.2403, RMSE=2.9457, MAE=2.1390
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2683 ± 0.0239
#     RMSE: 2.7980 ± 0.1518
#     MAE:  1.9688 ± 0.1315
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3730, RMSE=2.4354, MAE=1.8342
#     Fold 2/5: R²=0.3033, RMSE=2.5567, MAE=1.7348
#     Fold 3/5: R²=0.4664, RMSE=2.4244, MAE=1.6474
#     Fold 4/5: R²=0.4324, RMSE=2.6531, MAE=1.8859
#     Fold 5/5: R²=0.3041, RMSE=2.8192, MAE=2.0462
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3758 ± 0.0661
#     RMSE: 2.5778 ± 0.1471
#     MAE:  1.8297 ± 0.1359
#
#   Training SVR...
#     Fold 1/5: R²=0.6093, RMSE=1.9225, MAE=1.4366
#     Fold 2/5: R²=0.6100, RMSE=1.9128, MAE=1.3100
#     Fold 3/5: R²=0.6789, RMSE=1.8808, MAE=1.2831
#     Fold 4/5: R²=0.7063, RMSE=1.9084, MAE=1.3222
#     Fold 5/5: R²=0.5360, RMSE=2.3022, MAE=1.6296
#
#   SVR 5-Fold CV Results:
#     R²:   0.6281 ± 0.0598
#     RMSE: 1.9854 ± 0.1590
#     MAE:  1.3963 ± 0.1279
#
#   Training KNN...
#     Fold 1/5: R²=0.5985, RMSE=1.9487, MAE=1.4847
#     Fold 2/5: R²=0.5268, RMSE=2.1072, MAE=1.3659
#     Fold 3/5: R²=0.5630, RMSE=2.1940, MAE=1.4720
#     Fold 4/5: R²=0.5933, RMSE=2.2459, MAE=1.5807
#     Fold 5/5: R²=0.3994, RMSE=2.6191, MAE=1.8786
#
#   KNN 5-Fold CV Results:
#     R²:   0.5362 ± 0.0730
#     RMSE: 2.2230 ± 0.2222
#     MAE:  1.5564 ± 0.1749
#
#   Training Lasso...
#     Fold 1/5: R²=0.2092, RMSE=2.7351, MAE=2.0408
#     Fold 2/5: R²=0.2544, RMSE=2.6449, MAE=1.9069
#     Fold 3/5: R²=0.3055, RMSE=2.7659, MAE=1.9481
#     Fold 4/5: R²=0.2680, RMSE=3.0129, MAE=2.1168
#     Fold 5/5: R²=0.1915, RMSE=3.0388, MAE=2.2162
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2457 ± 0.0410
#     RMSE: 2.8395 ± 0.1575
#     MAE:  2.0458 ± 0.1122
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4505, RMSE=2.2799, MAE=1.6736
#     Fold 2/5: R²=0.4561, RMSE=2.2591, MAE=1.5141
#     Fold 3/5: R²=0.5067, RMSE=2.3311, MAE=1.5725
#     Fold 4/5: R²=0.5171, RMSE=2.4471, MAE=1.6943
#     Fold 5/5: R²=0.3878, RMSE=2.6444, MAE=1.9109
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4636 ± 0.0463
#     RMSE: 2.3923 ± 0.1419
#     MAE:  1.6731 ± 0.1359
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=-0.0096, RMSE=3.0903, MAE=2.2970
#     Fold 2/5: R²=-0.0056, RMSE=3.0715, MAE=2.1531
#     Fold 3/5: R²=-0.0442, RMSE=3.3915, MAE=2.3722
#     Fold 4/5: R²=-0.0499, RMSE=3.6083, MAE=2.5051
#     Fold 5/5: R²=-0.0034, RMSE=3.3854, MAE=2.4938
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   -0.0225 ± 0.0202
#     RMSE: 3.3094 ± 0.2032
#     MAE:  2.3642 ± 0.1310
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.4342, RMSE=2.3135, MAE=1.7622
#     Fold 2/5: R²=0.4036, RMSE=2.3655, MAE=1.8002
#     Fold 3/5: R²=0.4145, RMSE=2.5397, MAE=1.7603
#     Fold 4/5: R²=0.4040, RMSE=2.7186, MAE=1.8927
#     Fold 5/5: R²=0.3812, RMSE=2.6585, MAE=1.9467
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.4075 ± 0.0172
#     RMSE: 2.5191 ± 0.1584
#     MAE:  1.8324 ± 0.0746
#
#   Training LightGBM...
#     Fold 1/5: R²=0.4268, RMSE=2.3287, MAE=1.7377
#     Fold 2/5: R²=0.4524, RMSE=2.2667, MAE=1.7027
#     Fold 3/5: R²=0.4820, RMSE=2.3887, MAE=1.6901
#     Fold 4/5: R²=0.4403, RMSE=2.6346, MAE=1.8176
#     Fold 5/5: R²=0.4083, RMSE=2.5997, MAE=1.9308
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.4419 ± 0.0248
#     RMSE: 2.4437 ± 0.1472
#     MAE:  1.7758 ± 0.0894
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2544, RMSE=2.6558, MAE=1.9799
#     Fold 2/5: R²=0.2493, RMSE=2.6540, MAE=1.9099
#     Fold 3/5: R²=0.2118, RMSE=2.9466, MAE=1.9838
#     Fold 4/5: R²=0.2061, RMSE=3.1377, MAE=2.1707
#     Fold 5/5: R²=0.2225, RMSE=2.9800, MAE=2.1581
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.2288 ± 0.0196
#     RMSE: 2.8748 ± 0.1908
#     MAE:  2.0405 ± 0.1046
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.4658, RMSE=2.2479, MAE=1.7029
#     Fold 2/5: R²=0.3190, RMSE=2.5276, MAE=1.8907
#     Fold 3/5: R²=0.4256, RMSE=2.5155, MAE=1.7363
#     Fold 4/5: R²=0.4020, RMSE=2.7232, MAE=1.8807
#     Fold 5/5: R²=0.3658, RMSE=2.6915, MAE=1.9317
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.3956 ± 0.0502
#     RMSE: 2.5412 ± 0.1689
#     MAE:  1.8284 ± 0.0911
#
#   Training SVR...
#     Fold 1/5: R²=0.5747, RMSE=2.0057, MAE=1.5145
#     Fold 2/5: R²=0.5750, RMSE=1.9969, MAE=1.4646
#     Fold 3/5: R²=0.6077, RMSE=2.0788, MAE=1.4758
#     Fold 4/5: R²=0.6523, RMSE=2.0765, MAE=1.4295
#     Fold 5/5: R²=0.5493, RMSE=2.2688, MAE=1.7253
#
#   SVR 5-Fold CV Results:
#     R²:   0.5918 ± 0.0355
#     RMSE: 2.0853 ± 0.0979
#     MAE:  1.5220 ± 0.1052
#
#   Training KNN...
#     Fold 1/5: R²=0.5952, RMSE=1.9567, MAE=1.4118
#     Fold 2/5: R²=0.5578, RMSE=2.0369, MAE=1.4199
#     Fold 3/5: R²=0.5549, RMSE=2.2143, MAE=1.5099
#     Fold 4/5: R²=0.6003, RMSE=2.2265, MAE=1.5596
#     Fold 5/5: R²=0.4852, RMSE=2.4248, MAE=1.7067
#
#   KNN 5-Fold CV Results:
#     R²:   0.5587 ± 0.0412
#     RMSE: 2.1718 ± 0.1633
#     MAE:  1.5216 ± 0.1079
#
#   Training Lasso...
#     Fold 1/5: R²=0.2617, RMSE=2.6428, MAE=1.9876
#     Fold 2/5: R²=0.3896, RMSE=2.3932, MAE=1.8183
#     Fold 3/5: R²=0.3441, RMSE=2.6881, MAE=1.8909
#     Fold 4/5: R²=0.2677, RMSE=3.0136, MAE=2.1416
#     Fold 5/5: R²=0.2159, RMSE=2.9926, MAE=2.2040
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2958 ± 0.0624
#     RMSE: 2.7460 ± 0.2328
#     MAE:  2.0085 ± 0.1459
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.4935, RMSE=2.1889, MAE=1.6429
#     Fold 2/5: R²=0.4980, RMSE=2.1702, MAE=1.5889
#     Fold 3/5: R²=0.4942, RMSE=2.3605, MAE=1.6084
#     Fold 4/5: R²=0.4741, RMSE=2.5539, MAE=1.7571
#     Fold 5/5: R²=0.4311, RMSE=2.5491, MAE=1.8634
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.4782 ± 0.0250
#     RMSE: 2.3645 ± 0.1665
#     MAE:  1.6921 ± 0.1036
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=-0.0064, RMSE=3.0854, MAE=2.2938
#     Fold 2/5: R²=0.3366, RMSE=2.4949, MAE=1.7742
#     Fold 3/5: R²=-0.0410, RMSE=3.3863, MAE=2.3678
#     Fold 4/5: R²=-0.0446, RMSE=3.5992, MAE=2.4943
#     Fold 5/5: R²=-0.0020, RMSE=3.3830, MAE=2.4943
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.0485 ± 0.1451
#     RMSE: 3.1898 ± 0.3840
#     MAE:  2.2849 ± 0.2666
#
# ========================================================================================================================
#                           K-FOLD CROSS-VALIDATION RESULTS SUMMARY
# ========================================================================================================================
#
# ====================================================================================================
# NOISE TYPE: Mean Noise
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.6486 ± 0.0384
#   RMSE: 1.7736 ± 0.1669
#   MAE:  1.2622 ± 0.1078
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.5964 ± 0.0453
#   RMSE: 1.9001 ± 0.1792
#   MAE:  1.3843 ± 0.1164
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.5553 ± 0.0526
#   RMSE: 1.9955 ± 0.2030
#   MAE:  1.3938 ± 0.1397
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.5499 ± 0.0465
#   RMSE: 2.0103 ± 0.2104
#   MAE:  1.4340 ± 0.1351
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.5202 ± 0.0396
#   RMSE: 2.0749 ± 0.1934
#   MAE:  1.5288 ± 0.1247
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.5138 ± 0.0560
#   RMSE: 2.0873 ± 0.2177
#   MAE:  1.5090 ± 0.1361
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.5048 ± 0.0485
#   RMSE: 2.1075 ± 0.2080
#   MAE:  1.5377 ± 0.1509
# ...
# SVR                  (Base      ) + Fusion
#   R²:   0.5492 ± 0.0369
#   RMSE: 1.9811 ± 0.1092
#   MAE:  1.4761 ± 0.0868
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.4879 ± 0.0238
#   RMSE: 2.1115 ± 0.0550
#   MAE:  1.5247 ± 0.0431
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.4556 ± 0.0593
#   RMSE: 2.1764 ± 0.1544
#   MAE:  1.5792 ± 0.0887
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.4510 ± 0.0423
#   RMSE: 2.1873 ± 0.1324
#   MAE:  1.6755 ± 0.1020
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.4429 ± 0.0311
#   RMSE: 2.2038 ± 0.1150
#   MAE:  1.6787 ± 0.0773
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Remote Sensing
#   R²:   0.4148 ± 0.0446
#   RMSE: 2.2579 ± 0.1280
#   MAE:  1.7503 ± 0.1055
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.4142 ± 0.0481
#   RMSE: 2.2557 ± 0.0628
#   MAE:  1.6952 ± 0.0822
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.3965 ± 0.0765
#   RMSE: 2.2860 ± 0.0963
#   MAE:  1.6987 ± 0.0700
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Fusion
#   R²:   0.3802 ± 0.0403
#   RMSE: 2.3243 ± 0.1271
#   MAE:  1.7807 ± 0.0654
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# NOISE TYPE: Mid Freq
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.6234 ± 0.0424
#   RMSE: 1.7778 ± 0.1486
#   MAE:  1.2653 ± 0.0695
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.5938 ± 0.0419
#   RMSE: 1.8463 ± 0.1493
#   MAE:  1.3282 ± 0.0834
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.5620 ± 0.0583
#   RMSE: 1.9178 ± 0.1936
#   MAE:  1.3615 ± 0.1228
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.5180 ± 0.0500
#   RMSE: 2.0130 ± 0.1793
#   MAE:  1.4064 ± 0.1160
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.5119 ± 0.0428
#   RMSE: 2.0263 ± 0.1715
#   MAE:  1.4989 ± 0.1066
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.5014 ± 0.0296
#   RMSE: 2.0482 ± 0.1494
#   MAE:  1.4954 ± 0.1031
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.4990 ± 0.0481
#   RMSE: 2.0528 ± 0.1838
#   MAE:  1.4824 ± 0.0940
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.4827 ± 0.0295
#   RMSE: 2.0854 ± 0.1393
#   MAE:  1.5584 ± 0.1000
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Remote Sensing
#   R²:   0.4506 ± 0.0456
#   RMSE: 2.1498 ± 0.1791
#   MAE:  1.5767 ± 0.0946
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Fusion
#   R²:   0.4403 ± 0.0184
#   RMSE: 2.1695 ± 0.1292
#   MAE:  1.6140 ± 0.1043
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# NOISE TYPE: High Freq
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.6281 ± 0.0598
#   RMSE: 1.9854 ± 0.1590
#   MAE:  1.3963 ± 0.1279
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.5918 ± 0.0355
#   RMSE: 2.0853 ± 0.0979
#   MAE:  1.5220 ± 0.1052
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.5587 ± 0.0412
#   RMSE: 2.1718 ± 0.1633
#   MAE:  1.5216 ± 0.1079
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.5362 ± 0.0730
#   RMSE: 2.2230 ± 0.2222
#   MAE:  1.5564 ± 0.1749
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.4782 ± 0.0250
#   RMSE: 2.3645 ± 0.1665
#   MAE:  1.6921 ± 0.1036
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.4636 ± 0.0463
#   RMSE: 2.3923 ± 0.1419
#   MAE:  1.6731 ± 0.1359
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Fusion
#   R²:   0.4419 ± 0.0248
#   RMSE: 2.4437 ± 0.1472
#   MAE:  1.7758 ± 0.0894
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.4298 ± 0.0690
#   RMSE: 2.4687 ± 0.2269
#   MAE:  1.7578 ± 0.1482
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.4197 ± 0.0386
#   RMSE: 2.4914 ± 0.1638
#   MAE:  1.7968 ± 0.0938
# ----------------------------------------------------------------------------------------------------
# XGBoost              (Base      ) + Fusion
#   R²:   0.4075 ± 0.0172
#   RMSE: 2.5191 ± 0.1584
#   MAE:  1.8324 ± 0.0746
# ----------------------------------------------------------------------------------------------------
#
# ========================================================================================================================
#                           OVERALL TOP 10 BEST MODELS
# ========================================================================================================================
#
# SVR                  (Base      )
#   Noise: Mean Noise, Features: Remote Sensing
#   R²:   0.6486 ± 0.0384
#   RMSE: 1.7736 ± 0.1669
#   MAE:  1.2622 ± 0.1078
#
# SVR                  (Base      )
#   Noise: High Freq, Features: Remote Sensing
#   R²:   0.6281 ± 0.0598
#   RMSE: 1.9854 ± 0.1590
#   MAE:  1.3963 ± 0.1279
#
# SVR                  (Base      )
#   Noise: Mid Freq, Features: Remote Sensing
#   R²:   0.6234 ± 0.0424
#   RMSE: 1.7778 ± 0.1486
#   MAE:  1.2653 ± 0.0695
#
# SVR                  (Base      )
#   Noise: Mean Noise, Features: Fusion
#   R²:   0.5964 ± 0.0453
#   RMSE: 1.9001 ± 0.1792
#   MAE:  1.3843 ± 0.1164
#
# SVR                  (Base      )
#   Noise: Low Freq, Features: Remote Sensing
#   R²:   0.5943 ± 0.0172
#   RMSE: 1.8814 ± 0.0970
#   MAE:  1.3832 ± 0.0713
#
# SVR                  (Base      )
#   Noise: Mid Freq, Features: Fusion
#   R²:   0.5938 ± 0.0419
#   RMSE: 1.8463 ± 0.1493
#   MAE:  1.3282 ± 0.0834
#
# SVR                  (Base      )
#   Noise: High Freq, Features: Fusion
#   R²:   0.5918 ± 0.0355
#   RMSE: 2.0853 ± 0.0979
#   MAE:  1.5220 ± 0.1052
#
# KNN                  (Base      )
#   Noise: Mid Freq, Features: Fusion
#   R²:   0.5620 ± 0.0583
#   RMSE: 1.9178 ± 0.1936
#   MAE:  1.3615 ± 0.1228
#
# KNN                  (Base      )
#   Noise: High Freq, Features: Fusion
#   R²:   0.5587 ± 0.0412
#   RMSE: 2.1718 ± 0.1633
#   MAE:  1.5216 ± 0.1079
#
# KNN                  (Base      )
#   Noise: Mean Noise, Features: Fusion
#   R²:   0.5553 ± 0.0526
#   RMSE: 1.9955 ± 0.2030
#   MAE:  1.3938 ± 0.1397
#
# ========================================================================================================================
#
# ========================================================================================================================
# Results saved to 'comprehensive_kfold_results.csv'
#
# ========================================================================================================================
# SAVING ALL BEST MODELS...
# ========================================================================================================================
#   ✓ Saved: Mean Noise - street - XGBoost
#   ✓ Saved: Mean Noise - street - LightGBM
#   ✓ Saved: Mean Noise - street - Random Forest
#   ✓ Saved: Mean Noise - street - Gradient Boosting
#   ✓ Saved: Mean Noise - street - SVR
#   ✓ Saved: Mean Noise - street - KNN
#   ✓ Saved: Mean Noise - street - Lasso
#   ✓ Saved: Mean Noise - street - Voting
#   ✓ Saved: Mean Noise - street - Stacking
#   ✓ Saved: Mean Noise - remote - XGBoost
#   ✓ Saved: Mean Noise - remote - LightGBM
#   ✓ Saved: Mean Noise - remote - Random Forest
#   ✓ Saved: Mean Noise - remote - Gradient Boosting
#   ✓ Saved: Mean Noise - remote - SVR
#   ✓ Saved: Mean Noise - remote - KNN
#   ✓ Saved: Mean Noise - remote - Lasso
#   ✓ Saved: Mean Noise - remote - Voting
#   ✓ Saved: Mean Noise - remote - Stacking
#   ✓ Saved: Mean Noise - fusion - XGBoost
#   ✓ Saved: Mean Noise - fusion - LightGBM
#   ✓ Saved: Mean Noise - fusion - Random Forest
#   ✓ Saved: Mean Noise - fusion - Gradient Boosting
#   ✓ Saved: Mean Noise - fusion - SVR
#   ✓ Saved: Mean Noise - fusion - KNN
#   ✓ Saved: Mean Noise - fusion - Lasso
#   ✓ Saved: Mean Noise - fusion - Voting
#   ✓ Saved: Mean Noise - fusion - Stacking
#   ✓ Saved: Low Freq - street - XGBoost
#   ✓ Saved: Low Freq - street - LightGBM
#   ✓ Saved: Low Freq - street - Random Forest
#   ✓ Saved: Low Freq - street - Gradient Boosting
#   ✓ Saved: Low Freq - street - SVR
#   ✓ Saved: Low Freq - street - KNN
#   ✓ Saved: Low Freq - street - Lasso
#   ✓ Saved: Low Freq - street - Voting
#   ✓ Saved: Low Freq - street - Stacking
#   ✓ Saved: Low Freq - remote - XGBoost
#   ✓ Saved: Low Freq - remote - LightGBM
#   ✓ Saved: Low Freq - remote - Random Forest
#   ✓ Saved: Low Freq - remote - Gradient Boosting
#   ✓ Saved: Low Freq - remote - SVR
#   ✓ Saved: Low Freq - remote - KNN
#   ✓ Saved: Low Freq - remote - Lasso
#   ✓ Saved: Low Freq - remote - Voting
#   ✓ Saved: Low Freq - remote - Stacking
#   ✓ Saved: Low Freq - fusion - XGBoost
#   ✓ Saved: Low Freq - fusion - LightGBM
#   ✓ Saved: Low Freq - fusion - Random Forest
#   ✓ Saved: Low Freq - fusion - Gradient Boosting
#   ✓ Saved: Low Freq - fusion - SVR
#   ✓ Saved: Low Freq - fusion - KNN
#   ✓ Saved: Low Freq - fusion - Lasso
#   ✓ Saved: Low Freq - fusion - Voting
#   ✓ Saved: Low Freq - fusion - Stacking
#   ✓ Saved: Mid Freq - street - XGBoost
#   ✓ Saved: Mid Freq - street - LightGBM
#   ✓ Saved: Mid Freq - street - Random Forest
#   ✓ Saved: Mid Freq - street - Gradient Boosting
#   ✓ Saved: Mid Freq - street - SVR
#   ✓ Saved: Mid Freq - street - KNN
#   ✓ Saved: Mid Freq - street - Lasso
#   ✓ Saved: Mid Freq - street - Voting
#   ✓ Saved: Mid Freq - street - Stacking
#   ✓ Saved: Mid Freq - remote - XGBoost
#   ✓ Saved: Mid Freq - remote - LightGBM
#   ✓ Saved: Mid Freq - remote - Random Forest
#   ✓ Saved: Mid Freq - remote - Gradient Boosting
#   ✓ Saved: Mid Freq - remote - SVR
#   ✓ Saved: Mid Freq - remote - KNN
#   ✓ Saved: Mid Freq - remote - Lasso
#   ✓ Saved: Mid Freq - remote - Voting
#   ✓ Saved: Mid Freq - remote - Stacking
#   ✓ Saved: Mid Freq - fusion - XGBoost
#   ✓ Saved: Mid Freq - fusion - LightGBM
#   ✓ Saved: Mid Freq - fusion - Random Forest
#   ✓ Saved: Mid Freq - fusion - Gradient Boosting
#   ✓ Saved: Mid Freq - fusion - SVR
#   ✓ Saved: Mid Freq - fusion - KNN
#   ✓ Saved: Mid Freq - fusion - Lasso
#   ✓ Saved: Mid Freq - fusion - Voting
#   ✓ Saved: Mid Freq - fusion - Stacking
#   ✓ Saved: High Freq - street - XGBoost
#   ✓ Saved: High Freq - street - LightGBM
#   ✓ Saved: High Freq - street - Random Forest
#   ✓ Saved: High Freq - street - Gradient Boosting
#   ✓ Saved: High Freq - street - SVR
#   ✓ Saved: High Freq - street - KNN
#   ✓ Saved: High Freq - street - Lasso
#   ✓ Saved: High Freq - street - Voting
#   ✓ Saved: High Freq - street - Stacking
#   ✓ Saved: High Freq - remote - XGBoost
#   ✓ Saved: High Freq - remote - LightGBM
#   ✓ Saved: High Freq - remote - Random Forest
#   ✓ Saved: High Freq - remote - Gradient Boosting
#   ✓ Saved: High Freq - remote - SVR
#   ✓ Saved: High Freq - remote - KNN
#   ✓ Saved: High Freq - remote - Lasso
#   ✓ Saved: High Freq - remote - Voting
#   ✓ Saved: High Freq - remote - Stacking
#   ✓ Saved: High Freq - fusion - XGBoost
#   ✓ Saved: High Freq - fusion - LightGBM
#   ✓ Saved: High Freq - fusion - Random Forest
#   ✓ Saved: High Freq - fusion - Gradient Boosting
#   ✓ Saved: High Freq - fusion - SVR
#   ✓ Saved: High Freq - fusion - KNN
#   ✓ Saved: High Freq - fusion - Lasso
#   ✓ Saved: High Freq - fusion - Voting
#   ✓ Saved: High Freq - fusion - Stacking
#
#   ✓ Saved complete predictor object
#
# ========================================================================================================================
# Successfully saved 108 models to 'saved_models' directory
# ========================================================================================================================
# ========================================================================================================================
#
# ========================================================================================================================
#                            EXPERIMENT COMPLETED SUCCESSFULLY
# ========================================================================================================================
#
# Summary:
# • Total models evaluated: 9 (7 base models + 2 ensemble models)
# • Base models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso
# • Ensemble models: Voting (7 models), Stacking (7 models + Lasso)
# • Feature types: Street View, Remote Sensing, Fusion
# • Noise types: Mean Noise, Low Freq, Mid Freq, High Freq
# • Cross-validation: 5-fold
# • Metrics: R², RMSE, MAE, MSE (all with mean ± std)
# • All models saved to 'saved_models/' directory
#
# Results saved to 'comprehensive_kfold_results.csv'
#
# ========================================================================================================================
# DEMONSTRATION: How to Load and Use Saved Models
# ========================================================================================================================
#
# 1. Loading a single model:
# Loaded model: Mean Noise - fusion - XGBoost
#   R²: 0.4352
#   RMSE: 2.2501
#   MAE: 1.6541
#
# 2. Making predictions with a saved model:
#   predictions = predictor.predict_with_saved_model(
#       X_new=new_data,
#       noise_type='Mean Noise',
#       feature_type='fusion',
#       model_name='XGBoost'
#   )
#
# 3. Loading complete predictor:
#   loaded_predictor = ComprehensiveKFoldNoisePredictor.load_complete_predictor('saved_models')

# %%
# 创建预测器
predictor = ComprehensiveKFoldNoisePredictor()

# 文件路径
street_view_path = './revise_data/features_dinov3-vitb16-pretrain-lvd1689m.npy'
remote_sensing_path = './revise_data/features_dinov3-vitl16-pretrain-sat493m.npy'
noise_labels_path = './revise_data/noise_labels_15_new_2.npy'

try:
    # 加载数据
    print("Loading data...")
    street_features, remote_features, fusion_features, labels = predictor.load_data(
        street_view_path, remote_sensing_path, noise_labels_path
    )
    
    # 准备特征字典
    features_dict = {
        'street': street_features,
        'remote': remote_features,
        'fusion': fusion_features
    }
    
    # 执行K折交叉验证并保存模型
    print("\nStarting comprehensive K-fold cross-validation...")
    results_df = predictor.k_fold_cross_validation_all_models(
        features_dict=features_dict,
        labels=labels,
        k=5,  # 5折交叉验证
        optimize_hyperparams=False,  # 设为True可启用超参数优化（会更慢）
        save_best_models=True  # 自动保存所有最佳模型
    )
    
    print(f"\n{'='*120}")
    print("                           EXPERIMENT COMPLETED SUCCESSFULLY")
    print(f"{'='*120}")
    print("\nSummary:")
    print("• Total models evaluated: 9 (7 base models + 2 ensemble models)")
    print("• Base models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso")
    print("• Ensemble models: Voting (7 models), Stacking (7 models + Lasso)")
    print("• Feature types: Street View, Remote Sensing, Fusion")
    print("• Noise types: Mean Noise, Low Freq, Mid Freq, High Freq")
    print("• Cross-validation: 5-fold")
    print("• Metrics: R², RMSE, MAE, MSE (all with mean ± std)")
    print("• All models saved to 'saved_models/' directory")
    print("\nResults saved to 'comprehensive_kfold_results.csv'")
    
    # ============ 演示如何使用保存的模型 ============
    print(f"\n{'='*120}")
    print("DEMONSTRATION: How to Load and Use Saved Models")
    print(f"{'='*120}")
    
    # 示例1: 加载单个模型
    print("\n1. Loading a single model:")
    try:
        model, preprocessors, info = predictor.load_saved_model(
            noise_type='Mean Noise',
            feature_type='fusion',
            model_name='XGBoost',
            save_dir='saved_models'
        )
    except:
        print("  (Model not found - will be available after training)")
    
    # 示例2: 使用保存的模型进行预测
    print("\n2. Making predictions with a saved model:")
    print("  predictions = predictor.predict_with_saved_model(")
    print("      X_new=new_data,")
    print("      noise_type='Mean Noise',")
    print("      feature_type='fusion',")
    print("      model_name='XGBoost'")
    print("  )")
    
    # 示例3: 加载完整的predictor
    print("\n3. Loading complete predictor:")
    print("  loaded_predictor = ComprehensiveKFoldNoisePredictor.load_complete_predictor('saved_models')")
    
except FileNotFoundError as e:
    print(f"File not found: {e}")
    print("Please ensure the following files exist:")
    print(f"- {street_view_path}")
    print(f"- {remote_sensing_path}")
    print(f"- {noise_labels_path}")
except Exception as e:
    print(f"Error occurred: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Loading data...
# Street view features shape: (923, 768)
# Remote sensing features shape: (923, 1024)
# Noise labels shape: (923, 4)
#
# Starting comprehensive K-fold cross-validation...
#
# ========================================================================================================================
#           K-FOLD CROSS-VALIDATION FOR ALL 8 MODELS + ENSEMBLES (K=5)
# ========================================================================================================================
# Models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso
# Ensembles: Voting (7 models), Stacking (7 models + Lasso)
#
# ====================================================================================================
# NOISE TYPE: Mean Noise
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3044, RMSE=3.1386, MAE=2.5488
#     Fold 2/5: R²=0.2342, RMSE=3.3780, MAE=2.6315
#     Fold 3/5: R²=0.2608, RMSE=3.4966, MAE=2.5975
#     Fold 4/5: R²=0.2835, RMSE=3.3013, MAE=2.5644
#     Fold 5/5: R²=0.2110, RMSE=3.6844, MAE=2.9019
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2588 ± 0.0334
#     RMSE: 3.3998 ± 0.1837
#     MAE:  2.6488 ± 0.1297
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3341, RMSE=3.0709, MAE=2.4988
#     Fold 2/5: R²=0.2581, RMSE=3.3249, MAE=2.5939
#     Fold 3/5: R²=0.2577, RMSE=3.5038, MAE=2.6337
#     Fold 4/5: R²=0.2603, RMSE=3.3542, MAE=2.5557
#     Fold 5/5: R²=0.2350, RMSE=3.6279, MAE=2.8714
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2690 ± 0.0338
#     RMSE: 3.3764 ± 0.1876
#     MAE:  2.6307 ± 0.1283
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2048, RMSE=3.3558, MAE=2.7191
#     Fold 2/5: R²=0.1524, RMSE=3.5540, MAE=2.7739
#     Fold 3/5: R²=0.1883, RMSE=3.6640, MAE=2.7719
#     Fold 4/5: R²=0.1944, RMSE=3.5004, MAE=2.7132
#     Fold 5/5: R²=0.1812, RMSE=3.7532, MAE=2.9267
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1842 ± 0.0177
#     RMSE: 3.5655 ± 0.1366
#     MAE:  2.7809 ± 0.0772
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3035, RMSE=3.1405, MAE=2.5323
#     Fold 2/5: R²=0.2143, RMSE=3.4216, MAE=2.7242
#     Fold 3/5: R²=0.2895, RMSE=3.4279, MAE=2.6244
#     Fold 4/5: R²=0.2584, RMSE=3.3585, MAE=2.5661
#     Fold 5/5: R²=0.2155, RMSE=3.6737, MAE=2.9106
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2563 ± 0.0368
#     RMSE: 3.4044 ± 0.1704
#     MAE:  2.6715 ± 0.1361
#
#   Training SVR...
#     Fold 1/5: R²=0.3857, RMSE=2.9494, MAE=2.4028
#     Fold 2/5: R²=0.3100, RMSE=3.2065, MAE=2.4980
#     Fold 3/5: R²=0.2985, RMSE=3.4063, MAE=2.6064
#     Fold 4/5: R²=0.3413, RMSE=3.1653, MAE=2.4309
#     Fold 5/5: R²=0.2606, RMSE=3.5666, MAE=2.7715
#
#   SVR 5-Fold CV Results:
#     R²:   0.3192 ± 0.0421
#     RMSE: 3.2588 ± 0.2115
#     MAE:  2.5419 ± 0.1345
#
#   Training KNN...
#     Fold 1/5: R²=0.3699, RMSE=2.9872, MAE=2.4291
#     Fold 2/5: R²=0.3246, RMSE=3.1725, MAE=2.4304
#     Fold 3/5: R²=0.3212, RMSE=3.3505, MAE=2.5399
#     Fold 4/5: R²=0.3166, RMSE=3.2241, MAE=2.4868
#     Fold 5/5: R²=0.1997, RMSE=3.7107, MAE=2.8009
#
#   KNN 5-Fold CV Results:
#     R²:   0.3064 ± 0.0567
#     RMSE: 3.2890 ± 0.2410
#     MAE:  2.5374 ± 0.1380
#
#   Training Lasso...
#     Fold 1/5: R²=0.3039, RMSE=3.1397, MAE=2.5543
#     Fold 2/5: R²=0.2151, RMSE=3.4200, MAE=2.7372
#     Fold 3/5: R²=0.2477, RMSE=3.5275, MAE=2.6735
#     Fold 4/5: R²=0.2740, RMSE=3.3230, MAE=2.6115
#     Fold 5/5: R²=0.2482, RMSE=3.5965, MAE=2.8589
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2578 ± 0.0297
#     RMSE: 3.4014 ± 0.1606
#     MAE:  2.6871 ± 0.1054
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3803, RMSE=2.9624, MAE=2.3952
#     Fold 2/5: R²=0.3013, RMSE=3.2267, MAE=2.5426
#     Fold 3/5: R²=0.3204, RMSE=3.3526, MAE=2.5332
#     Fold 4/5: R²=0.3396, RMSE=3.1693, MAE=2.4460
#     Fold 5/5: R²=0.2741, RMSE=3.5340, MAE=2.7656
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3231 ± 0.0359
#     RMSE: 3.2490 ± 0.1902
#     MAE:  2.5365 ± 0.1271
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3122, RMSE=3.1208, MAE=2.5401
#     Fold 2/5: R²=0.2388, RMSE=3.3679, MAE=2.6804
#     Fold 3/5: R²=0.2548, RMSE=3.5107, MAE=2.6329
#     Fold 4/5: R²=0.3235, RMSE=3.2076, MAE=2.5175
#     Fold 5/5: R²=0.2364, RMSE=3.6246, MAE=2.8260
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2732 ± 0.0372
#     RMSE: 3.3663 ± 0.1860
#     MAE:  2.6394 ± 0.1107
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2253, RMSE=3.3122, MAE=2.6818
#     Fold 2/5: R²=0.1606, RMSE=3.5367, MAE=2.6991
#     Fold 3/5: R²=0.2638, RMSE=3.4894, MAE=2.6475
#     Fold 4/5: R²=0.2136, RMSE=3.4585, MAE=2.7439
#     Fold 5/5: R²=0.2509, RMSE=3.5900, MAE=2.8171
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2228 ± 0.0359
#     RMSE: 3.4774 ± 0.0938
#     MAE:  2.7179 ± 0.0585
#
#   Training LightGBM...
#     Fold 1/5: R²=0.1956, RMSE=3.3752, MAE=2.7482
#     Fold 2/5: R²=0.1345, RMSE=3.5912, MAE=2.7568
#     Fold 3/5: R²=0.2997, RMSE=3.4033, MAE=2.6229
#     Fold 4/5: R²=0.2275, RMSE=3.4277, MAE=2.7055
#     Fold 5/5: R²=0.3148, RMSE=3.4335, MAE=2.6705
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2344 ± 0.0667
#     RMSE: 3.4462 ± 0.0754
#     MAE:  2.7008 ± 0.0498
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1866, RMSE=3.3939, MAE=2.7842
#     Fold 2/5: R²=0.1563, RMSE=3.5457, MAE=2.7490
#     Fold 3/5: R²=0.2095, RMSE=3.6157, MAE=2.7310
#     Fold 4/5: R²=0.1640, RMSE=3.5659, MAE=2.8157
#     Fold 5/5: R²=0.1651, RMSE=3.7901, MAE=2.9736
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1763 ± 0.0194
#     RMSE: 3.5823 ± 0.1276
#     MAE:  2.8107 ± 0.0865
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2095, RMSE=3.3457, MAE=2.7041
#     Fold 2/5: R²=0.1468, RMSE=3.5655, MAE=2.7634
#     Fold 3/5: R²=0.2766, RMSE=3.4590, MAE=2.6615
#     Fold 4/5: R²=0.1874, RMSE=3.5157, MAE=2.7736
#     Fold 5/5: R²=0.2845, RMSE=3.5086, MAE=2.7401
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2210 ± 0.0527
#     RMSE: 3.4789 ± 0.0747
#     MAE:  2.7285 ± 0.0412
#
#   Training SVR...
#     Fold 1/5: R²=0.2165, RMSE=3.3310, MAE=2.6299
#     Fold 2/5: R²=0.2461, RMSE=3.3517, MAE=2.5693
#     Fold 3/5: R²=0.3148, RMSE=3.3663, MAE=2.4969
#     Fold 4/5: R²=0.3112, RMSE=3.2368, MAE=2.4662
#     Fold 5/5: R²=0.3265, RMSE=3.4041, MAE=2.6880
#
#   SVR 5-Fold CV Results:
#     R²:   0.2830 ± 0.0435
#     RMSE: 3.3380 ± 0.0559
#     MAE:  2.5701 ± 0.0820
#
#   Training KNN...
#     Fold 1/5: R²=0.2795, RMSE=3.1941, MAE=2.5570
#     Fold 2/5: R²=0.2510, RMSE=3.3407, MAE=2.5577
#     Fold 3/5: R²=0.2502, RMSE=3.5215, MAE=2.6964
#     Fold 4/5: R²=0.3168, RMSE=3.2237, MAE=2.4462
#     Fold 5/5: R²=0.2407, RMSE=3.6142, MAE=2.8175
#
#   KNN 5-Fold CV Results:
#     R²:   0.2677 ± 0.0278
#     RMSE: 3.3789 ± 0.1646
#     MAE:  2.6149 ± 0.1287
#
#   Training Lasso...
#     Fold 1/5: R²=0.2127, RMSE=3.3391, MAE=2.6731
#     Fold 2/5: R²=0.1696, RMSE=3.5176, MAE=2.7357
#     Fold 3/5: R²=0.2099, RMSE=3.6149, MAE=2.7067
#     Fold 4/5: R²=0.1906, RMSE=3.5086, MAE=2.7543
#     Fold 5/5: R²=0.2253, RMSE=3.6508, MAE=2.7874
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2016 ± 0.0195
#     RMSE: 3.5262 ± 0.1084
#     MAE:  2.7314 ± 0.0392
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.2814, RMSE=3.1900, MAE=2.5753
#     Fold 2/5: R²=0.2406, RMSE=3.3638, MAE=2.5845
#     Fold 3/5: R²=0.3263, RMSE=3.3381, MAE=2.5181
#     Fold 4/5: R²=0.2919, RMSE=3.2819, MAE=2.5643
#     Fold 5/5: R²=0.3133, RMSE=3.4372, MAE=2.6625
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.2907 ± 0.0296
#     RMSE: 3.3222 ± 0.0828
#     MAE:  2.5809 ± 0.0467
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1479, RMSE=3.4738, MAE=2.8448
#     Fold 2/5: R²=0.1599, RMSE=3.5380, MAE=2.7489
#     Fold 3/5: R²=0.0976, RMSE=3.8632, MAE=2.9148
#     Fold 4/5: R²=0.1761, RMSE=3.5400, MAE=2.8055
#     Fold 5/5: R²=0.1502, RMSE=3.8236, MAE=2.9756
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1464 ± 0.0263
#     RMSE: 3.6477 ± 0.1620
#     MAE:  2.8579 ± 0.0798
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3123, RMSE=3.1206, MAE=2.5033
#     Fold 2/5: R²=0.2583, RMSE=3.3246, MAE=2.5423
#     Fold 3/5: R²=0.2584, RMSE=3.5023, MAE=2.6518
#     Fold 4/5: R²=0.2730, RMSE=3.3253, MAE=2.5642
#     Fold 5/5: R²=0.2657, RMSE=3.5544, MAE=2.7890
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2735 ± 0.0201
#     RMSE: 3.3654 ± 0.1534
#     MAE:  2.6101 ± 0.1019
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2970, RMSE=3.1551, MAE=2.5766
#     Fold 2/5: R²=0.2469, RMSE=3.3500, MAE=2.6145
#     Fold 3/5: R²=0.2832, RMSE=3.4431, MAE=2.6470
#     Fold 4/5: R²=0.3226, RMSE=3.2099, MAE=2.4803
#     Fold 5/5: R²=0.2476, RMSE=3.5979, MAE=2.7927
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2795 ± 0.0292
#     RMSE: 3.3512 ± 0.1598
#     MAE:  2.6222 ± 0.1019
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1900, RMSE=3.3867, MAE=2.7624
#     Fold 2/5: R²=0.1794, RMSE=3.4967, MAE=2.7238
#     Fold 3/5: R²=0.1766, RMSE=3.6904, MAE=2.8211
#     Fold 4/5: R²=0.1808, RMSE=3.5299, MAE=2.7299
#     Fold 5/5: R²=0.1771, RMSE=3.7627, MAE=2.9315
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1808 ± 0.0049
#     RMSE: 3.5733 ± 0.1358
#     MAE:  2.7937 ± 0.0770
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.3214, RMSE=3.0999, MAE=2.4752
#     Fold 2/5: R²=0.2505, RMSE=3.3418, MAE=2.5943
#     Fold 3/5: R²=0.2905, RMSE=3.4255, MAE=2.5900
#     Fold 4/5: R²=0.2603, RMSE=3.3542, MAE=2.5922
#     Fold 5/5: R²=0.2603, RMSE=3.5673, MAE=2.7812
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2766 ± 0.0261
#     RMSE: 3.3578 ± 0.1518
#     MAE:  2.6066 ± 0.0983
#
#   Training SVR...
#     Fold 1/5: R²=0.3819, RMSE=2.9586, MAE=2.3190
#     Fold 2/5: R²=0.2916, RMSE=3.2491, MAE=2.5103
#     Fold 3/5: R²=0.3269, RMSE=3.3367, MAE=2.5259
#     Fold 4/5: R²=0.4177, RMSE=2.9760, MAE=2.2161
#     Fold 5/5: R²=0.3480, RMSE=3.3494, MAE=2.5251
#
#   SVR 5-Fold CV Results:
#     R²:   0.3532 ± 0.0436
#     RMSE: 3.1739 ± 0.1723
#     MAE:  2.4193 ± 0.1282
#
#   Training KNN...
#     Fold 1/5: R²=0.4247, RMSE=2.8542, MAE=2.3570
#     Fold 2/5: R²=0.3893, RMSE=3.0166, MAE=2.2395
#     Fold 3/5: R²=0.2475, RMSE=3.5280, MAE=2.5736
#     Fold 4/5: R²=0.4295, RMSE=2.9456, MAE=2.2543
#     Fold 5/5: R²=0.2619, RMSE=3.5636, MAE=2.7143
#
#   KNN 5-Fold CV Results:
#     R²:   0.3506 ± 0.0797
#     RMSE: 3.1816 ± 0.3020
#     MAE:  2.4277 ± 0.1865
#
#   Training Lasso...
#     Fold 1/5: R²=0.3061, RMSE=3.1348, MAE=2.4821
#     Fold 2/5: R²=0.2219, RMSE=3.4051, MAE=2.6969
#     Fold 3/5: R²=0.3077, RMSE=3.3838, MAE=2.5317
#     Fold 4/5: R²=0.2853, RMSE=3.2970, MAE=2.6061
#     Fold 5/5: R²=0.2575, RMSE=3.5741, MAE=2.7899
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2757 ± 0.0325
#     RMSE: 3.3590 ± 0.1436
#     MAE:  2.6213 ± 0.1111
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3829, RMSE=2.9561, MAE=2.3863
#     Fold 2/5: R²=0.3165, RMSE=3.1914, MAE=2.4627
#     Fold 3/5: R²=0.3266, RMSE=3.3372, MAE=2.4994
#     Fold 4/5: R²=0.3690, RMSE=3.0981, MAE=2.3682
#     Fold 5/5: R²=0.3113, RMSE=3.4422, MAE=2.6706
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3413 ± 0.0291
#     RMSE: 3.2050 ± 0.1717
#     MAE:  2.4774 ± 0.1079
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3429, RMSE=3.0504, MAE=2.4690
#     Fold 2/5: R²=0.2010, RMSE=3.4506, MAE=2.7410
#     Fold 3/5: R²=0.2304, RMSE=3.5677, MAE=2.6849
#     Fold 4/5: R²=0.3187, RMSE=3.2191, MAE=2.4926
#     Fold 5/5: R²=0.2419, RMSE=3.6115, MAE=2.8143
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2670 ± 0.0544
#     RMSE: 3.3798 ± 0.2137
#     MAE:  2.6404 ± 0.1368
#
# ====================================================================================================
# NOISE TYPE: Low Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.1962, RMSE=3.3301, MAE=2.5346
#     Fold 2/5: R²=0.2084, RMSE=3.6337, MAE=2.9386
#     Fold 3/5: R²=0.2147, RMSE=3.5974, MAE=2.7546
#     Fold 4/5: R²=0.1995, RMSE=3.4086, MAE=2.7069
#     Fold 5/5: R²=0.1760, RMSE=3.5984, MAE=2.8648
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.1990 ± 0.0132
#     RMSE: 3.5136 ± 0.1211
#     MAE:  2.7599 ± 0.1390
#
#   Training LightGBM...
#     Fold 1/5: R²=0.1844, RMSE=3.3544, MAE=2.5627
#     Fold 2/5: R²=0.1980, RMSE=3.6574, MAE=2.9674
#     Fold 3/5: R²=0.2336, RMSE=3.5539, MAE=2.7685
#     Fold 4/5: R²=0.2381, RMSE=3.3255, MAE=2.6524
#     Fold 5/5: R²=0.1763, RMSE=3.5976, MAE=2.8927
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2061 ± 0.0253
#     RMSE: 3.4978 ± 0.1333
#     MAE:  2.7688 ± 0.1489
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1448, RMSE=3.4349, MAE=2.6983
#     Fold 2/5: R²=0.1154, RMSE=3.8411, MAE=3.0964
#     Fold 3/5: R²=0.1285, RMSE=3.7897, MAE=2.8785
#     Fold 4/5: R²=0.1405, RMSE=3.5320, MAE=2.8299
#     Fold 5/5: R²=0.0961, RMSE=3.7687, MAE=2.9674
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1251 ± 0.0177
#     RMSE: 3.6733 ± 0.1598
#     MAE:  2.8941 ± 0.1334
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.1893, RMSE=3.3443, MAE=2.5748
#     Fold 2/5: R²=0.2137, RMSE=3.6215, MAE=2.9558
#     Fold 3/5: R²=0.2102, RMSE=3.6077, MAE=2.7643
#     Fold 4/5: R²=0.2208, RMSE=3.3630, MAE=2.6664
#     Fold 5/5: R²=0.1303, RMSE=3.6967, MAE=2.9180
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.1929 ± 0.0330
#     RMSE: 3.5267 ± 0.1446
#     MAE:  2.7758 ± 0.1450
#
#   Training SVR...
#     Fold 1/5: R²=0.2361, RMSE=3.2465, MAE=2.4876
#     Fold 2/5: R²=0.2931, RMSE=3.4336, MAE=2.7218
#     Fold 3/5: R²=0.3544, RMSE=3.2620, MAE=2.4513
#     Fold 4/5: R²=0.3636, RMSE=3.0392, MAE=2.2894
#     Fold 5/5: R²=0.2528, RMSE=3.4264, MAE=2.6681
#
#   SVR 5-Fold CV Results:
#     R²:   0.3000 ± 0.0517
#     RMSE: 3.2815 ± 0.1445
#     MAE:  2.5236 ± 0.1559
#
#   Training KNN...
#     Fold 1/5: R²=0.2206, RMSE=3.2792, MAE=2.4487
#     Fold 2/5: R²=0.3267, RMSE=3.3512, MAE=2.5895
#     Fold 3/5: R²=0.3391, RMSE=3.3002, MAE=2.5170
#     Fold 4/5: R²=0.3813, RMSE=2.9967, MAE=2.3487
#     Fold 5/5: R²=0.2213, RMSE=3.4980, MAE=2.6361
#
#   KNN 5-Fold CV Results:
#     R²:   0.2978 ± 0.0653
#     RMSE: 3.2851 ± 0.1632
#     MAE:  2.5080 ± 0.1020
#
#   Training Lasso...
#     Fold 1/5: R²=0.1737, RMSE=3.3764, MAE=2.6270
#     Fold 2/5: R²=0.2041, RMSE=3.6434, MAE=2.9466
#     Fold 3/5: R²=0.2159, RMSE=3.5946, MAE=2.6939
#     Fold 4/5: R²=0.1385, RMSE=3.5362, MAE=2.8107
#     Fold 5/5: R²=0.1372, RMSE=3.6820, MAE=2.9947
#
#   Lasso 5-Fold CV Results:
#     R²:   0.1739 ± 0.0325
#     RMSE: 3.5665 ± 0.1069
#     MAE:  2.8146 ± 0.1412
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.2671, RMSE=3.1798, MAE=2.4197
#     Fold 2/5: R²=0.2847, RMSE=3.4540, MAE=2.7848
#     Fold 3/5: R²=0.3021, RMSE=3.3913, MAE=2.5359
#     Fold 4/5: R²=0.3159, RMSE=3.1511, MAE=2.5032
#     Fold 5/5: R²=0.2282, RMSE=3.4825, MAE=2.7677
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.2796 ± 0.0305
#     RMSE: 3.3317 ± 0.1393
#     MAE:  2.6023 ± 0.1471
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2016, RMSE=3.3190, MAE=2.6032
#     Fold 2/5: R²=0.2371, RMSE=3.5672, MAE=2.8228
#     Fold 3/5: R²=0.1463, RMSE=3.7508, MAE=2.8551
#     Fold 4/5: R²=0.2204, RMSE=3.3638, MAE=2.6869
#     Fold 5/5: R²=0.1133, RMSE=3.7327, MAE=2.9837
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1837 ± 0.0466
#     RMSE: 3.5467 ± 0.1800
#     MAE:  2.7904 ± 0.1329
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2459, RMSE=3.2254, MAE=2.4922
#     Fold 2/5: R²=0.3300, RMSE=3.3430, MAE=2.6559
#     Fold 3/5: R²=0.1992, RMSE=3.6328, MAE=2.7148
#     Fold 4/5: R²=0.2047, RMSE=3.3975, MAE=2.7528
#     Fold 5/5: R²=0.2065, RMSE=3.5311, MAE=2.8733
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2373 ± 0.0492
#     RMSE: 3.4259 ± 0.1427
#     MAE:  2.6978 ± 0.1250
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2360, RMSE=3.2466, MAE=2.5222
#     Fold 2/5: R²=0.3185, RMSE=3.3715, MAE=2.6921
#     Fold 3/5: R²=0.1701, RMSE=3.6983, MAE=2.7331
#     Fold 4/5: R²=0.2216, RMSE=3.3613, MAE=2.7078
#     Fold 5/5: R²=0.2484, RMSE=3.4365, MAE=2.7695
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2389 ± 0.0479
#     RMSE: 3.4228 ± 0.1507
#     MAE:  2.6849 ± 0.0855
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1796, RMSE=3.3644, MAE=2.6571
#     Fold 2/5: R²=0.1771, RMSE=3.7047, MAE=2.9167
#     Fold 3/5: R²=0.1148, RMSE=3.8195, MAE=2.8980
#     Fold 4/5: R²=0.1430, RMSE=3.5268, MAE=2.8178
#     Fold 5/5: R²=0.1506, RMSE=3.6533, MAE=2.9359
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1530 ± 0.0239
#     RMSE: 3.6137 ± 0.1561
#     MAE:  2.8451 ± 0.1022
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2266, RMSE=3.2665, MAE=2.4894
#     Fold 2/5: R²=0.3146, RMSE=3.3811, MAE=2.6901
#     Fold 3/5: R²=0.2070, RMSE=3.6151, MAE=2.7407
#     Fold 4/5: R²=0.2327, RMSE=3.3373, MAE=2.6916
#     Fold 5/5: R²=0.1726, RMSE=3.6057, MAE=2.9144
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2307 ± 0.0469
#     RMSE: 3.4411 ± 0.1430
#     MAE:  2.7053 ± 0.1356
#
#   Training SVR...
#     Fold 1/5: R²=0.3183, RMSE=3.0667, MAE=2.3141
#     Fold 2/5: R²=0.3706, RMSE=3.2399, MAE=2.5872
#     Fold 3/5: R²=0.2620, RMSE=3.4876, MAE=2.5427
#     Fold 4/5: R²=0.2622, RMSE=3.2725, MAE=2.5861
#     Fold 5/5: R²=0.3752, RMSE=3.1332, MAE=2.5087
#
#   SVR 5-Fold CV Results:
#     R²:   0.3177 ± 0.0496
#     RMSE: 3.2400 ± 0.1441
#     MAE:  2.5078 ± 0.1012
#
#   Training KNN...
#     Fold 1/5: R²=0.2344, RMSE=3.2500, MAE=2.4560
#     Fold 2/5: R²=0.3675, RMSE=3.2480, MAE=2.5923
#     Fold 3/5: R²=0.2503, RMSE=3.5150, MAE=2.6069
#     Fold 4/5: R²=0.2005, RMSE=3.4066, MAE=2.6354
#     Fold 5/5: R²=0.2686, RMSE=3.3901, MAE=2.6382
#
#   KNN 5-Fold CV Results:
#     R²:   0.2643 ± 0.0563
#     RMSE: 3.3619 ± 0.1017
#     MAE:  2.5858 ± 0.0671
#
#   Training Lasso...
#     Fold 1/5: R²=0.2255, RMSE=3.2688, MAE=2.5586
#     Fold 2/5: R²=0.2326, RMSE=3.5776, MAE=2.8108
#     Fold 3/5: R²=0.0839, RMSE=3.8856, MAE=3.0015
#     Fold 4/5: R²=0.1082, RMSE=3.5977, MAE=2.8872
#     Fold 5/5: R²=0.1574, RMSE=3.6386, MAE=2.8622
#
#   Lasso 5-Fold CV Results:
#     R²:   0.1615 ± 0.0601
#     RMSE: 3.5937 ± 0.1965
#     MAE:  2.8241 ± 0.1467
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3200, RMSE=3.0628, MAE=2.3510
#     Fold 2/5: R²=0.3632, RMSE=3.2591, MAE=2.5799
#     Fold 3/5: R²=0.2378, RMSE=3.5442, MAE=2.6235
#     Fold 4/5: R²=0.2657, RMSE=3.2647, MAE=2.6052
#     Fold 5/5: R²=0.2847, RMSE=3.3524, MAE=2.6834
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.2943 ± 0.0436
#     RMSE: 3.2966 ± 0.1559
#     MAE:  2.5686 ± 0.1140
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1544, RMSE=3.4155, MAE=2.7244
#     Fold 2/5: R²=0.1972, RMSE=3.6591, MAE=2.9087
#     Fold 3/5: R²=0.0481, RMSE=3.9607, MAE=3.0363
#     Fold 4/5: R²=0.1371, RMSE=3.5390, MAE=2.8223
#     Fold 5/5: R²=0.0673, RMSE=3.8283, MAE=3.0897
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1208 ± 0.0555
#     RMSE: 3.6805 ± 0.1955
#     MAE:  2.9163 ± 0.1343
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2606, RMSE=3.1938, MAE=2.4384
#     Fold 2/5: R²=0.2681, RMSE=3.4938, MAE=2.7958
#     Fold 3/5: R²=0.2776, RMSE=3.4504, MAE=2.6820
#     Fold 4/5: R²=0.1418, RMSE=3.5293, MAE=2.6845
#     Fold 5/5: R²=0.1242, RMSE=3.7097, MAE=2.9533
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2145 ± 0.0670
#     RMSE: 3.4754 ± 0.1662
#     MAE:  2.7108 ± 0.1684
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2517, RMSE=3.2130, MAE=2.5086
#     Fold 2/5: R²=0.2371, RMSE=3.5671, MAE=2.8393
#     Fold 3/5: R²=0.2970, RMSE=3.4038, MAE=2.6614
#     Fold 4/5: R²=0.1545, RMSE=3.5032, MAE=2.6670
#     Fold 5/5: R²=0.1046, RMSE=3.7509, MAE=2.9715
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2090 ± 0.0696
#     RMSE: 3.4876 ± 0.1779
#     MAE:  2.7296 ± 0.1600
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1835, RMSE=3.3563, MAE=2.6587
#     Fold 2/5: R²=0.1715, RMSE=3.7173, MAE=2.9832
#     Fold 3/5: R²=0.1834, RMSE=3.6685, MAE=2.8122
#     Fold 4/5: R²=0.1184, RMSE=3.5772, MAE=2.8376
#     Fold 5/5: R²=0.0925, RMSE=3.7761, MAE=3.0230
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1499 ± 0.0374
#     RMSE: 3.6191 ± 0.1467
#     MAE:  2.8629 ± 0.1304
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2632, RMSE=3.1882, MAE=2.4508
#     Fold 2/5: R²=0.2712, RMSE=3.4865, MAE=2.7572
#     Fold 3/5: R²=0.2921, RMSE=3.4157, MAE=2.6384
#     Fold 4/5: R²=0.0992, RMSE=3.6159, MAE=2.7835
#     Fold 5/5: R²=0.0885, RMSE=3.7844, MAE=2.9981
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2029 ± 0.0895
#     RMSE: 3.4981 ± 0.1994
#     MAE:  2.7256 ± 0.1799
#
#   Training SVR...
#     Fold 1/5: R²=0.3509, RMSE=2.9926, MAE=2.3201
#     Fold 2/5: R²=0.3609, RMSE=3.2649, MAE=2.6233
#     Fold 3/5: R²=0.3993, RMSE=3.1463, MAE=2.4670
#     Fold 4/5: R²=0.3066, RMSE=3.1725, MAE=2.3824
#     Fold 5/5: R²=0.3138, RMSE=3.2836, MAE=2.5204
#
#   SVR 5-Fold CV Results:
#     R²:   0.3463 ± 0.0337
#     RMSE: 3.1720 ± 0.1039
#     MAE:  2.4626 ± 0.1058
#
#   Training KNN...
#     Fold 1/5: R²=0.3189, RMSE=3.0655, MAE=2.3037
#     Fold 2/5: R²=0.4276, RMSE=3.0898, MAE=2.4292
#     Fold 3/5: R²=0.3953, RMSE=3.1568, MAE=2.4556
#     Fold 4/5: R²=0.3682, RMSE=3.0283, MAE=2.3482
#     Fold 5/5: R²=0.3092, RMSE=3.2946, MAE=2.5161
#
#   KNN 5-Fold CV Results:
#     R²:   0.3638 ± 0.0449
#     RMSE: 3.1270 ± 0.0937
#     MAE:  2.4106 ± 0.0759
#
#   Training Lasso...
#     Fold 1/5: R²=0.2284, RMSE=3.2627, MAE=2.5544
#     Fold 2/5: R²=0.2859, RMSE=3.4513, MAE=2.7607
#     Fold 3/5: R²=0.1650, RMSE=3.7096, MAE=2.8351
#     Fold 4/5: R²=0.1544, RMSE=3.5034, MAE=2.7225
#     Fold 5/5: R²=0.1203, RMSE=3.7179, MAE=3.0023
#
#   Lasso 5-Fold CV Results:
#     R²:   0.1908 ± 0.0590
#     RMSE: 3.5290 ± 0.1708
#     MAE:  2.7750 ± 0.1462
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3455, RMSE=3.0050, MAE=2.3235
#     Fold 2/5: R²=0.3434, RMSE=3.3092, MAE=2.6548
#     Fold 3/5: R²=0.3420, RMSE=3.2930, MAE=2.5460
#     Fold 4/5: R²=0.2613, RMSE=3.2745, MAE=2.4941
#     Fold 5/5: R²=0.2270, RMSE=3.4852, MAE=2.7552
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3038 ± 0.0500
#     RMSE: 3.2734 ± 0.1540
#     MAE:  2.5547 ± 0.1466
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2565, RMSE=3.2027, MAE=2.5201
#     Fold 2/5: R²=0.2722, RMSE=3.4842, MAE=2.7903
#     Fold 3/5: R²=0.1373, RMSE=3.7707, MAE=2.8871
#     Fold 4/5: R²=0.1518, RMSE=3.5088, MAE=2.7624
#     Fold 5/5: R²=0.1850, RMSE=3.5786, MAE=2.8475
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2005 ± 0.0546
#     RMSE: 3.5090 ± 0.1832
#     MAE:  2.7615 ± 0.1283
#
# ====================================================================================================
# NOISE TYPE: Mid Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2991, RMSE=2.9991, MAE=2.3672
#     Fold 2/5: R²=0.2087, RMSE=3.3743, MAE=2.6784
#     Fold 3/5: R²=0.2421, RMSE=3.4626, MAE=2.6714
#     Fold 4/5: R²=0.2227, RMSE=3.3094, MAE=2.6423
#     Fold 5/5: R²=0.1684, RMSE=3.6515, MAE=2.8975
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2282 ± 0.0429
#     RMSE: 3.3594 ± 0.2138
#     MAE:  2.6514 ± 0.1688
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2747, RMSE=3.0509, MAE=2.4335
#     Fold 2/5: R²=0.2262, RMSE=3.3368, MAE=2.6292
#     Fold 3/5: R²=0.2395, RMSE=3.4685, MAE=2.7273
#     Fold 4/5: R²=0.2184, RMSE=3.3185, MAE=2.6402
#     Fold 5/5: R²=0.1421, RMSE=3.7087, MAE=2.9380
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2202 ± 0.0435
#     RMSE: 3.3767 ± 0.2144
#     MAE:  2.6737 ± 0.1634
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2220, RMSE=3.1597, MAE=2.5432
#     Fold 2/5: R²=0.1319, RMSE=3.5344, MAE=2.8169
#     Fold 3/5: R²=0.1564, RMSE=3.6532, MAE=2.7674
#     Fold 4/5: R²=0.1655, RMSE=3.4290, MAE=2.7309
#     Fold 5/5: R²=0.1450, RMSE=3.7024, MAE=2.9395
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1642 ± 0.0310
#     RMSE: 3.4957 ± 0.1931
#     MAE:  2.7596 ± 0.1291
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2901, RMSE=3.0182, MAE=2.4010
#     Fold 2/5: R²=0.1744, RMSE=3.4468, MAE=2.7179
#     Fold 3/5: R²=0.2381, RMSE=3.4719, MAE=2.7205
#     Fold 4/5: R²=0.2374, RMSE=3.2780, MAE=2.6291
#     Fold 5/5: R²=0.1171, RMSE=3.7624, MAE=3.0030
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2114 ± 0.0597
#     RMSE: 3.3955 ± 0.2447
#     MAE:  2.6943 ± 0.1933
#
#   Training SVR...
#     Fold 1/5: R²=0.3255, RMSE=2.9420, MAE=2.3199
#     Fold 2/5: R²=0.2937, RMSE=3.1881, MAE=2.5247
#     Fold 3/5: R²=0.3251, RMSE=3.2676, MAE=2.4581
#     Fold 4/5: R²=0.3188, RMSE=3.0981, MAE=2.3537
#     Fold 5/5: R²=0.2758, RMSE=3.4074, MAE=2.6613
#
#   SVR 5-Fold CV Results:
#     R²:   0.3078 ± 0.0198
#     RMSE: 3.1806 ± 0.1567
#     MAE:  2.4635 ± 0.1229
#
#   Training KNN...
#     Fold 1/5: R²=0.3576, RMSE=2.8712, MAE=2.3304
#     Fold 2/5: R²=0.3429, RMSE=3.0750, MAE=2.3324
#     Fold 3/5: R²=0.3377, RMSE=3.2370, MAE=2.4179
#     Fold 4/5: R²=0.3281, RMSE=3.0769, MAE=2.3983
#     Fold 5/5: R²=0.2789, RMSE=3.4002, MAE=2.6038
#
#   KNN 5-Fold CV Results:
#     R²:   0.3290 ± 0.0268
#     RMSE: 3.1321 ± 0.1773
#     MAE:  2.4165 ± 0.0999
#
#   Training Lasso...
#     Fold 1/5: R²=0.2604, RMSE=3.0808, MAE=2.4155
#     Fold 2/5: R²=0.1835, RMSE=3.4278, MAE=2.7420
#     Fold 3/5: R²=0.2475, RMSE=3.4504, MAE=2.5896
#     Fold 4/5: R²=0.1886, RMSE=3.3812, MAE=2.7157
#     Fold 5/5: R²=0.2301, RMSE=3.5134, MAE=2.8316
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2220 ± 0.0310
#     RMSE: 3.3707 ± 0.1511
#     MAE:  2.6589 ± 0.1442
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3537, RMSE=2.8798, MAE=2.2811
#     Fold 2/5: R²=0.2809, RMSE=3.2168, MAE=2.5389
#     Fold 3/5: R²=0.3123, RMSE=3.2984, MAE=2.5319
#     Fold 4/5: R²=0.3087, RMSE=3.1209, MAE=2.4621
#     Fold 5/5: R²=0.2481, RMSE=3.4721, MAE=2.7494
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3007 ± 0.0351
#     RMSE: 3.1976 ± 0.1963
#     MAE:  2.5127 ± 0.1505
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.2909, RMSE=3.0165, MAE=2.4068
#     Fold 2/5: R²=0.2296, RMSE=3.3294, MAE=2.6336
#     Fold 3/5: R²=0.2181, RMSE=3.5171, MAE=2.6232
#     Fold 4/5: R²=0.2661, RMSE=3.2158, MAE=2.5712
#     Fold 5/5: R²=0.2190, RMSE=3.5386, MAE=2.7884
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2447 ± 0.0289
#     RMSE: 3.3235 ± 0.1948
#     MAE:  2.6046 ± 0.1226
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2325, RMSE=3.1384, MAE=2.4982
#     Fold 2/5: R²=0.2238, RMSE=3.3420, MAE=2.5238
#     Fold 3/5: R²=0.2004, RMSE=3.5568, MAE=2.6372
#     Fold 4/5: R²=0.2185, RMSE=3.3184, MAE=2.6048
#     Fold 5/5: R²=0.1849, RMSE=3.6151, MAE=2.8130
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2120 ± 0.0172
#     RMSE: 3.3941 ± 0.1727
#     MAE:  2.6154 ± 0.1111
#
#   Training LightGBM...
#     Fold 1/5: R²=0.1805, RMSE=3.2429, MAE=2.5332
#     Fold 2/5: R²=0.1904, RMSE=3.4131, MAE=2.5583
#     Fold 3/5: R²=0.2441, RMSE=3.4582, MAE=2.6121
#     Fold 4/5: R²=0.1683, RMSE=3.4233, MAE=2.6774
#     Fold 5/5: R²=0.2365, RMSE=3.4988, MAE=2.7291
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2039 ± 0.0306
#     RMSE: 3.4073 ± 0.0875
#     MAE:  2.6220 ± 0.0729
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1675, RMSE=3.2685, MAE=2.6579
#     Fold 2/5: R²=0.1600, RMSE=3.4767, MAE=2.6889
#     Fold 3/5: R²=0.1407, RMSE=3.6871, MAE=2.7664
#     Fold 4/5: R²=0.1404, RMSE=3.4803, MAE=2.7699
#     Fold 5/5: R²=0.1678, RMSE=3.6529, MAE=2.8594
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1553 ± 0.0123
#     RMSE: 3.5131 ± 0.1497
#     MAE:  2.7485 ± 0.0705
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2024, RMSE=3.1993, MAE=2.5415
#     Fold 2/5: R²=0.2445, RMSE=3.2971, MAE=2.5263
#     Fold 3/5: R²=0.1528, RMSE=3.6610, MAE=2.7180
#     Fold 4/5: R²=0.1933, RMSE=3.3714, MAE=2.6442
#     Fold 5/5: R²=0.1618, RMSE=3.6659, MAE=2.8613
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.1910 ± 0.0326
#     RMSE: 3.4389 ± 0.1913
#     MAE:  2.6583 ± 0.1233
#
#   Training SVR...
#     Fold 1/5: R²=0.2625, RMSE=3.0763, MAE=2.4032
#     Fold 2/5: R²=0.3079, RMSE=3.1558, MAE=2.3956
#     Fold 3/5: R²=0.2926, RMSE=3.3454, MAE=2.5441
#     Fold 4/5: R²=0.2218, RMSE=3.3114, MAE=2.5439
#     Fold 5/5: R²=0.3580, RMSE=3.2083, MAE=2.4966
#
#   SVR 5-Fold CV Results:
#     R²:   0.2886 ± 0.0455
#     RMSE: 3.2194 ± 0.0990
#     MAE:  2.4767 ± 0.0655
#
#   Training KNN...
#     Fold 1/5: R²=0.2873, RMSE=3.0241, MAE=2.3645
#     Fold 2/5: R²=0.3273, RMSE=3.1112, MAE=2.3674
#     Fold 3/5: R²=0.1930, RMSE=3.5731, MAE=2.7330
#     Fold 4/5: R²=0.2019, RMSE=3.3534, MAE=2.5887
#     Fold 5/5: R²=0.3006, RMSE=3.3488, MAE=2.6231
#
#   KNN 5-Fold CV Results:
#     R²:   0.2620 ± 0.0544
#     RMSE: 3.2821 ± 0.1949
#     MAE:  2.5353 ± 0.1463
#
#   Training Lasso...
#     Fold 1/5: R²=0.2422, RMSE=3.1184, MAE=2.4486
#     Fold 2/5: R²=0.1531, RMSE=3.4909, MAE=2.6285
#     Fold 3/5: R²=0.1370, RMSE=3.6951, MAE=2.7265
#     Fold 4/5: R²=0.1876, RMSE=3.3832, MAE=2.6210
#     Fold 5/5: R²=0.2556, RMSE=3.4548, MAE=2.6738
#
#   Lasso 5-Fold CV Results:
#     R²:   0.1951 ± 0.0471
#     RMSE: 3.4285 ± 0.1865
#     MAE:  2.6197 ± 0.0935
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.2939, RMSE=3.0101, MAE=2.3718
#     Fold 2/5: R²=0.2874, RMSE=3.2022, MAE=2.4530
#     Fold 3/5: R²=0.2548, RMSE=3.4335, MAE=2.5583
#     Fold 4/5: R²=0.2526, RMSE=3.2452, MAE=2.5290
#     Fold 5/5: R²=0.2913, RMSE=3.3708, MAE=2.6196
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.2760 ± 0.0183
#     RMSE: 3.2524 ± 0.1470
#     MAE:  2.5063 ± 0.0860
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1894, RMSE=3.2252, MAE=2.6063
#     Fold 2/5: R²=0.1483, RMSE=3.5008, MAE=2.7447
#     Fold 3/5: R²=0.1004, RMSE=3.7726, MAE=2.8170
#     Fold 4/5: R²=0.1946, RMSE=3.3688, MAE=2.6720
#     Fold 5/5: R²=0.1318, RMSE=3.7309, MAE=2.9568
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1529 ± 0.0355
#     RMSE: 3.5196 ± 0.2090
#     MAE:  2.7593 ± 0.1213
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.3117, RMSE=2.9719, MAE=2.3282
#     Fold 2/5: R²=0.2571, RMSE=3.2696, MAE=2.4970
#     Fold 3/5: R²=0.2044, RMSE=3.5478, MAE=2.6906
#     Fold 4/5: R²=0.2266, RMSE=3.3011, MAE=2.6046
#     Fold 5/5: R²=0.2303, RMSE=3.5130, MAE=2.7584
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2460 ± 0.0369
#     RMSE: 3.3207 ± 0.2065
#     MAE:  2.5758 ± 0.1516
#
#   Training LightGBM...
#     Fold 1/5: R²=0.3520, RMSE=2.8836, MAE=2.2598
#     Fold 2/5: R²=0.2850, RMSE=3.2077, MAE=2.4382
#     Fold 3/5: R²=0.2277, RMSE=3.4955, MAE=2.6591
#     Fold 4/5: R²=0.2067, RMSE=3.3432, MAE=2.5514
#     Fold 5/5: R²=0.3124, RMSE=3.3203, MAE=2.6248
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2768 ± 0.0535
#     RMSE: 3.2501 ± 0.2049
#     MAE:  2.5067 ± 0.1448
#
#   Training Random Forest...
#     Fold 1/5: R²=0.2107, RMSE=3.1825, MAE=2.5602
#     Fold 2/5: R²=0.1573, RMSE=3.4823, MAE=2.7239
#     Fold 3/5: R²=0.1560, RMSE=3.6540, MAE=2.7467
#     Fold 4/5: R²=0.1538, RMSE=3.4529, MAE=2.7268
#     Fold 5/5: R²=0.1585, RMSE=3.6731, MAE=2.9298
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1673 ± 0.0218
#     RMSE: 3.4889 ± 0.1769
#     MAE:  2.7375 ± 0.1173
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.2949, RMSE=3.0080, MAE=2.3667
#     Fold 2/5: R²=0.2890, RMSE=3.1985, MAE=2.5392
#     Fold 3/5: R²=0.2309, RMSE=3.4881, MAE=2.6704
#     Fold 4/5: R²=0.2080, RMSE=3.3406, MAE=2.6341
#     Fold 5/5: R²=0.2270, RMSE=3.5205, MAE=2.7782
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2500 ± 0.0352
#     RMSE: 3.3111 ± 0.1901
#     MAE:  2.5977 ± 0.1386
#
#   Training SVR...
#     Fold 1/5: R²=0.3733, RMSE=2.8359, MAE=2.1600
#     Fold 2/5: R²=0.3286, RMSE=3.1082, MAE=2.4015
#     Fold 3/5: R²=0.3487, RMSE=3.2100, MAE=2.4370
#     Fold 4/5: R²=0.3575, RMSE=3.0087, MAE=2.2798
#     Fold 5/5: R²=0.3690, RMSE=3.1806, MAE=2.4260
#
#   SVR 5-Fold CV Results:
#     R²:   0.3554 ± 0.0160
#     RMSE: 3.0687 ± 0.1355
#     MAE:  2.3409 ± 0.1064
#
#   Training KNN...
#     Fold 1/5: R²=0.3831, RMSE=2.8136, MAE=2.2469
#     Fold 2/5: R²=0.3564, RMSE=3.0432, MAE=2.2985
#     Fold 3/5: R²=0.3032, RMSE=3.3201, MAE=2.4810
#     Fold 4/5: R²=0.4036, RMSE=2.8989, MAE=2.2699
#     Fold 5/5: R²=0.3108, RMSE=3.3242, MAE=2.5172
#
#   KNN 5-Fold CV Results:
#     R²:   0.3514 ± 0.0393
#     RMSE: 3.0800 ± 0.2109
#     MAE:  2.3627 ± 0.1132
#
#   Training Lasso...
#     Fold 1/5: R²=0.2744, RMSE=3.0515, MAE=2.3534
#     Fold 2/5: R²=0.2688, RMSE=3.2437, MAE=2.5446
#     Fold 3/5: R²=0.2005, RMSE=3.5564, MAE=2.6540
#     Fold 4/5: R²=0.2181, RMSE=3.3191, MAE=2.6385
#     Fold 5/5: R²=0.2566, RMSE=3.4524, MAE=2.7463
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2437 ± 0.0292
#     RMSE: 3.3246 ± 0.1739
#     MAE:  2.5874 ± 0.1333
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3806, RMSE=2.8193, MAE=2.1795
#     Fold 2/5: R²=0.3288, RMSE=3.1077, MAE=2.3835
#     Fold 3/5: R²=0.2864, RMSE=3.3599, MAE=2.5359
#     Fold 4/5: R²=0.3217, RMSE=3.0915, MAE=2.4181
#     Fold 5/5: R²=0.3172, RMSE=3.3087, MAE=2.6014
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3270 ± 0.0305
#     RMSE: 3.1374 ± 0.1913
#     MAE:  2.4237 ± 0.1452
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.3037, RMSE=2.9892, MAE=2.3620
#     Fold 2/5: R²=0.2273, RMSE=3.3344, MAE=2.6175
#     Fold 3/5: R²=0.1618, RMSE=3.6414, MAE=2.7190
#     Fold 4/5: R²=0.2215, RMSE=3.3121, MAE=2.6287
#     Fold 5/5: R²=0.2572, RMSE=3.4511, MAE=2.7199
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.2343 ± 0.0465
#     RMSE: 3.3456 ± 0.2130
#     MAE:  2.6094 ± 0.1310
#
# ====================================================================================================
# NOISE TYPE: High Freq
# ====================================================================================================
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Street View
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2395, RMSE=3.8024, MAE=2.9181
#     Fold 2/5: R²=0.1642, RMSE=4.2215, MAE=3.0357
#     Fold 3/5: R²=0.1676, RMSE=4.0831, MAE=3.1460
#     Fold 4/5: R²=0.2309, RMSE=3.9794, MAE=2.9678
#     Fold 5/5: R²=0.1862, RMSE=3.9159, MAE=2.9593
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.1977 ± 0.0317
#     RMSE: 4.0005 ± 0.1432
#     MAE:  3.0054 ± 0.0798
#
#   Training LightGBM...
#     Fold 1/5: R²=0.1873, RMSE=3.9306, MAE=3.0742
#     Fold 2/5: R²=0.1682, RMSE=4.2114, MAE=3.0197
#     Fold 3/5: R²=0.1796, RMSE=4.0534, MAE=3.1094
#     Fold 4/5: R²=0.2376, RMSE=3.9619, MAE=2.9822
#     Fold 5/5: R²=0.1721, RMSE=3.9496, MAE=3.0381
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.1890 ± 0.0252
#     RMSE: 4.0214 ± 0.1040
#     MAE:  3.0447 ± 0.0439
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1432, RMSE=4.0359, MAE=3.0403
#     Fold 2/5: R²=0.0865, RMSE=4.4135, MAE=3.1092
#     Fold 3/5: R²=0.1306, RMSE=4.1727, MAE=3.0434
#     Fold 4/5: R²=0.1537, RMSE=4.1744, MAE=3.0708
#     Fold 5/5: R²=0.1528, RMSE=3.9956, MAE=2.9555
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1334 ± 0.0249
#     RMSE: 4.1584 ± 0.1463
#     MAE:  3.0439 ± 0.0506
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.1890, RMSE=3.9265, MAE=3.0539
#     Fold 2/5: R²=0.2009, RMSE=4.1278, MAE=2.9884
#     Fold 3/5: R²=0.1289, RMSE=4.1769, MAE=3.1941
#     Fold 4/5: R²=0.2249, RMSE=3.9950, MAE=3.0152
#     Fold 5/5: R²=0.1366, RMSE=4.0334, MAE=3.0743
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.1761 ± 0.0373
#     RMSE: 4.0519 ± 0.0902
#     MAE:  3.0652 ± 0.0710
#
#   Training SVR...
#     Fold 1/5: R²=0.3115, RMSE=3.6177, MAE=2.7220
#     Fold 2/5: R²=0.2821, RMSE=3.9127, MAE=2.8653
#     Fold 3/5: R²=0.1834, RMSE=4.0441, MAE=3.1076
#     Fold 4/5: R²=0.3364, RMSE=3.6963, MAE=2.7165
#     Fold 5/5: R²=0.1881, RMSE=3.9114, MAE=2.9293
#
#   SVR 5-Fold CV Results:
#     R²:   0.2603 ± 0.0633
#     RMSE: 3.8364 ± 0.1562
#     MAE:  2.8681 ± 0.1452
#
#   Training KNN...
#     Fold 1/5: R²=0.3161, RMSE=3.6057, MAE=2.8074
#     Fold 2/5: R²=0.3473, RMSE=3.7306, MAE=2.7378
#     Fold 3/5: R²=0.1539, RMSE=4.1165, MAE=3.1428
#     Fold 4/5: R²=0.3105, RMSE=3.7678, MAE=2.7493
#     Fold 5/5: R²=0.0988, RMSE=4.1207, MAE=3.0817
#
#   KNN 5-Fold CV Results:
#     R²:   0.2453 ± 0.0995
#     RMSE: 3.8683 ± 0.2114
#     MAE:  2.9038 ± 0.1729
#
#   Training Lasso...
#     Fold 1/5: R²=0.2225, RMSE=3.8445, MAE=2.9261
#     Fold 2/5: R²=0.1867, RMSE=4.1643, MAE=3.0887
#     Fold 3/5: R²=0.1739, RMSE=4.0675, MAE=3.0525
#     Fold 4/5: R²=0.2482, RMSE=3.9344, MAE=3.0174
#     Fold 5/5: R²=0.1957, RMSE=3.8930, MAE=2.9538
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2054 ± 0.0267
#     RMSE: 3.9807 ± 0.1180
#     MAE:  3.0077 ± 0.0604
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.2895, RMSE=3.6751, MAE=2.8061
#     Fold 2/5: R²=0.2576, RMSE=3.9786, MAE=2.8255
#     Fold 3/5: R²=0.2194, RMSE=3.9540, MAE=2.9983
#     Fold 4/5: R²=0.3027, RMSE=3.7891, MAE=2.8064
#     Fold 5/5: R²=0.2259, RMSE=3.8193, MAE=2.8879
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.2590 ± 0.0332
#     RMSE: 3.8432 ± 0.1117
#     MAE:  2.8648 ± 0.0732
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1205, RMSE=4.0890, MAE=3.0880
#     Fold 2/5: R²=0.1214, RMSE=4.3284, MAE=3.0576
#     Fold 3/5: R²=0.1151, RMSE=4.2097, MAE=3.0701
#     Fold 4/5: R²=0.1191, RMSE=4.2587, MAE=3.1284
#     Fold 5/5: R²=0.0988, RMSE=4.1207, MAE=3.0500
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1150 ± 0.0084
#     RMSE: 4.2013 ± 0.0879
#     MAE:  3.0788 ± 0.0279
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Remote Sensing
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2308, RMSE=3.8240, MAE=2.9216
#     Fold 2/5: R²=0.2173, RMSE=4.0852, MAE=2.9536
#     Fold 3/5: R²=0.3534, RMSE=3.5985, MAE=2.6968
#     Fold 4/5: R²=0.3094, RMSE=3.7708, MAE=2.7786
#     Fold 5/5: R²=0.1572, RMSE=3.9852, MAE=3.0279
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2536 ± 0.0696
#     RMSE: 3.8527 ± 0.1696
#     MAE:  2.8757 ± 0.1206
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2404, RMSE=3.8000, MAE=2.9363
#     Fold 2/5: R²=0.1933, RMSE=4.1474, MAE=3.0491
#     Fold 3/5: R²=0.3471, RMSE=3.6161, MAE=2.7247
#     Fold 4/5: R²=0.3129, RMSE=3.7614, MAE=2.8833
#     Fold 5/5: R²=0.1194, RMSE=4.0734, MAE=3.0874
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2426 ± 0.0818
#     RMSE: 3.8797 ± 0.1995
#     MAE:  2.9362 ± 0.1289
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1676, RMSE=3.9779, MAE=2.9547
#     Fold 2/5: R²=0.1928, RMSE=4.1486, MAE=2.9838
#     Fold 3/5: R²=0.2446, RMSE=3.8895, MAE=2.8687
#     Fold 4/5: R²=0.2074, RMSE=4.0398, MAE=2.9971
#     Fold 5/5: R²=0.1196, RMSE=4.0729, MAE=3.0783
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1864 ± 0.0417
#     RMSE: 4.0258 ± 0.0876
#     MAE:  2.9765 ± 0.0677
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.1617, RMSE=3.9919, MAE=3.0639
#     Fold 2/5: R²=0.1947, RMSE=4.1438, MAE=3.0242
#     Fold 3/5: R²=0.3066, RMSE=3.7264, MAE=2.8206
#     Fold 4/5: R²=0.2783, RMSE=3.8547, MAE=2.8362
#     Fold 5/5: R²=0.0910, RMSE=4.1387, MAE=3.1491
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2065 ± 0.0783
#     RMSE: 3.9711 ± 0.1623
#     MAE:  2.9788 ± 0.1294
#
#   Training SVR...
#     Fold 1/5: R²=0.2729, RMSE=3.7178, MAE=2.7605
#     Fold 2/5: R²=0.3227, RMSE=3.8004, MAE=2.8692
#     Fold 3/5: R²=0.4181, RMSE=3.4137, MAE=2.6325
#     Fold 4/5: R²=0.4436, RMSE=3.3847, MAE=2.4785
#     Fold 5/5: R²=0.2726, RMSE=3.7023, MAE=2.8542
#
#   SVR 5-Fold CV Results:
#     R²:   0.3460 ± 0.0721
#     RMSE: 3.6038 ± 0.1706
#     MAE:  2.7190 ± 0.1469
#
#   Training KNN...
#     Fold 1/5: R²=0.3254, RMSE=3.5811, MAE=2.7168
#     Fold 2/5: R²=0.2876, RMSE=3.8975, MAE=2.9114
#     Fold 3/5: R²=0.3573, RMSE=3.5878, MAE=2.7165
#     Fold 4/5: R²=0.3890, RMSE=3.5470, MAE=2.6829
#     Fold 5/5: R²=0.2024, RMSE=3.8768, MAE=2.9438
#
#   KNN 5-Fold CV Results:
#     R²:   0.3123 ± 0.0644
#     RMSE: 3.6980 ± 0.1552
#     MAE:  2.7943 ± 0.1100
#
#   Training Lasso...
#     Fold 1/5: R²=0.0963, RMSE=4.1449, MAE=3.1816
#     Fold 2/5: R²=0.1697, RMSE=4.2076, MAE=3.1618
#     Fold 3/5: R²=0.2736, RMSE=3.8142, MAE=2.8962
#     Fold 4/5: R²=0.2353, RMSE=3.9679, MAE=3.0339
#     Fold 5/5: R²=0.1505, RMSE=4.0009, MAE=3.0363
#
#   Lasso 5-Fold CV Results:
#     R²:   0.1851 ± 0.0627
#     RMSE: 4.0271 ± 0.1385
#     MAE:  3.0620 ± 0.1032
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.2877, RMSE=3.6799, MAE=2.7900
#     Fold 2/5: R²=0.2975, RMSE=3.8705, MAE=2.8325
#     Fold 3/5: R²=0.4049, RMSE=3.4524, MAE=2.5847
#     Fold 4/5: R²=0.3859, RMSE=3.5558, MAE=2.6501
#     Fold 5/5: R²=0.2374, RMSE=3.7908, MAE=2.8916
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3227 ± 0.0631
#     RMSE: 3.6699 ± 0.1518
#     MAE:  2.7498 ± 0.1147
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1916, RMSE=3.9201, MAE=2.9681
#     Fold 2/5: R²=0.1677, RMSE=4.2128, MAE=3.0106
#     Fold 3/5: R²=0.1407, RMSE=4.1483, MAE=3.0128
#     Fold 4/5: R²=0.1468, RMSE=4.1913, MAE=3.0597
#     Fold 5/5: R²=0.2060, RMSE=3.8680, MAE=2.8754
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1706 ± 0.0251
#     RMSE: 4.0681 ± 0.1445
#     MAE:  2.9853 ± 0.0621
#
# ----------------------------------------------------------------------------------------------------
# Feature Type: Fusion
# ----------------------------------------------------------------------------------------------------
#
#   Training XGBoost...
#     Fold 1/5: R²=0.2243, RMSE=3.8401, MAE=2.9821
#     Fold 2/5: R²=0.2419, RMSE=4.0207, MAE=2.8698
#     Fold 3/5: R²=0.2552, RMSE=3.8621, MAE=2.8657
#     Fold 4/5: R²=0.3178, RMSE=3.7480, MAE=2.7735
#     Fold 5/5: R²=0.1366, RMSE=4.0334, MAE=3.0453
#
#   XGBoost 5-Fold CV Results:
#     R²:   0.2352 ± 0.0585
#     RMSE: 3.9009 ± 0.1100
#     MAE:  2.9073 ± 0.0956
#
#   Training LightGBM...
#     Fold 1/5: R²=0.2115, RMSE=3.8716, MAE=2.9630
#     Fold 2/5: R²=0.1938, RMSE=4.1461, MAE=3.0385
#     Fold 3/5: R²=0.1968, RMSE=4.0107, MAE=3.0709
#     Fold 4/5: R²=0.3556, RMSE=3.6426, MAE=2.7671
#     Fold 5/5: R²=0.1221, RMSE=4.0672, MAE=3.0529
#
#   LightGBM 5-Fold CV Results:
#     R²:   0.2160 ± 0.0764
#     RMSE: 3.9476 ± 0.1769
#     MAE:  2.9785 ± 0.1119
#
#   Training Random Forest...
#     Fold 1/5: R²=0.1637, RMSE=3.9872, MAE=3.0785
#     Fold 2/5: R²=0.1396, RMSE=4.2833, MAE=3.0225
#     Fold 3/5: R²=0.1782, RMSE=4.0568, MAE=2.9955
#     Fold 4/5: R²=0.2042, RMSE=4.0479, MAE=3.0178
#     Fold 5/5: R²=0.1431, RMSE=4.0183, MAE=3.0294
#
#   Random Forest 5-Fold CV Results:
#     R²:   0.1658 ± 0.0238
#     RMSE: 4.0787 ± 0.1052
#     MAE:  3.0287 ± 0.0273
#
#   Training Gradient Boosting...
#     Fold 1/5: R²=0.1516, RMSE=4.0160, MAE=3.1587
#     Fold 2/5: R²=0.1629, RMSE=4.2250, MAE=3.1419
#     Fold 3/5: R²=0.2344, RMSE=3.9158, MAE=2.9241
#     Fold 4/5: R²=0.3505, RMSE=3.6569, MAE=2.7956
#     Fold 5/5: R²=0.1586, RMSE=3.9819, MAE=2.9833
#
#   Gradient Boosting 5-Fold CV Results:
#     R²:   0.2116 ± 0.0756
#     RMSE: 3.9591 ± 0.1831
#     MAE:  3.0007 ± 0.1365
#
#   Training SVR...
#     Fold 1/5: R²=0.3552, RMSE=3.5010, MAE=2.6705
#     Fold 2/5: R²=0.3784, RMSE=3.6407, MAE=2.6924
#     Fold 3/5: R²=0.3307, RMSE=3.6611, MAE=2.8493
#     Fold 4/5: R²=0.4741, RMSE=3.2906, MAE=2.4386
#     Fold 5/5: R²=0.1573, RMSE=3.9849, MAE=3.0451
#
#   SVR 5-Fold CV Results:
#     R²:   0.3391 ± 0.1031
#     RMSE: 3.6157 ± 0.2271
#     MAE:  2.7392 ± 0.2015
#
#   Training KNN...
#     Fold 1/5: R²=0.3698, RMSE=3.4612, MAE=2.6964
#     Fold 2/5: R²=0.3632, RMSE=3.6850, MAE=2.7313
#     Fold 3/5: R²=0.3316, RMSE=3.6586, MAE=2.7839
#     Fold 4/5: R²=0.4418, RMSE=3.3902, MAE=2.4894
#     Fold 5/5: R²=0.1627, RMSE=3.9721, MAE=2.9804
#
#   KNN 5-Fold CV Results:
#     R²:   0.3338 ± 0.0929
#     RMSE: 3.6334 ± 0.2034
#     MAE:  2.7363 ± 0.1577
#
#   Training Lasso...
#     Fold 1/5: R²=0.2303, RMSE=3.8253, MAE=2.9014
#     Fold 2/5: R²=0.2622, RMSE=3.9663, MAE=2.9252
#     Fold 3/5: R²=0.2471, RMSE=3.8832, MAE=2.9578
#     Fold 4/5: R²=0.3072, RMSE=3.7768, MAE=2.8544
#     Fold 5/5: R²=0.1746, RMSE=3.9437, MAE=3.0382
#
#   Lasso 5-Fold CV Results:
#     R²:   0.2443 ± 0.0432
#     RMSE: 3.8791 ± 0.0709
#     MAE:  2.9354 ± 0.0615
#
#   Creating Ensemble Models...
#
#   Training Voting Ensemble...
#     Fold 1/5: R²=0.3248, RMSE=3.5827, MAE=2.7435
#     Fold 2/5: R²=0.3022, RMSE=3.8574, MAE=2.7800
#     Fold 3/5: R²=0.3260, RMSE=3.6741, MAE=2.7873
#     Fold 4/5: R²=0.4071, RMSE=3.4941, MAE=2.5995
#     Fold 5/5: R²=0.2230, RMSE=3.8264, MAE=2.8866
#
#   Voting Ensemble 5-Fold CV Results:
#     R²:   0.3166 ± 0.0588
#     RMSE: 3.6869 ± 0.1391
#     MAE:  2.7594 ± 0.0929
#
#   Training Stacking Ensemble...
#     Fold 1/5: R²=0.1738, RMSE=3.9631, MAE=3.0413
#     Fold 2/5: R²=0.1854, RMSE=4.1678, MAE=2.9291
#     Fold 3/5: R²=0.1847, RMSE=4.0409, MAE=2.9463
#     Fold 4/5: R²=0.2620, RMSE=3.8982, MAE=2.8664
#     Fold 5/5: R²=0.1808, RMSE=3.9289, MAE=2.9336
#
#   Stacking Ensemble 5-Fold CV Results:
#     R²:   0.1973 ± 0.0326
#     RMSE: 3.9998 ± 0.0965
#     MAE:  2.9433 ± 0.0563
#
# ========================================================================================================================
#                           K-FOLD CROSS-VALIDATION RESULTS SUMMARY
# ========================================================================================================================
#
# ====================================================================================================
# NOISE TYPE: Mean Noise
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.3532 ± 0.0436
#   RMSE: 3.1739 ± 0.1723
#   MAE:  2.4193 ± 0.1282
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.3506 ± 0.0797
#   RMSE: 3.1816 ± 0.3020
#   MAE:  2.4277 ± 0.1865
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.3413 ± 0.0291
#   RMSE: 3.2050 ± 0.1717
#   MAE:  2.4774 ± 0.1079
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Street View
#   R²:   0.3231 ± 0.0359
#   RMSE: 3.2490 ± 0.1902
#   MAE:  2.5365 ± 0.1271
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.3192 ± 0.0421
#   RMSE: 3.2588 ± 0.2115
#   MAE:  2.5419 ± 0.1345
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.3064 ± 0.0567
#   RMSE: 3.2890 ± 0.2410
#   MAE:  2.5374 ± 0.1380
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.2907 ± 0.0296
#   RMSE: 3.3222 ± 0.0828
#   MAE:  2.5809 ± 0.0467
# ...
# SVR                  (Base      ) + Fusion
#   R²:   0.3463 ± 0.0337
#   RMSE: 3.1720 ± 0.1039
#   MAE:  2.4626 ± 0.1058
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.3177 ± 0.0496
#   RMSE: 3.2400 ± 0.1441
#   MAE:  2.5078 ± 0.1012
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.3038 ± 0.0500
#   RMSE: 3.2734 ± 0.1540
#   MAE:  2.5547 ± 0.1466
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.3000 ± 0.0517
#   RMSE: 3.2815 ± 0.1445
#   MAE:  2.5236 ± 0.1559
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.2978 ± 0.0653
#   RMSE: 3.2851 ± 0.1632
#   MAE:  2.5080 ± 0.1020
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.2943 ± 0.0436
#   RMSE: 3.2966 ± 0.1559
#   MAE:  2.5686 ± 0.1140
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Street View
#   R²:   0.2796 ± 0.0305
#   RMSE: 3.3317 ± 0.1393
#   MAE:  2.6023 ± 0.1471
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.2643 ± 0.0563
#   RMSE: 3.3619 ± 0.1017
#   MAE:  2.5858 ± 0.0671
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Remote Sensing
#   R²:   0.2389 ± 0.0479
#   RMSE: 3.4228 ± 0.1507
#   MAE:  2.6849 ± 0.0855
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# NOISE TYPE: Mid Freq
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.3554 ± 0.0160
#   RMSE: 3.0687 ± 0.1355
#   MAE:  2.3409 ± 0.1064
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.3514 ± 0.0393
#   RMSE: 3.0800 ± 0.2109
#   MAE:  2.3627 ± 0.1132
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.3290 ± 0.0268
#   RMSE: 3.1321 ± 0.1773
#   MAE:  2.4165 ± 0.0999
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.3270 ± 0.0305
#   RMSE: 3.1374 ± 0.1913
#   MAE:  2.4237 ± 0.1452
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.3078 ± 0.0198
#   RMSE: 3.1806 ± 0.1567
#   MAE:  2.4635 ± 0.1229
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Street View
#   R²:   0.3007 ± 0.0351
#   RMSE: 3.1976 ± 0.1963
#   MAE:  2.5127 ± 0.1505
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.2886 ± 0.0455
#   RMSE: 3.2194 ± 0.0990
#   MAE:  2.4767 ± 0.0655
# ----------------------------------------------------------------------------------------------------
# LightGBM             (Base      ) + Fusion
#   R²:   0.2768 ± 0.0535
#   RMSE: 3.2501 ± 0.2049
#   MAE:  2.5067 ± 0.1448
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.2760 ± 0.0183
#   RMSE: 3.2524 ± 0.1470
#   MAE:  2.5063 ± 0.0860
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.2620 ± 0.0544
#   RMSE: 3.2821 ± 0.1949
#   MAE:  2.5353 ± 0.1463
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# NOISE TYPE: High Freq
# ====================================================================================================
#
# Top 10 Models (by R² Score):
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Remote Sensing
#   R²:   0.3460 ± 0.0721
#   RMSE: 3.6038 ± 0.1706
#   MAE:  2.7190 ± 0.1469
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Fusion
#   R²:   0.3391 ± 0.1031
#   RMSE: 3.6157 ± 0.2271
#   MAE:  2.7392 ± 0.2015
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Fusion
#   R²:   0.3338 ± 0.0929
#   RMSE: 3.6334 ± 0.2034
#   MAE:  2.7363 ± 0.1577
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Remote Sensing
#   R²:   0.3227 ± 0.0631
#   RMSE: 3.6699 ± 0.1518
#   MAE:  2.7498 ± 0.1147
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Fusion
#   R²:   0.3166 ± 0.0588
#   RMSE: 3.6869 ± 0.1391
#   MAE:  2.7594 ± 0.0929
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Remote Sensing
#   R²:   0.3123 ± 0.0644
#   RMSE: 3.6980 ± 0.1552
#   MAE:  2.7943 ± 0.1100
# ----------------------------------------------------------------------------------------------------
# SVR                  (Base      ) + Street View
#   R²:   0.2603 ± 0.0633
#   RMSE: 3.8364 ± 0.1562
#   MAE:  2.8681 ± 0.1452
# ----------------------------------------------------------------------------------------------------
# Voting               (Ensemble  ) + Street View
#   R²:   0.2590 ± 0.0332
#   RMSE: 3.8432 ± 0.1117
#   MAE:  2.8648 ± 0.0732
# ----------------------------------------------------------------------------------------------------
# XGBoost              (Base      ) + Remote Sensing
#   R²:   0.2536 ± 0.0696
#   RMSE: 3.8527 ± 0.1696
#   MAE:  2.8757 ± 0.1206
# ----------------------------------------------------------------------------------------------------
# KNN                  (Base      ) + Street View
#   R²:   0.2453 ± 0.0995
#   RMSE: 3.8683 ± 0.2114
#   MAE:  2.9038 ± 0.1729
# ----------------------------------------------------------------------------------------------------
#
# ========================================================================================================================
#                           OVERALL TOP 10 BEST MODELS
# ========================================================================================================================
#
# KNN                  (Base      )
#   Noise: Low Freq, Features: Fusion
#   R²:   0.3638 ± 0.0449
#   RMSE: 3.1270 ± 0.0937
#   MAE:  2.4106 ± 0.0759
#
# SVR                  (Base      )
#   Noise: Mid Freq, Features: Fusion
#   R²:   0.3554 ± 0.0160
#   RMSE: 3.0687 ± 0.1355
#   MAE:  2.3409 ± 0.1064
#
# SVR                  (Base      )
#   Noise: Mean Noise, Features: Fusion
#   R²:   0.3532 ± 0.0436
#   RMSE: 3.1739 ± 0.1723
#   MAE:  2.4193 ± 0.1282
#
# KNN                  (Base      )
#   Noise: Mid Freq, Features: Fusion
#   R²:   0.3514 ± 0.0393
#   RMSE: 3.0800 ± 0.2109
#   MAE:  2.3627 ± 0.1132
#
# KNN                  (Base      )
#   Noise: Mean Noise, Features: Fusion
#   R²:   0.3506 ± 0.0797
#   RMSE: 3.1816 ± 0.3020
#   MAE:  2.4277 ± 0.1865
#
# SVR                  (Base      )
#   Noise: Low Freq, Features: Fusion
#   R²:   0.3463 ± 0.0337
#   RMSE: 3.1720 ± 0.1039
#   MAE:  2.4626 ± 0.1058
#
# SVR                  (Base      )
#   Noise: High Freq, Features: Remote Sensing
#   R²:   0.3460 ± 0.0721
#   RMSE: 3.6038 ± 0.1706
#   MAE:  2.7190 ± 0.1469
#
# Voting               (Ensemble  )
#   Noise: Mean Noise, Features: Fusion
#   R²:   0.3413 ± 0.0291
#   RMSE: 3.2050 ± 0.1717
#   MAE:  2.4774 ± 0.1079
#
# SVR                  (Base      )
#   Noise: High Freq, Features: Fusion
#   R²:   0.3391 ± 0.1031
#   RMSE: 3.6157 ± 0.2271
#   MAE:  2.7392 ± 0.2015
#
# KNN                  (Base      )
#   Noise: High Freq, Features: Fusion
#   R²:   0.3338 ± 0.0929
#   RMSE: 3.6334 ± 0.2034
#   MAE:  2.7363 ± 0.1577
#
# ========================================================================================================================
#
# ========================================================================================================================
# Results saved to 'comprehensive_kfold_results.csv'
#
# ========================================================================================================================
# SAVING ALL BEST MODELS...
# ========================================================================================================================
#   ✓ Saved: Mean Noise - street - XGBoost
#   ✓ Saved: Mean Noise - street - LightGBM
#   ✓ Saved: Mean Noise - street - Random Forest
#   ✓ Saved: Mean Noise - street - Gradient Boosting
#   ✓ Saved: Mean Noise - street - SVR
#   ✓ Saved: Mean Noise - street - KNN
#   ✓ Saved: Mean Noise - street - Lasso
#   ✓ Saved: Mean Noise - street - Voting
#   ✓ Saved: Mean Noise - street - Stacking
#   ✓ Saved: Mean Noise - remote - XGBoost
#   ✓ Saved: Mean Noise - remote - LightGBM
#   ✓ Saved: Mean Noise - remote - Random Forest
#   ✓ Saved: Mean Noise - remote - Gradient Boosting
#   ✓ Saved: Mean Noise - remote - SVR
#   ✓ Saved: Mean Noise - remote - KNN
#   ✓ Saved: Mean Noise - remote - Lasso
#   ✓ Saved: Mean Noise - remote - Voting
#   ✓ Saved: Mean Noise - remote - Stacking
#   ✓ Saved: Mean Noise - fusion - XGBoost
#   ✓ Saved: Mean Noise - fusion - LightGBM
#   ✓ Saved: Mean Noise - fusion - Random Forest
#   ✓ Saved: Mean Noise - fusion - Gradient Boosting
#   ✓ Saved: Mean Noise - fusion - SVR
#   ✓ Saved: Mean Noise - fusion - KNN
#   ✓ Saved: Mean Noise - fusion - Lasso
#   ✓ Saved: Mean Noise - fusion - Voting
#   ✓ Saved: Mean Noise - fusion - Stacking
#   ✓ Saved: Low Freq - street - XGBoost
#   ✓ Saved: Low Freq - street - LightGBM
#   ✓ Saved: Low Freq - street - Random Forest
#   ✓ Saved: Low Freq - street - Gradient Boosting
#   ✓ Saved: Low Freq - street - SVR
#   ✓ Saved: Low Freq - street - KNN
#   ✓ Saved: Low Freq - street - Lasso
#   ✓ Saved: Low Freq - street - Voting
#   ✓ Saved: Low Freq - street - Stacking
#   ✓ Saved: Low Freq - remote - XGBoost
#   ✓ Saved: Low Freq - remote - LightGBM
#   ✓ Saved: Low Freq - remote - Random Forest
#   ✓ Saved: Low Freq - remote - Gradient Boosting
#   ✓ Saved: Low Freq - remote - SVR
#   ✓ Saved: Low Freq - remote - KNN
#   ✓ Saved: Low Freq - remote - Lasso
#   ✓ Saved: Low Freq - remote - Voting
#   ✓ Saved: Low Freq - remote - Stacking
#   ✓ Saved: Low Freq - fusion - XGBoost
#   ✓ Saved: Low Freq - fusion - LightGBM
#   ✓ Saved: Low Freq - fusion - Random Forest
#   ✓ Saved: Low Freq - fusion - Gradient Boosting
#   ✓ Saved: Low Freq - fusion - SVR
#   ✓ Saved: Low Freq - fusion - KNN
#   ✓ Saved: Low Freq - fusion - Lasso
#   ✓ Saved: Low Freq - fusion - Voting
#   ✓ Saved: Low Freq - fusion - Stacking
#   ✓ Saved: Mid Freq - street - XGBoost
#   ✓ Saved: Mid Freq - street - LightGBM
#   ✓ Saved: Mid Freq - street - Random Forest
#   ✓ Saved: Mid Freq - street - Gradient Boosting
#   ✓ Saved: Mid Freq - street - SVR
#   ✓ Saved: Mid Freq - street - KNN
#   ✓ Saved: Mid Freq - street - Lasso
#   ✓ Saved: Mid Freq - street - Voting
#   ✓ Saved: Mid Freq - street - Stacking
#   ✓ Saved: Mid Freq - remote - XGBoost
#   ✓ Saved: Mid Freq - remote - LightGBM
#   ✓ Saved: Mid Freq - remote - Random Forest
#   ✓ Saved: Mid Freq - remote - Gradient Boosting
#   ✓ Saved: Mid Freq - remote - SVR
#   ✓ Saved: Mid Freq - remote - KNN
#   ✓ Saved: Mid Freq - remote - Lasso
#   ✓ Saved: Mid Freq - remote - Voting
#   ✓ Saved: Mid Freq - remote - Stacking
#   ✓ Saved: Mid Freq - fusion - XGBoost
#   ✓ Saved: Mid Freq - fusion - LightGBM
#   ✓ Saved: Mid Freq - fusion - Random Forest
#   ✓ Saved: Mid Freq - fusion - Gradient Boosting
#   ✓ Saved: Mid Freq - fusion - SVR
#   ✓ Saved: Mid Freq - fusion - KNN
#   ✓ Saved: Mid Freq - fusion - Lasso
#   ✓ Saved: Mid Freq - fusion - Voting
#   ✓ Saved: Mid Freq - fusion - Stacking
#   ✓ Saved: High Freq - street - XGBoost
#   ✓ Saved: High Freq - street - LightGBM
#   ✓ Saved: High Freq - street - Random Forest
#   ✓ Saved: High Freq - street - Gradient Boosting
#   ✓ Saved: High Freq - street - SVR
#   ✓ Saved: High Freq - street - KNN
#   ✓ Saved: High Freq - street - Lasso
#   ✓ Saved: High Freq - street - Voting
#   ✓ Saved: High Freq - street - Stacking
#   ✓ Saved: High Freq - remote - XGBoost
#   ✓ Saved: High Freq - remote - LightGBM
#   ✓ Saved: High Freq - remote - Random Forest
#   ✓ Saved: High Freq - remote - Gradient Boosting
#   ✓ Saved: High Freq - remote - SVR
#   ✓ Saved: High Freq - remote - KNN
#   ✓ Saved: High Freq - remote - Lasso
#   ✓ Saved: High Freq - remote - Voting
#   ✓ Saved: High Freq - remote - Stacking
#   ✓ Saved: High Freq - fusion - XGBoost
#   ✓ Saved: High Freq - fusion - LightGBM
#   ✓ Saved: High Freq - fusion - Random Forest
#   ✓ Saved: High Freq - fusion - Gradient Boosting
#   ✓ Saved: High Freq - fusion - SVR
#   ✓ Saved: High Freq - fusion - KNN
#   ✓ Saved: High Freq - fusion - Lasso
#   ✓ Saved: High Freq - fusion - Voting
#   ✓ Saved: High Freq - fusion - Stacking
#
#   ✓ Saved complete predictor object
#
# ========================================================================================================================
# Successfully saved 108 models to 'saved_models' directory
# ========================================================================================================================
# ========================================================================================================================
#
# ========================================================================================================================
#                            EXPERIMENT COMPLETED SUCCESSFULLY
# ========================================================================================================================
#
# Summary:
# • Total models evaluated: 9 (7 base models + 2 ensemble models)
# • Base models: XGBoost, LightGBM, Random Forest, Gradient Boosting, SVR, KNN, Lasso
# • Ensemble models: Voting (7 models), Stacking (7 models + Lasso)
# • Feature types: Street View, Remote Sensing, Fusion
# • Noise types: Mean Noise, Low Freq, Mid Freq, High Freq
# • Cross-validation: 5-fold
# • Metrics: R², RMSE, MAE, MSE (all with mean ± std)
# • All models saved to 'saved_models/' directory
#
# Results saved to 'comprehensive_kfold_results.csv'
#
# ========================================================================================================================
# DEMONSTRATION: How to Load and Use Saved Models
# ========================================================================================================================
#
# 1. Loading a single model:
# Loaded model: Mean Noise - fusion - XGBoost
#   R²: 0.2735
#   RMSE: 3.3654
#   MAE: 2.6101
#
# 2. Making predictions with a saved model:
#   predictions = predictor.predict_with_saved_model(
#       X_new=new_data,
#       noise_type='Mean Noise',
#       feature_type='fusion',
#       model_name='XGBoost'
#   )
#
# 3. Loading complete predictor:
#   loaded_predictor = ComprehensiveKFoldNoisePredictor.load_complete_predictor('saved_models')
